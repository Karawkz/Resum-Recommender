# %%
import pandas as pd
from pymongo import MongoClient
import warnings
warnings.filterwarnings('ignore')
from nltk import WordNetLemmatizer, word_tokenize
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.decomposition import NMF, TruncatedSVD
from gensim.models import Word2Vec
import string
import numpy as np
import json
import pickle

# %% [markdown]
# #### Loading the Data

# %%
client = MongoClient()
client.list_database_names()
# Out:
# ['admin',
#  'books',
#  'catalog',
#  'config',
#  'events',
#  'legistlation',
#  'local',
#  'resumes']

# %%
resumes = client.resumes.resumes_cleaned
resumes.count()
# Out:
# 21068

# %%
df = pd.DataFrame(list(resumes.find({'Title':{'$exists': 1}},
                                    {'Companies': 1, 'Resume Summary': 1, 'Current Location': 1, 
                                     'Start Dates': 1, 'Work Experiences': 1, 'Universities': 1, 'Analyst': 1, 
                                     'Engineer': 1, 'Scientist': 1, 'Bachelors': 1, 'Masters': 1, 'PhD': 1,
                                     'in': 1, 'Skills': 1, 'Additionals': 1, 'y':1, '_id': 0})))
df.head()
# Out:
#                                          Additionals  Analyst  Bachelors  \
# 0                                                           1          1
# 1                                                           1          1
# 2                                                           0          1
# 3                                                           1          1
# 4  '/ Licenses VMware Certified Professional ( VC...        0          1
#
#                                            Companies   Current Location  \
# 0  ' Yoox Net- A- Porter Group', ' Yoox Net- A- P...                 ''
# 1  ' Thimble LLC/ contract', ' Florida State Univ...  ' Washington, DC'
# 2  ' New York State Office of Mental Health', ' N...    ' New York, NY'
# 3  ' Allied Benefit Systems', ' Expedia, Inc.', '...     ' Chicago, IL'
# 4  ' Presidio', ' Presidio', ' Global', ' The Geo...      ' Reston, VA'
#
#    Engineer  Masters  PhD                                     Resume Summary  \
# 0         0        0    0  ' Goal-oriented team player with experience in...
# 1         0        0    0  ' Detail-oriented, methodical, and analytical,...
# 2         1        1    0  ' Over 15 years of experience in information t...
# 3         0        0    0
# 4         1        1    0  " 6+ years of experience in Data Center design...
#
#    Scientist                                             Skills Start Dates  \
# 0          0  ' SERVICE', '3 years', ' SALES', '3 years', ' ...           6
# 1          0  ' Microsoft Office', '5 years', ' SAS', '2 yea...           2
# 2          0  ' ORACLE', '10+ years', ' PL/ SQL', '10+ years...          18
# 3          0  ' VBA', '3 years', ' Excel', '3 years', ' Powe...           5
# 4          0  ' Vmware', '6 years', ' Cisco', '6 years', ' E...           8
#
#                                         Universities  \
# 0           ' Bloomsburg University of Pennsylvania'
# 1                        ' Florida State University'
# 2  ' Arizona State University', ' Annamalai Unive...
# 3  ' Statistics B. Sc. Concordia University Montr...
# 4  ' The George Washington University', ' Univers...
#
#                                     Work Experiences  \
# 0  ' Formulate sales reports and other metrics us...
# 1  ' Manually adjusted and corrected data collect...
# 2  '- Worked on Data Warehouse projects from ince...
# 3  '- Collected, cleaned, organized data from mul...
# 4  ' Presidio was founded to fill a niche overloo...
#
#                                                   in         y
# 0           ' Business Administration and Marketing'   Analyst
# 1                                      ' Statistics'   Analyst
# 2  ' Information Systems', ' Mechanical and Produ...  Engineer
# 3                          ' Mathematics of Finance'   Analyst
# 4  ' Electrical Engineering', ' Electronics Engin...  Engineer

# %%
df = df.astype(str)

# %% [markdown]
# ### Tokenization

# %%
lemmatize = WordNetLemmatizer()
translator = str.maketrans('', '', string.punctuation)
def token_text(text):
    tokens = word_tokenize(text)
    clean_tokens = [lemmatize.lemmatize(token.lower().strip().translate(translator)) for token in tokens]
    return ' '.join(clean_tokens)

# %%
df_ = df.copy()
def token_columns(df,df_):
    for column in df_.columns:
        df_[column] = df[column].apply(token_text)
    return df_

df_ = token_columns(df,df_)

# %%
df_.head()
# Out:
#                                          Additionals Analyst Bachelors  \
# 0                                                          1         1
# 1                                                          1         1
# 2                                                          0         1
# 3                                                          1         1
# 4   license vmware certified professional  vcp  j...       0         1
#
#                                            Companies  Current Location  \
# 0   yoox net a porter group    yoox net a porter ...
# 1   thimble llc contract    florida state univers...   washington  dc
# 2   new york state office of mental health    new...     new york  ny
# 3   allied benefit system    expedia  inc    aspi...      chicago  il
# 4   presidio    presidio    global    the george ...       reston  va
#
#   Engineer Masters PhD                                     Resume Summary  \
# 0        0       0   0   goaloriented team player with experience in v...
# 1        0       0   0   detailoriented  methodical  and analytical  a...
# 2        1       1   0   over 15 year of experience in information tec...
# 3        0       0   0
# 4        1       1   0   6 year of experience in data center design  i...
#
#   Scientist                                             Skills Start Dates  \
# 0         0   service   3 year    sale   3 year    sale   2...           6
# 1         0   microsoft office   5 year    sa   2 year    d...           2
# 2         0   oracle   10 year    pl sql   10 year    sql  ...          18
# 3         0   vba   3 year    excel   3 year    power bi   ...           5
# 4         0   vmware   6 year    cisco   6 year    emc   6 ...           8
#
#                                         Universities  \
# 0             bloomsburg university of pennsylvania
# 1                          florida state university
# 2   arizona state university    annamalai univers...
# 3     statistic b sc  concordia university montreal
# 4   the george washington university    universit...
#
#                                     Work Experiences  \
# 0   formulate sale report and other metric using ...
# 1   manually adjusted and corrected data collecti...
# 2   worked on data warehouse project from incepti...
# 3   collected  cleaned  organized data from multi...
# 4   presidio wa founded to fill a niche overlooke...
#
#                                                   in         y
# 0             business administration and marketing    analyst
# 1                                         statistic    analyst
# 2   information system    mechanical and production   engineer
# 3                            mathematics of finance    analyst
# 4   electrical engineering    electronics enginee...  engineer

# %%
df_combined = df_['Companies'] + df_['Skills'] + df_['Additionals'] + df_['Current Location'] + df_['Resume Summary']\
+ df_['Universities'] + df_['Work Experiences'] + df_['in']

df_combined = pd.DataFrame(df_combined, columns=['text'])
df_combined.head()
# Out:
#                                                 text
# 0   yoox net a porter group    yoox net a porter ...
# 1   thimble llc contract    florida state univers...
# 2   new york state office of mental health    new...
# 3   allied benefit system    expedia  inc    aspi...
# 4   presidio    presidio    global    the george ...

# %%
with open('df.pkl','wb') as file:
    pickle.dump(df_combined,file)

# %% [markdown]
# ### Word2Vec

# %%
sentences = df_combined.text.str.split()
model = Word2Vec(sentences, size=100, window=5, min_count=5)

model.wv.most_similar('scientist')
# Out:
# [('enthusiast', 0.6711856722831726),
#  ('statistician', 0.6542973518371582),
#  ('analyst', 0.6500447988510132),
#  ('mathematician', 0.6346460580825806),
#  ('aspiring', 0.6344203948974609),
#  ('resultsdriven', 0.6298266649246216),
#  ('researcher', 0.6288260221481323),
#  ('seasoned', 0.6143649816513062),
#  ('strategist', 0.6112597584724426),
#  ('engineer', 0.6069817543029785)]

# %%
# Function to take a document as a list of words and return the document vector
def get_doc_vec(words, model):
    good_words = []
    for word in words:
        # Words not in the original model will fail
        try:
            if model.wv[word] is not None:
                good_words.append(word)
        except:
            continue
    # If no words are in the original model
    if len(good_words) == 0:
        return None
    # Return the mean of the vectors for all the good words
    return model.wv[good_words].mean(axis=0)

# %%
vecs = df_combined.text.str.split().map(lambda x: get_doc_vec(x, model))
df_['vecs'] = vecs
df_.dropna(subset=['vecs'],inplace=True)
df_.head()
# Out:
#                                          Additionals Analyst Bachelors  \
# 0                                                          1         1
# 1                                                          1         1
# 2                                                          0         1
# 3                                                          1         1
# 4   license vmware certified professional  vcp  j...       0         1
#
#                                            Companies  Current Location  \
# 0   yoox net a porter group    yoox net a porter ...
# 1   thimble llc contract    florida state univers...   washington  dc
# 2   new york state office of mental health    new...     new york  ny
# 3   allied benefit system    expedia  inc    aspi...      chicago  il
# 4   presidio    presidio    global    the george ...       reston  va
#
#   Engineer Masters PhD                                     Resume Summary  \
# 0        0       0   0   goaloriented team player with experience in v...
# 1        0       0   0   detailoriented  methodical  and analytical  a...
# 2        1       1   0   over 15 year of experience in information tec...
# 3        0       0   0
# 4        1       1   0   6 year of experience in data center design  i...
#
#   Scientist                                             Skills Start Dates  \
# 0         0   service   3 year    sale   3 year    sale   2...           6
# 1         0   microsoft office   5 year    sa   2 year    d...           2
# 2         0   oracle   10 year    pl sql   10 year    sql  ...          18
# 3         0   vba   3 year    excel   3 year    power bi   ...           5
# 4         0   vmware   6 year    cisco   6 year    emc   6 ...           8
#
#                                         Universities  \
# 0             bloomsburg university of pennsylvania
# 1                          florida state university
# 2   arizona state university    annamalai univers...
# 3     statistic b sc  concordia university montreal
# 4   the george washington university    universit...
#
#                                     Work Experiences  \
# 0   formulate sale report and other metric using ...
# 1   manually adjusted and corrected data collecti...
# 2   worked on data warehouse project from incepti...
# 3   collected  cleaned  organized data from multi...
# 4   presidio wa founded to fill a niche overlooke...
#
#                                                   in         y  \
# 0             business administration and marketing    analyst
# 1                                         statistic    analyst
# 2   information system    mechanical and production   engineer
# 3                            mathematics of finance    analyst
# 4   electrical engineering    electronics enginee...  engineer
#
#                                                 vecs
# 0  [0.41427964, -0.88509446, 0.3524626, 0.5670323...
# 1  [0.2914878, -0.59264576, 0.43134314, 0.6466263...
# 2  [0.58659595, -0.24278928, 0.47927913, 0.431336...
# 3  [0.93572193, -0.3007371, 0.44101924, 0.4377344...
# 4  [0.17530711, -0.3703728, -0.076127686, 0.11814...

# %%
# Create a Numpy array of the document vectors
np_vecs = np.zeros((len(df_), 100))
for i, vec in enumerate(df_['vecs']):
    np_vecs[i, :] = vec
    
# Combine the full dataframe with the labels
w2v_data = pd.concat([df_.reset_index(), pd.DataFrame(np_vecs)], axis=1)

# %%
w2v_data = w2v_data.drop(['index','Additionals','vecs','Companies','Current Location','Resume Summary',
                         'Skills','Universities','Work Experiences','in'],axis=1)
w2v_data.head()
# Out:
#   Analyst Bachelors Engineer Masters PhD Scientist Start Dates         y  \
# 0       1         1        0       0   0         0           6   analyst
# 1       1         1        0       0   0         0           2   analyst
# 2       0         1        1       1   0         0          18  engineer
# 3       1         1        0       0   0         0           5   analyst
# 4       0         1        1       1   0         0           8  engineer
#
#           0         1    ...           90        91        92        93  \
# 0  0.414280 -0.885094    ...     0.253690  0.018478 -0.135905 -0.812658
# 1  0.291488 -0.592646    ...     0.091699 -0.087341 -0.188046 -0.413816
# 2  0.586596 -0.242789    ...     0.607049 -0.277285  0.089873 -0.936028
# 3  0.935722 -0.300737    ...     0.339273 -0.294313  0.121354 -0.538947
# 4  0.175307 -0.370373    ...    -0.032867 -0.170324 -0.097706 -0.499279
#
#          94        95        96        97        98        99
# 0 -0.206039 -0.429455 -0.375995  0.705037  0.211959  0.305924
# 1 -0.357783 -0.675707 -0.790313  0.477981 -0.170263 -0.303014
# 2  0.136684 -0.193377 -0.427384  0.174778  0.108993  0.274367
# 3 -0.113011 -0.777224 -0.537407 -0.062251 -0.406997 -0.052850
# 4 -0.043168 -0.114414 -0.118862  0.376500 -0.097990  0.213679
#
# [5 rows x 108 columns]

# %% [markdown]
# #### Store data in MongoDB and pickle files.

# %%
client = MongoClient('localhost', 27017)
db = client['resumes']

w2v_data_coll = json.loads(w2v_data.T.to_json()).values()
db.w2v.insert(w2v_data_coll)
# Out:
# [ObjectId('5b9aad759bd8d2174df93767'),
#  ObjectId('5b9aad759bd8d2174df93768'),
#  ObjectId('5b9aad759bd8d2174df93769'),
#  ObjectId('5b9aad759bd8d2174df9376a'),
#  ObjectId('5b9aad759bd8d2174df9376b'),
#  ObjectId('5b9aad759bd8d2174df9376c'),
#  ObjectId('5b9aad759bd8d2174df9376d'),
#  ObjectId('5b9aad759bd8d2174df9376e'),
#  ObjectId('5b9aad759bd8d2174df9376f'),
#  ObjectId('5b9aad759bd8d2174df93770'),
#  ObjectId('5b9aad759bd8d2174df93771'),
#  ObjectId('5b9aad759bd8d2174df93772'),
#  ObjectId('5b9aad759bd8d2174df93773'),
#  ObjectId('5b9aad759bd8d2174df93774'),
#  ObjectId('5b9aad759bd8d2174df93775'),
#  ObjectId('5b9aad759bd8d2174df93776'),
#  ObjectId('5b9aad759bd8d2174df93777'),
#  ObjectId('5b9aad759bd8d2174df93778'),
#  ObjectId('5b9aad759bd8d2174df93779'),
#  ObjectId('5b9aad759bd8d2174df9377a'),
#  ObjectId('5b9aad759bd8d2174df9377b'),
#  ObjectId('5b9aad759bd8d2174df9377c'),
#  ObjectId('5b9aad759bd8d2174df9377d'),
#  ObjectId('5b9aad759bd8d2174df9377e'),
#  ObjectId('5b9aad759bd8d2174df9377f'),
#  ObjectId('5b9aad759bd8d2174df93780'),
#  ObjectId('5b9aad759bd8d2174df93781'),
#  ObjectId('5b9aad759bd8d2174df93782'),
#  ObjectId('5b9aad759bd8d2174df93783'),
#  ObjectId('5b9aad759bd8d2174df93784'),
#  ObjectId('5b9aad759bd8d2174df93785'),
#  ObjectId('5b9aad759bd8d2174df93786'),
#  ObjectId('5b9aad759bd8d2174df93787'),
#  ObjectId('5b9aad759bd8d2174df93788'),
#  ObjectId('5b9aad759bd8d2174df93789'),
#  ObjectId('5b9aad759bd8d2174df9378a'),
#  ObjectId('5b9aad759bd8d2174df9378b'),
#  ObjectId('5b9aad759bd8d2174df9378c'),
#  ObjectId('5b9aad759bd8d2174df9378d'),
#  ObjectId('5b9aad759bd8d2174df9378e'),
#  ObjectId('5b9aad759bd8d2174df9378f'),
#  ObjectId('5b9aad759bd8d2174df93790'),
#  ObjectId('5b9aad759bd8d2174df93791'),
#  ObjectId('5b9aad759bd8d2174df93792'),
#  ObjectId('5b9aad759bd8d2174df93793'),
#  ObjectId('5b9aad759bd8d2174df93794'),
#  ObjectId('5b9aad759bd8d2174df93795'),
#  ObjectId('5b9aad759bd8d2174df93796'),
#  ObjectId('5b9aad759bd8d2174df93797'),
#  ObjectId('5b9aad759bd8d2174df93798'),
#  ObjectId('5b9aad759bd8d2174df93799'),
#  ObjectId('5b9aad759bd8d2174df9379a'),
#  ObjectId('5b9aad759bd8d2174df9379b'),
#  ObjectId('5b9aad759bd8d2174df9379c'),
#  ObjectId('5b9aad759bd8d2174df9379d'),
#  ObjectId('5b9aad759bd8d2174df9379e'),
#  ObjectId('5b9aad759bd8d2174df9379f'),
#  ObjectId('5b9aad759bd8d2174df937a0'),
#  ObjectId('5b9aad759bd8d2174df937a1'),
#  ObjectId('5b9aad759bd8d2174df937a2'),
#  ObjectId('5b9aad759bd8d2174df937a3'),
#  ObjectId('5b9aad759bd8d2174df937a4'),
#  ObjectId('5b9aad759bd8d2174df937a5'),
#  ObjectId('5b9aad759bd8d2174df937a6'),
#  ObjectId('5b9aad759bd8d2174df937a7'),
#  ObjectId('5b9aad759bd8d2174df937a8'),
#  ObjectId('5b9aad759bd8d2174df937a9'),
#  ObjectId('5b9aad759bd8d2174df937aa'),
#  ObjectId('5b9aad759bd8d2174df937ab'),
#  ObjectId('5b9aad759bd8d2174df937ac'),
#  ObjectId('5b9aad759bd8d2174df937ad'),
#  ObjectId('5b9aad759bd8d2174df937ae'),
#  ObjectId('5b9aad759bd8d2174df937af'),
#  ObjectId('5b9aad759bd8d2174df937b0'),
#  ObjectId('5b9aad759bd8d2174df937b1'),
#  ObjectId('5b9aad759bd8d2174df937b2'),
#  ObjectId('5b9aad759bd8d2174df937b3'),
#  ObjectId('5b9aad759bd8d2174df937b4'),
#  ObjectId('5b9aad759bd8d2174df937b5'),
#  ObjectId('5b9aad759bd8d2174df937b6'),
#  ObjectId('5b9aad759bd8d2174df937b7'),
#  ObjectId('5b9aad759bd8d2174df937b8'),
#  ObjectId('5b9aad759bd8d2174df937b9'),
#  ObjectId('5b9aad759bd8d2174df937ba'),
#  ObjectId('5b9aad759bd8d2174df937bb'),
#  ObjectId('5b9aad759bd8d2174df937bc'),
#  ObjectId('5b9aad759bd8d2174df937bd'),
#  ObjectId('5b9aad759bd8d2174df937be'),
#  ObjectId('5b9aad759bd8d2174df937bf'),
#  ObjectId('5b9aad759bd8d2174df937c0'),
#  ObjectId('5b9aad759bd8d2174df937c1'),
#  ObjectId('5b9aad759bd8d2174df937c2'),
#  ObjectId('5b9aad759bd8d2174df937c3'),
#  ObjectId('5b9aad759bd8d2174df937c4'),
#  ObjectId('5b9aad759bd8d2174df937c5'),
#  ObjectId('5b9aad759bd8d2174df937c6'),
#  ObjectId('5b9aad759bd8d2174df937c7'),
#  ObjectId('5b9aad759bd8d2174df937c8'),
#  ObjectId('5b9aad759bd8d2174df937c9'),
#  ObjectId('5b9aad759bd8d2174df937ca'),
#  ObjectId('5b9aad759bd8d2174df937cb'),
#  ObjectId('5b9aad759bd8d2174df937cc'),
#  ObjectId('5b9aad759bd8d2174df937cd'),
#  ObjectId('5b9aad759bd8d2174df937ce'),
#  ObjectId('5b9aad759bd8d2174df937cf'),
#  ObjectId('5b9aad759bd8d2174df937d0'),
#  ObjectId('5b9aad759bd8d2174df937d1'),
#  ObjectId('5b9aad759bd8d2174df937d2'),
#  ObjectId('5b9aad759bd8d2174df937d3'),
#  ObjectId('5b9aad759bd8d2174df937d4'),
#  ObjectId('5b9aad759bd8d2174df937d5'),
#  ObjectId('5b9aad759bd8d2174df937d6'),
#  ObjectId('5b9aad759bd8d2174df937d7'),
#  ObjectId('5b9aad759bd8d2174df937d8'),
#  ObjectId('5b9aad759bd8d2174df937d9'),
#  ObjectId('5b9aad759bd8d2174df937da'),
#  ObjectId('5b9aad759bd8d2174df937db'),
#  ObjectId('5b9aad759bd8d2174df937dc'),
#  ObjectId('5b9aad759bd8d2174df937dd'),
#  ObjectId('5b9aad759bd8d2174df937de'),
#  ObjectId('5b9aad759bd8d2174df937df'),
#  ObjectId('5b9aad759bd8d2174df937e0'),
#  ObjectId('5b9aad759bd8d2174df937e1'),
#  ObjectId('5b9aad759bd8d2174df937e2'),
#  ObjectId('5b9aad759bd8d2174df937e3'),
#  ObjectId('5b9aad759bd8d2174df937e4'),
#  ObjectId('5b9aad759bd8d2174df937e5'),
#  ObjectId('5b9aad759bd8d2174df937e6'),
#  ObjectId('5b9aad759bd8d2174df937e7'),
#  ObjectId('5b9aad759bd8d2174df937e8'),
#  ObjectId('5b9aad759bd8d2174df937e9'),
#  ObjectId('5b9aad759bd8d2174df937ea'),
#  ObjectId('5b9aad759bd8d2174df937eb'),
#  ObjectId('5b9aad759bd8d2174df937ec'),
#  ObjectId('5b9aad759bd8d2174df937ed'),
#  ObjectId('5b9aad759bd8d2174df937ee'),
#  ObjectId('5b9aad759bd8d2174df937ef'),
#  ObjectId('5b9aad759bd8d2174df937f0'),
#  ObjectId('5b9aad759bd8d2174df937f1'),
#  ObjectId('5b9aad759bd8d2174df937f2'),
#  ObjectId('5b9aad759bd8d2174df937f3'),
#  ObjectId('5b9aad759bd8d2174df937f4'),
#  ObjectId('5b9aad759bd8d2174df937f5'),
#  ObjectId('5b9aad759bd8d2174df937f6'),
#  ObjectId('5b9aad759bd8d2174df937f7'),
#  ObjectId('5b9aad759bd8d2174df937f8'),
#  ObjectId('5b9aad759bd8d2174df937f9'),
#  ObjectId('5b9aad759bd8d2174df937fa'),
#  ObjectId('5b9aad759bd8d2174df937fb'),
#  ObjectId('5b9aad759bd8d2174df937fc'),
#  ObjectId('5b9aad759bd8d2174df937fd'),
#  ObjectId('5b9aad759bd8d2174df937fe'),
#  ObjectId('5b9aad759bd8d2174df937ff'),
#  ObjectId('5b9aad759bd8d2174df93800'),
#  ObjectId('5b9aad759bd8d2174df93801'),
#  ObjectId('5b9aad759bd8d2174df93802'),
#  ObjectId('5b9aad759bd8d2174df93803'),
#  ObjectId('5b9aad759bd8d2174df93804'),
#  ObjectId('5b9aad759bd8d2174df93805'),
#  ObjectId('5b9aad759bd8d2174df93806'),
#  ObjectId('5b9aad759bd8d2174df93807'),
#  ObjectId('5b9aad759bd8d2174df93808'),
#  ObjectId('5b9aad759bd8d2174df93809'),
#  ObjectId('5b9aad759bd8d2174df9380a'),
#  ObjectId('5b9aad759bd8d2174df9380b'),
#  ObjectId('5b9aad759bd8d2174df9380c'),
#  ObjectId('5b9aad759bd8d2174df9380d'),
#  ObjectId('5b9aad759bd8d2174df9380e'),
#  ObjectId('5b9aad759bd8d2174df9380f'),
#  ObjectId('5b9aad759bd8d2174df93810'),
#  ObjectId('5b9aad759bd8d2174df93811'),
#  ObjectId('5b9aad759bd8d2174df93812'),
#  ObjectId('5b9aad759bd8d2174df93813'),
#  ObjectId('5b9aad759bd8d2174df93814'),
#  ObjectId('5b9aad759bd8d2174df93815'),
#  ObjectId('5b9aad759bd8d2174df93816'),
#  ObjectId('5b9aad759bd8d2174df93817'),
#  ObjectId('5b9aad759bd8d2174df93818'),
#  ObjectId('5b9aad759bd8d2174df93819'),
#  ObjectId('5b9aad759bd8d2174df9381a'),
#  ObjectId('5b9aad759bd8d2174df9381b'),
#  ObjectId('5b9aad759bd8d2174df9381c'),
#  ObjectId('5b9aad759bd8d2174df9381d'),
#  ObjectId('5b9aad759bd8d2174df9381e'),
#  ObjectId('5b9aad759bd8d2174df9381f'),
#  ObjectId('5b9aad759bd8d2174df93820'),
#  ObjectId('5b9aad759bd8d2174df93821'),
#  ObjectId('5b9aad759bd8d2174df93822'),
#  ObjectId('5b9aad759bd8d2174df93823'),
#  ObjectId('5b9aad759bd8d2174df93824'),
#  ObjectId('5b9aad759bd8d2174df93825'),
#  ObjectId('5b9aad759bd8d2174df93826'),
#  ObjectId('5b9aad759bd8d2174df93827'),
#  ObjectId('5b9aad759bd8d2174df93828'),
#  ObjectId('5b9aad759bd8d2174df93829'),
#  ObjectId('5b9aad759bd8d2174df9382a'),
#  ObjectId('5b9aad759bd8d2174df9382b'),
#  ObjectId('5b9aad759bd8d2174df9382c'),
#  ObjectId('5b9aad759bd8d2174df9382d'),
#  ObjectId('5b9aad759bd8d2174df9382e'),
#  ObjectId('5b9aad759bd8d2174df9382f'),
#  ObjectId('5b9aad759bd8d2174df93830'),
#  ObjectId('5b9aad759bd8d2174df93831'),
#  ObjectId('5b9aad759bd8d2174df93832'),
#  ObjectId('5b9aad759bd8d2174df93833'),
#  ObjectId('5b9aad759bd8d2174df93834'),
#  ObjectId('5b9aad759bd8d2174df93835'),
#  ObjectId('5b9aad759bd8d2174df93836'),
#  ObjectId('5b9aad759bd8d2174df93837'),
#  ObjectId('5b9aad759bd8d2174df93838'),
#  ObjectId('5b9aad759bd8d2174df93839'),
#  ObjectId('5b9aad759bd8d2174df9383a'),
#  ObjectId('5b9aad759bd8d2174df9383b'),
#  ObjectId('5b9aad759bd8d2174df9383c'),
#  ObjectId('5b9aad759bd8d2174df9383d'),
#  ObjectId('5b9aad759bd8d2174df9383e'),
#  ObjectId('5b9aad759bd8d2174df9383f'),
#  ObjectId('5b9aad759bd8d2174df93840'),
#  ObjectId('5b9aad759bd8d2174df93841'),
#  ObjectId('5b9aad759bd8d2174df93842'),
#  ObjectId('5b9aad759bd8d2174df93843'),
#  ObjectId('5b9aad759bd8d2174df93844'),
#  ObjectId('5b9aad759bd8d2174df93845'),
#  ObjectId('5b9aad759bd8d2174df93846'),
#  ObjectId('5b9aad759bd8d2174df93847'),
#  ObjectId('5b9aad759bd8d2174df93848'),
#  ObjectId('5b9aad759bd8d2174df93849'),
#  ObjectId('5b9aad759bd8d2174df9384a'),
#  ObjectId('5b9aad759bd8d2174df9384b'),
#  ObjectId('5b9aad759bd8d2174df9384c'),
#  ObjectId('5b9aad759bd8d2174df9384d'),
#  ObjectId('5b9aad759bd8d2174df9384e'),
#  ObjectId('5b9aad759bd8d2174df9384f'),
#  ObjectId('5b9aad759bd8d2174df93850'),
#  ObjectId('5b9aad759bd8d2174df93851'),
#  ObjectId('5b9aad759bd8d2174df93852'),
#  ObjectId('5b9aad759bd8d2174df93853'),
#  ObjectId('5b9aad759bd8d2174df93854'),
#  ObjectId('5b9aad759bd8d2174df93855'),
#  ObjectId('5b9aad759bd8d2174df93856'),
#  ObjectId('5b9aad759bd8d2174df93857'),
#  ObjectId('5b9aad759bd8d2174df93858'),
#  ObjectId('5b9aad759bd8d2174df93859'),
#  ObjectId('5b9aad759bd8d2174df9385a'),
#  ObjectId('5b9aad759bd8d2174df9385b'),
#  ObjectId('5b9aad759bd8d2174df9385c'),
#  ObjectId('5b9aad759bd8d2174df9385d'),
#  ObjectId('5b9aad759bd8d2174df9385e'),
#  ObjectId('5b9aad759bd8d2174df9385f'),
#  ObjectId('5b9aad759bd8d2174df93860'),
#  ObjectId('5b9aad759bd8d2174df93861'),
#  ObjectId('5b9aad759bd8d2174df93862'),
#  ObjectId('5b9aad759bd8d2174df93863'),
#  ObjectId('5b9aad759bd8d2174df93864'),
#  ObjectId('5b9aad759bd8d2174df93865'),
#  ObjectId('5b9aad759bd8d2174df93866'),
#  ObjectId('5b9aad759bd8d2174df93867'),
#  ObjectId('5b9aad759bd8d2174df93868'),
#  ObjectId('5b9aad759bd8d2174df93869'),
#  ObjectId('5b9aad759bd8d2174df9386a'),
#  ObjectId('5b9aad759bd8d2174df9386b'),
#  ObjectId('5b9aad759bd8d2174df9386c'),
#  ObjectId('5b9aad759bd8d2174df9386d'),
#  ObjectId('5b9aad759bd8d2174df9386e'),
#  ObjectId('5b9aad759bd8d2174df9386f'),
#  ObjectId('5b9aad759bd8d2174df93870'),
#  ObjectId('5b9aad759bd8d2174df93871'),
#  ObjectId('5b9aad759bd8d2174df93872'),
#  ObjectId('5b9aad759bd8d2174df93873'),
#  ObjectId('5b9aad759bd8d2174df93874'),
#  ObjectId('5b9aad759bd8d2174df93875'),
#  ObjectId('5b9aad759bd8d2174df93876'),
#  ObjectId('5b9aad759bd8d2174df93877'),
#  ObjectId('5b9aad759bd8d2174df93878'),
#  ObjectId('5b9aad759bd8d2174df93879'),
#  ObjectId('5b9aad759bd8d2174df9387a'),
#  ObjectId('5b9aad759bd8d2174df9387b'),
#  ObjectId('5b9aad759bd8d2174df9387c'),
#  ObjectId('5b9aad759bd8d2174df9387d'),
#  ObjectId('5b9aad759bd8d2174df9387e'),
#  ObjectId('5b9aad759bd8d2174df9387f'),
#  ObjectId('5b9aad759bd8d2174df93880'),
#  ObjectId('5b9aad759bd8d2174df93881'),
#  ObjectId('5b9aad759bd8d2174df93882'),
#  ObjectId('5b9aad759bd8d2174df93883'),
#  ObjectId('5b9aad759bd8d2174df93884'),
#  ObjectId('5b9aad759bd8d2174df93885'),
#  ObjectId('5b9aad759bd8d2174df93886'),
#  ObjectId('5b9aad759bd8d2174df93887'),
#  ObjectId('5b9aad759bd8d2174df93888'),
#  ObjectId('5b9aad759bd8d2174df93889'),
#  ObjectId('5b9aad759bd8d2174df9388a'),
#  ObjectId('5b9aad759bd8d2174df9388b'),
#  ObjectId('5b9aad759bd8d2174df9388c'),
#  ObjectId('5b9aad759bd8d2174df9388d'),
#  ObjectId('5b9aad759bd8d2174df9388e'),
#  ObjectId('5b9aad759bd8d2174df9388f'),
#  ObjectId('5b9aad759bd8d2174df93890'),
#  ObjectId('5b9aad759bd8d2174df93891'),
#  ObjectId('5b9aad759bd8d2174df93892'),
#  ObjectId('5b9aad759bd8d2174df93893'),
#  ObjectId('5b9aad759bd8d2174df93894'),
#  ObjectId('5b9aad759bd8d2174df93895'),
#  ObjectId('5b9aad759bd8d2174df93896'),
#  ObjectId('5b9aad759bd8d2174df93897'),
#  ObjectId('5b9aad759bd8d2174df93898'),
#  ObjectId('5b9aad759bd8d2174df93899'),
#  ObjectId('5b9aad759bd8d2174df9389a'),
#  ObjectId('5b9aad759bd8d2174df9389b'),
#  ObjectId('5b9aad759bd8d2174df9389c'),
#  ObjectId('5b9aad759bd8d2174df9389d'),
#  ObjectId('5b9aad759bd8d2174df9389e'),
#  ObjectId('5b9aad759bd8d2174df9389f'),
#  ObjectId('5b9aad759bd8d2174df938a0'),
#  ObjectId('5b9aad759bd8d2174df938a1'),
#  ObjectId('5b9aad759bd8d2174df938a2'),
#  ObjectId('5b9aad759bd8d2174df938a3'),
#  ObjectId('5b9aad759bd8d2174df938a4'),
#  ObjectId('5b9aad759bd8d2174df938a5'),
#  ObjectId('5b9aad759bd8d2174df938a6'),
#  ObjectId('5b9aad759bd8d2174df938a7'),
#  ObjectId('5b9aad759bd8d2174df938a8'),
#  ObjectId('5b9aad759bd8d2174df938a9'),
#  ObjectId('5b9aad759bd8d2174df938aa'),
#  ObjectId('5b9aad759bd8d2174df938ab'),
#  ObjectId('5b9aad759bd8d2174df938ac'),
#  ObjectId('5b9aad759bd8d2174df938ad'),
#  ObjectId('5b9aad759bd8d2174df938ae'),
#  ObjectId('5b9aad759bd8d2174df938af'),
#  ObjectId('5b9aad759bd8d2174df938b0'),
#  ObjectId('5b9aad759bd8d2174df938b1'),
#  ObjectId('5b9aad759bd8d2174df938b2'),
#  ObjectId('5b9aad759bd8d2174df938b3'),
#  ObjectId('5b9aad759bd8d2174df938b4'),
#  ObjectId('5b9aad759bd8d2174df938b5'),
#  ObjectId('5b9aad759bd8d2174df938b6'),
#  ObjectId('5b9aad759bd8d2174df938b7'),
#  ObjectId('5b9aad759bd8d2174df938b8'),
#  ObjectId('5b9aad759bd8d2174df938b9'),
#  ObjectId('5b9aad759bd8d2174df938ba'),
#  ObjectId('5b9aad759bd8d2174df938bb'),
#  ObjectId('5b9aad759bd8d2174df938bc'),
#  ObjectId('5b9aad759bd8d2174df938bd'),
#  ObjectId('5b9aad759bd8d2174df938be'),
#  ObjectId('5b9aad759bd8d2174df938bf'),
#  ObjectId('5b9aad759bd8d2174df938c0'),
#  ObjectId('5b9aad759bd8d2174df938c1'),
#  ObjectId('5b9aad759bd8d2174df938c2'),
#  ObjectId('5b9aad759bd8d2174df938c3'),
#  ObjectId('5b9aad759bd8d2174df938c4'),
#  ObjectId('5b9aad759bd8d2174df938c5'),
#  ObjectId('5b9aad759bd8d2174df938c6'),
#  ObjectId('5b9aad759bd8d2174df938c7'),
#  ObjectId('5b9aad759bd8d2174df938c8'),
#  ObjectId('5b9aad759bd8d2174df938c9'),
#  ObjectId('5b9aad759bd8d2174df938ca'),
#  ObjectId('5b9aad759bd8d2174df938cb'),
#  ObjectId('5b9aad759bd8d2174df938cc'),
#  ObjectId('5b9aad759bd8d2174df938cd'),
#  ObjectId('5b9aad759bd8d2174df938ce'),
#  ObjectId('5b9aad759bd8d2174df938cf'),
#  ObjectId('5b9aad759bd8d2174df938d0'),
#  ObjectId('5b9aad759bd8d2174df938d1'),
#  ObjectId('5b9aad759bd8d2174df938d2'),
#  ObjectId('5b9aad759bd8d2174df938d3'),
#  ObjectId('5b9aad759bd8d2174df938d4'),
#  ObjectId('5b9aad759bd8d2174df938d5'),
#  ObjectId('5b9aad759bd8d2174df938d6'),
#  ObjectId('5b9aad759bd8d2174df938d7'),
#  ObjectId('5b9aad759bd8d2174df938d8'),
#  ObjectId('5b9aad759bd8d2174df938d9'),
#  ObjectId('5b9aad759bd8d2174df938da'),
#  ObjectId('5b9aad759bd8d2174df938db'),
#  ObjectId('5b9aad759bd8d2174df938dc'),
#  ObjectId('5b9aad759bd8d2174df938dd'),
#  ObjectId('5b9aad759bd8d2174df938de'),
#  ObjectId('5b9aad759bd8d2174df938df'),
#  ObjectId('5b9aad759bd8d2174df938e0'),
#  ObjectId('5b9aad759bd8d2174df938e1'),
#  ObjectId('5b9aad759bd8d2174df938e2'),
#  ObjectId('5b9aad759bd8d2174df938e3'),
#  ObjectId('5b9aad759bd8d2174df938e4'),
#  ObjectId('5b9aad759bd8d2174df938e5'),
#  ObjectId('5b9aad759bd8d2174df938e6'),
#  ObjectId('5b9aad759bd8d2174df938e7'),
#  ObjectId('5b9aad759bd8d2174df938e8'),
#  ObjectId('5b9aad759bd8d2174df938e9'),
#  ObjectId('5b9aad759bd8d2174df938ea'),
#  ObjectId('5b9aad759bd8d2174df938eb'),
#  ObjectId('5b9aad759bd8d2174df938ec'),
#  ObjectId('5b9aad759bd8d2174df938ed'),
#  ObjectId('5b9aad759bd8d2174df938ee'),
#  ObjectId('5b9aad759bd8d2174df938ef'),
#  ObjectId('5b9aad759bd8d2174df938f0'),
#  ObjectId('5b9aad759bd8d2174df938f1'),
#  ObjectId('5b9aad759bd8d2174df938f2'),
#  ObjectId('5b9aad759bd8d2174df938f3'),
#  ObjectId('5b9aad759bd8d2174df938f4'),
#  ObjectId('5b9aad759bd8d2174df938f5'),
#  ObjectId('5b9aad759bd8d2174df938f6'),
#  ObjectId('5b9aad759bd8d2174df938f7'),
#  ObjectId('5b9aad759bd8d2174df938f8'),
#  ObjectId('5b9aad759bd8d2174df938f9'),
#  ObjectId('5b9aad759bd8d2174df938fa'),
#  ObjectId('5b9aad759bd8d2174df938fb'),
#  ObjectId('5b9aad759bd8d2174df938fc'),
#  ObjectId('5b9aad759bd8d2174df938fd'),
#  ObjectId('5b9aad759bd8d2174df938fe'),
#  ObjectId('5b9aad759bd8d2174df938ff'),
#  ObjectId('5b9aad759bd8d2174df93900'),
#  ObjectId('5b9aad759bd8d2174df93901'),
#  ObjectId('5b9aad759bd8d2174df93902'),
#  ObjectId('5b9aad759bd8d2174df93903'),
#  ObjectId('5b9aad759bd8d2174df93904'),
#  ObjectId('5b9aad759bd8d2174df93905'),
#  ObjectId('5b9aad759bd8d2174df93906'),
#  ObjectId('5b9aad759bd8d2174df93907'),
#  ObjectId('5b9aad759bd8d2174df93908'),
#  ObjectId('5b9aad759bd8d2174df93909'),
#  ObjectId('5b9aad759bd8d2174df9390a'),
#  ObjectId('5b9aad759bd8d2174df9390b'),
#  ObjectId('5b9aad759bd8d2174df9390c'),
#  ObjectId('5b9aad759bd8d2174df9390d'),
#  ObjectId('5b9aad759bd8d2174df9390e'),
#  ObjectId('5b9aad759bd8d2174df9390f'),
#  ObjectId('5b9aad759bd8d2174df93910'),
#  ObjectId('5b9aad759bd8d2174df93911'),
#  ObjectId('5b9aad759bd8d2174df93912'),
#  ObjectId('5b9aad759bd8d2174df93913'),
#  ObjectId('5b9aad759bd8d2174df93914'),
#  ObjectId('5b9aad759bd8d2174df93915'),
#  ObjectId('5b9aad759bd8d2174df93916'),
#  ObjectId('5b9aad759bd8d2174df93917'),
#  ObjectId('5b9aad759bd8d2174df93918'),
#  ObjectId('5b9aad759bd8d2174df93919'),
#  ObjectId('5b9aad759bd8d2174df9391a'),
#  ObjectId('5b9aad759bd8d2174df9391b'),
#  ObjectId('5b9aad759bd8d2174df9391c'),
#  ObjectId('5b9aad759bd8d2174df9391d'),
#  ObjectId('5b9aad759bd8d2174df9391e'),
#  ObjectId('5b9aad759bd8d2174df9391f'),
#  ObjectId('5b9aad759bd8d2174df93920'),
#  ObjectId('5b9aad759bd8d2174df93921'),
#  ObjectId('5b9aad759bd8d2174df93922'),
#  ObjectId('5b9aad759bd8d2174df93923'),
#  ObjectId('5b9aad759bd8d2174df93924'),
#  ObjectId('5b9aad759bd8d2174df93925'),
#  ObjectId('5b9aad759bd8d2174df93926'),
#  ObjectId('5b9aad759bd8d2174df93927'),
#  ObjectId('5b9aad759bd8d2174df93928'),
#  ObjectId('5b9aad759bd8d2174df93929'),
#  ObjectId('5b9aad759bd8d2174df9392a'),
#  ObjectId('5b9aad759bd8d2174df9392b'),
#  ObjectId('5b9aad759bd8d2174df9392c'),
#  ObjectId('5b9aad759bd8d2174df9392d'),
#  ObjectId('5b9aad759bd8d2174df9392e'),
#  ObjectId('5b9aad759bd8d2174df9392f'),
#  ObjectId('5b9aad759bd8d2174df93930'),
#  ObjectId('5b9aad759bd8d2174df93931'),
#  ObjectId('5b9aad759bd8d2174df93932'),
#  ObjectId('5b9aad759bd8d2174df93933'),
#  ObjectId('5b9aad759bd8d2174df93934'),
#  ObjectId('5b9aad759bd8d2174df93935'),
#  ObjectId('5b9aad759bd8d2174df93936'),
#  ObjectId('5b9aad759bd8d2174df93937'),
#  ObjectId('5b9aad759bd8d2174df93938'),
#  ObjectId('5b9aad759bd8d2174df93939'),
#  ObjectId('5b9aad759bd8d2174df9393a'),
#  ObjectId('5b9aad759bd8d2174df9393b'),
#  ObjectId('5b9aad759bd8d2174df9393c'),
#  ObjectId('5b9aad759bd8d2174df9393d'),
#  ObjectId('5b9aad759bd8d2174df9393e'),
#  ObjectId('5b9aad759bd8d2174df9393f'),
#  ObjectId('5b9aad759bd8d2174df93940'),
#  ObjectId('5b9aad759bd8d2174df93941'),
#  ObjectId('5b9aad759bd8d2174df93942'),
#  ObjectId('5b9aad759bd8d2174df93943'),
#  ObjectId('5b9aad759bd8d2174df93944'),
#  ObjectId('5b9aad759bd8d2174df93945'),
#  ObjectId('5b9aad759bd8d2174df93946'),
#  ObjectId('5b9aad759bd8d2174df93947'),
#  ObjectId('5b9aad759bd8d2174df93948'),
#  ObjectId('5b9aad759bd8d2174df93949'),
#  ObjectId('5b9aad759bd8d2174df9394a'),
#  ObjectId('5b9aad759bd8d2174df9394b'),
#  ObjectId('5b9aad759bd8d2174df9394c'),
#  ObjectId('5b9aad759bd8d2174df9394d'),
#  ObjectId('5b9aad759bd8d2174df9394e'),
#  ObjectId('5b9aad759bd8d2174df9394f'),
#  ObjectId('5b9aad759bd8d2174df93950'),
#  ObjectId('5b9aad759bd8d2174df93951'),
#  ObjectId('5b9aad759bd8d2174df93952'),
#  ObjectId('5b9aad759bd8d2174df93953'),
#  ObjectId('5b9aad759bd8d2174df93954'),
#  ObjectId('5b9aad759bd8d2174df93955'),
#  ObjectId('5b9aad759bd8d2174df93956'),
#  ObjectId('5b9aad759bd8d2174df93957'),
#  ObjectId('5b9aad759bd8d2174df93958'),
#  ObjectId('5b9aad759bd8d2174df93959'),
#  ObjectId('5b9aad759bd8d2174df9395a'),
#  ObjectId('5b9aad759bd8d2174df9395b'),
#  ObjectId('5b9aad759bd8d2174df9395c'),
#  ObjectId('5b9aad759bd8d2174df9395d'),
#  ObjectId('5b9aad759bd8d2174df9395e'),
#  ObjectId('5b9aad759bd8d2174df9395f'),
#  ObjectId('5b9aad759bd8d2174df93960'),
#  ObjectId('5b9aad759bd8d2174df93961'),
#  ObjectId('5b9aad759bd8d2174df93962'),
#  ObjectId('5b9aad759bd8d2174df93963'),
#  ObjectId('5b9aad759bd8d2174df93964'),
#  ObjectId('5b9aad759bd8d2174df93965'),
#  ObjectId('5b9aad759bd8d2174df93966'),
#  ObjectId('5b9aad759bd8d2174df93967'),
#  ObjectId('5b9aad759bd8d2174df93968'),
#  ObjectId('5b9aad759bd8d2174df93969'),
#  ObjectId('5b9aad759bd8d2174df9396a'),
#  ObjectId('5b9aad759bd8d2174df9396b'),
#  ObjectId('5b9aad759bd8d2174df9396c'),
#  ObjectId('5b9aad759bd8d2174df9396d'),
#  ObjectId('5b9aad759bd8d2174df9396e'),
#  ObjectId('5b9aad759bd8d2174df9396f'),
#  ObjectId('5b9aad759bd8d2174df93970'),
#  ObjectId('5b9aad759bd8d2174df93971'),
#  ObjectId('5b9aad759bd8d2174df93972'),
#  ObjectId('5b9aad759bd8d2174df93973'),
#  ObjectId('5b9aad759bd8d2174df93974'),
#  ObjectId('5b9aad759bd8d2174df93975'),
#  ObjectId('5b9aad759bd8d2174df93976'),
#  ObjectId('5b9aad759bd8d2174df93977'),
#  ObjectId('5b9aad759bd8d2174df93978'),
#  ObjectId('5b9aad759bd8d2174df93979'),
#  ObjectId('5b9aad759bd8d2174df9397a'),
#  ObjectId('5b9aad759bd8d2174df9397b'),
#  ObjectId('5b9aad759bd8d2174df9397c'),
#  ObjectId('5b9aad759bd8d2174df9397d'),
#  ObjectId('5b9aad759bd8d2174df9397e'),
#  ObjectId('5b9aad759bd8d2174df9397f'),
#  ObjectId('5b9aad759bd8d2174df93980'),
#  ObjectId('5b9aad759bd8d2174df93981'),
#  ObjectId('5b9aad759bd8d2174df93982'),
#  ObjectId('5b9aad759bd8d2174df93983'),
#  ObjectId('5b9aad759bd8d2174df93984'),
#  ObjectId('5b9aad759bd8d2174df93985'),
#  ObjectId('5b9aad759bd8d2174df93986'),
#  ObjectId('5b9aad759bd8d2174df93987'),
#  ObjectId('5b9aad759bd8d2174df93988'),
#  ObjectId('5b9aad759bd8d2174df93989'),
#  ObjectId('5b9aad759bd8d2174df9398a'),
#  ObjectId('5b9aad759bd8d2174df9398b'),
#  ObjectId('5b9aad759bd8d2174df9398c'),
#  ObjectId('5b9aad759bd8d2174df9398d'),
#  ObjectId('5b9aad759bd8d2174df9398e'),
#  ObjectId('5b9aad759bd8d2174df9398f'),
#  ObjectId('5b9aad759bd8d2174df93990'),
#  ObjectId('5b9aad759bd8d2174df93991'),
#  ObjectId('5b9aad759bd8d2174df93992'),
#  ObjectId('5b9aad759bd8d2174df93993'),
#  ObjectId('5b9aad759bd8d2174df93994'),
#  ObjectId('5b9aad759bd8d2174df93995'),
#  ObjectId('5b9aad759bd8d2174df93996'),
#  ObjectId('5b9aad759bd8d2174df93997'),
#  ObjectId('5b9aad759bd8d2174df93998'),
#  ObjectId('5b9aad759bd8d2174df93999'),
#  ObjectId('5b9aad759bd8d2174df9399a'),
#  ObjectId('5b9aad759bd8d2174df9399b'),
#  ObjectId('5b9aad759bd8d2174df9399c'),
#  ObjectId('5b9aad759bd8d2174df9399d'),
#  ObjectId('5b9aad759bd8d2174df9399e'),
#  ObjectId('5b9aad759bd8d2174df9399f'),
#  ObjectId('5b9aad759bd8d2174df939a0'),
#  ObjectId('5b9aad759bd8d2174df939a1'),
#  ObjectId('5b9aad759bd8d2174df939a2'),
#  ObjectId('5b9aad759bd8d2174df939a3'),
#  ObjectId('5b9aad759bd8d2174df939a4'),
#  ObjectId('5b9aad759bd8d2174df939a5'),
#  ObjectId('5b9aad759bd8d2174df939a6'),
#  ObjectId('5b9aad759bd8d2174df939a7'),
#  ObjectId('5b9aad759bd8d2174df939a8'),
#  ObjectId('5b9aad759bd8d2174df939a9'),
#  ObjectId('5b9aad759bd8d2174df939aa'),
#  ObjectId('5b9aad759bd8d2174df939ab'),
#  ObjectId('5b9aad759bd8d2174df939ac'),
#  ObjectId('5b9aad759bd8d2174df939ad'),
#  ObjectId('5b9aad759bd8d2174df939ae'),
#  ObjectId('5b9aad759bd8d2174df939af'),
#  ObjectId('5b9aad759bd8d2174df939b0'),
#  ObjectId('5b9aad759bd8d2174df939b1'),
#  ObjectId('5b9aad759bd8d2174df939b2'),
#  ObjectId('5b9aad759bd8d2174df939b3'),
#  ObjectId('5b9aad759bd8d2174df939b4'),
#  ObjectId('5b9aad759bd8d2174df939b5'),
#  ObjectId('5b9aad759bd8d2174df939b6'),
#  ObjectId('5b9aad759bd8d2174df939b7'),
#  ObjectId('5b9aad759bd8d2174df939b8'),
#  ObjectId('5b9aad759bd8d2174df939b9'),
#  ObjectId('5b9aad759bd8d2174df939ba'),
#  ObjectId('5b9aad759bd8d2174df939bb'),
#  ObjectId('5b9aad759bd8d2174df939bc'),
#  ObjectId('5b9aad759bd8d2174df939bd'),
#  ObjectId('5b9aad759bd8d2174df939be'),
#  ObjectId('5b9aad759bd8d2174df939bf'),
#  ObjectId('5b9aad759bd8d2174df939c0'),
#  ObjectId('5b9aad759bd8d2174df939c1'),
#  ObjectId('5b9aad759bd8d2174df939c2'),
#  ObjectId('5b9aad759bd8d2174df939c3'),
#  ObjectId('5b9aad759bd8d2174df939c4'),
#  ObjectId('5b9aad759bd8d2174df939c5'),
#  ObjectId('5b9aad759bd8d2174df939c6'),
#  ObjectId('5b9aad759bd8d2174df939c7'),
#  ObjectId('5b9aad759bd8d2174df939c8'),
#  ObjectId('5b9aad759bd8d2174df939c9'),
#  ObjectId('5b9aad759bd8d2174df939ca'),
#  ObjectId('5b9aad759bd8d2174df939cb'),
#  ObjectId('5b9aad759bd8d2174df939cc'),
#  ObjectId('5b9aad759bd8d2174df939cd'),
#  ObjectId('5b9aad759bd8d2174df939ce'),
#  ObjectId('5b9aad759bd8d2174df939cf'),
#  ObjectId('5b9aad759bd8d2174df939d0'),
#  ObjectId('5b9aad759bd8d2174df939d1'),
#  ObjectId('5b9aad759bd8d2174df939d2'),
#  ObjectId('5b9aad759bd8d2174df939d3'),
#  ObjectId('5b9aad759bd8d2174df939d4'),
#  ObjectId('5b9aad759bd8d2174df939d5'),
#  ObjectId('5b9aad759bd8d2174df939d6'),
#  ObjectId('5b9aad759bd8d2174df939d7'),
#  ObjectId('5b9aad759bd8d2174df939d8'),
#  ObjectId('5b9aad759bd8d2174df939d9'),
#  ObjectId('5b9aad759bd8d2174df939da'),
#  ObjectId('5b9aad759bd8d2174df939db'),
#  ObjectId('5b9aad759bd8d2174df939dc'),
#  ObjectId('5b9aad759bd8d2174df939dd'),
#  ObjectId('5b9aad759bd8d2174df939de'),
#  ObjectId('5b9aad759bd8d2174df939df'),
#  ObjectId('5b9aad759bd8d2174df939e0'),
#  ObjectId('5b9aad759bd8d2174df939e1'),
#  ObjectId('5b9aad759bd8d2174df939e2'),
#  ObjectId('5b9aad759bd8d2174df939e3'),
#  ObjectId('5b9aad759bd8d2174df939e4'),
#  ObjectId('5b9aad759bd8d2174df939e5'),
#  ObjectId('5b9aad759bd8d2174df939e6'),
#  ObjectId('5b9aad759bd8d2174df939e7'),
#  ObjectId('5b9aad759bd8d2174df939e8'),
#  ObjectId('5b9aad759bd8d2174df939e9'),
#  ObjectId('5b9aad759bd8d2174df939ea'),
#  ObjectId('5b9aad759bd8d2174df939eb'),
#  ObjectId('5b9aad759bd8d2174df939ec'),
#  ObjectId('5b9aad759bd8d2174df939ed'),
#  ObjectId('5b9aad759bd8d2174df939ee'),
#  ObjectId('5b9aad759bd8d2174df939ef'),
#  ObjectId('5b9aad759bd8d2174df939f0'),
#  ObjectId('5b9aad759bd8d2174df939f1'),
#  ObjectId('5b9aad759bd8d2174df939f2'),
#  ObjectId('5b9aad759bd8d2174df939f3'),
#  ObjectId('5b9aad759bd8d2174df939f4'),
#  ObjectId('5b9aad759bd8d2174df939f5'),
#  ObjectId('5b9aad759bd8d2174df939f6'),
#  ObjectId('5b9aad759bd8d2174df939f7'),
#  ObjectId('5b9aad759bd8d2174df939f8'),
#  ObjectId('5b9aad759bd8d2174df939f9'),
#  ObjectId('5b9aad759bd8d2174df939fa'),
#  ObjectId('5b9aad759bd8d2174df939fb'),
#  ObjectId('5b9aad759bd8d2174df939fc'),
#  ObjectId('5b9aad759bd8d2174df939fd'),
#  ObjectId('5b9aad759bd8d2174df939fe'),
#  ObjectId('5b9aad759bd8d2174df939ff'),
#  ObjectId('5b9aad759bd8d2174df93a00'),
#  ObjectId('5b9aad759bd8d2174df93a01'),
#  ObjectId('5b9aad759bd8d2174df93a02'),
#  ObjectId('5b9aad759bd8d2174df93a03'),
#  ObjectId('5b9aad759bd8d2174df93a04'),
#  ObjectId('5b9aad759bd8d2174df93a05'),
#  ObjectId('5b9aad759bd8d2174df93a06'),
#  ObjectId('5b9aad759bd8d2174df93a07'),
#  ObjectId('5b9aad759bd8d2174df93a08'),
#  ObjectId('5b9aad759bd8d2174df93a09'),
#  ObjectId('5b9aad759bd8d2174df93a0a'),
#  ObjectId('5b9aad759bd8d2174df93a0b'),
#  ObjectId('5b9aad759bd8d2174df93a0c'),
#  ObjectId('5b9aad759bd8d2174df93a0d'),
#  ObjectId('5b9aad759bd8d2174df93a0e'),
#  ObjectId('5b9aad759bd8d2174df93a0f'),
#  ObjectId('5b9aad759bd8d2174df93a10'),
#  ObjectId('5b9aad759bd8d2174df93a11'),
#  ObjectId('5b9aad759bd8d2174df93a12'),
#  ObjectId('5b9aad759bd8d2174df93a13'),
#  ObjectId('5b9aad759bd8d2174df93a14'),
#  ObjectId('5b9aad759bd8d2174df93a15'),
#  ObjectId('5b9aad759bd8d2174df93a16'),
#  ObjectId('5b9aad759bd8d2174df93a17'),
#  ObjectId('5b9aad759bd8d2174df93a18'),
#  ObjectId('5b9aad759bd8d2174df93a19'),
#  ObjectId('5b9aad759bd8d2174df93a1a'),
#  ObjectId('5b9aad759bd8d2174df93a1b'),
#  ObjectId('5b9aad759bd8d2174df93a1c'),
#  ObjectId('5b9aad759bd8d2174df93a1d'),
#  ObjectId('5b9aad759bd8d2174df93a1e'),
#  ObjectId('5b9aad759bd8d2174df93a1f'),
#  ObjectId('5b9aad759bd8d2174df93a20'),
#  ObjectId('5b9aad759bd8d2174df93a21'),
#  ObjectId('5b9aad759bd8d2174df93a22'),
#  ObjectId('5b9aad759bd8d2174df93a23'),
#  ObjectId('5b9aad759bd8d2174df93a24'),
#  ObjectId('5b9aad759bd8d2174df93a25'),
#  ObjectId('5b9aad759bd8d2174df93a26'),
#  ObjectId('5b9aad759bd8d2174df93a27'),
#  ObjectId('5b9aad759bd8d2174df93a28'),
#  ObjectId('5b9aad759bd8d2174df93a29'),
#  ObjectId('5b9aad759bd8d2174df93a2a'),
#  ObjectId('5b9aad759bd8d2174df93a2b'),
#  ObjectId('5b9aad759bd8d2174df93a2c'),
#  ObjectId('5b9aad759bd8d2174df93a2d'),
#  ObjectId('5b9aad759bd8d2174df93a2e'),
#  ObjectId('5b9aad759bd8d2174df93a2f'),
#  ObjectId('5b9aad759bd8d2174df93a30'),
#  ObjectId('5b9aad759bd8d2174df93a31'),
#  ObjectId('5b9aad759bd8d2174df93a32'),
#  ObjectId('5b9aad759bd8d2174df93a33'),
#  ObjectId('5b9aad759bd8d2174df93a34'),
#  ObjectId('5b9aad759bd8d2174df93a35'),
#  ObjectId('5b9aad759bd8d2174df93a36'),
#  ObjectId('5b9aad759bd8d2174df93a37'),
#  ObjectId('5b9aad759bd8d2174df93a38'),
#  ObjectId('5b9aad759bd8d2174df93a39'),
#  ObjectId('5b9aad759bd8d2174df93a3a'),
#  ObjectId('5b9aad759bd8d2174df93a3b'),
#  ObjectId('5b9aad759bd8d2174df93a3c'),
#  ObjectId('5b9aad759bd8d2174df93a3d'),
#  ObjectId('5b9aad759bd8d2174df93a3e'),
#  ObjectId('5b9aad759bd8d2174df93a3f'),
#  ObjectId('5b9aad759bd8d2174df93a40'),
#  ObjectId('5b9aad759bd8d2174df93a41'),
#  ObjectId('5b9aad759bd8d2174df93a42'),
#  ObjectId('5b9aad759bd8d2174df93a43'),
#  ObjectId('5b9aad759bd8d2174df93a44'),
#  ObjectId('5b9aad759bd8d2174df93a45'),
#  ObjectId('5b9aad759bd8d2174df93a46'),
#  ObjectId('5b9aad759bd8d2174df93a47'),
#  ObjectId('5b9aad759bd8d2174df93a48'),
#  ObjectId('5b9aad759bd8d2174df93a49'),
#  ObjectId('5b9aad759bd8d2174df93a4a'),
#  ObjectId('5b9aad759bd8d2174df93a4b'),
#  ObjectId('5b9aad759bd8d2174df93a4c'),
#  ObjectId('5b9aad759bd8d2174df93a4d'),
#  ObjectId('5b9aad759bd8d2174df93a4e'),
#  ObjectId('5b9aad759bd8d2174df93a4f'),
#  ObjectId('5b9aad759bd8d2174df93a50'),
#  ObjectId('5b9aad759bd8d2174df93a51'),
#  ObjectId('5b9aad759bd8d2174df93a52'),
#  ObjectId('5b9aad759bd8d2174df93a53'),
#  ObjectId('5b9aad759bd8d2174df93a54'),
#  ObjectId('5b9aad759bd8d2174df93a55'),
#  ObjectId('5b9aad759bd8d2174df93a56'),
#  ObjectId('5b9aad759bd8d2174df93a57'),
#  ObjectId('5b9aad759bd8d2174df93a58'),
#  ObjectId('5b9aad759bd8d2174df93a59'),
#  ObjectId('5b9aad759bd8d2174df93a5a'),
#  ObjectId('5b9aad759bd8d2174df93a5b'),
#  ObjectId('5b9aad759bd8d2174df93a5c'),
#  ObjectId('5b9aad759bd8d2174df93a5d'),
#  ObjectId('5b9aad759bd8d2174df93a5e'),
#  ObjectId('5b9aad759bd8d2174df93a5f'),
#  ObjectId('5b9aad759bd8d2174df93a60'),
#  ObjectId('5b9aad759bd8d2174df93a61'),
#  ObjectId('5b9aad759bd8d2174df93a62'),
#  ObjectId('5b9aad759bd8d2174df93a63'),
#  ObjectId('5b9aad759bd8d2174df93a64'),
#  ObjectId('5b9aad759bd8d2174df93a65'),
#  ObjectId('5b9aad759bd8d2174df93a66'),
#  ObjectId('5b9aad759bd8d2174df93a67'),
#  ObjectId('5b9aad759bd8d2174df93a68'),
#  ObjectId('5b9aad759bd8d2174df93a69'),
#  ObjectId('5b9aad759bd8d2174df93a6a'),
#  ObjectId('5b9aad759bd8d2174df93a6b'),
#  ObjectId('5b9aad759bd8d2174df93a6c'),
#  ObjectId('5b9aad759bd8d2174df93a6d'),
#  ObjectId('5b9aad759bd8d2174df93a6e'),
#  ObjectId('5b9aad759bd8d2174df93a6f'),
#  ObjectId('5b9aad759bd8d2174df93a70'),
#  ObjectId('5b9aad759bd8d2174df93a71'),
#  ObjectId('5b9aad759bd8d2174df93a72'),
#  ObjectId('5b9aad759bd8d2174df93a73'),
#  ObjectId('5b9aad759bd8d2174df93a74'),
#  ObjectId('5b9aad759bd8d2174df93a75'),
#  ObjectId('5b9aad759bd8d2174df93a76'),
#  ObjectId('5b9aad759bd8d2174df93a77'),
#  ObjectId('5b9aad759bd8d2174df93a78'),
#  ObjectId('5b9aad759bd8d2174df93a79'),
#  ObjectId('5b9aad759bd8d2174df93a7a'),
#  ObjectId('5b9aad759bd8d2174df93a7b'),
#  ObjectId('5b9aad759bd8d2174df93a7c'),
#  ObjectId('5b9aad759bd8d2174df93a7d'),
#  ObjectId('5b9aad759bd8d2174df93a7e'),
#  ObjectId('5b9aad759bd8d2174df93a7f'),
#  ObjectId('5b9aad759bd8d2174df93a80'),
#  ObjectId('5b9aad759bd8d2174df93a81'),
#  ObjectId('5b9aad759bd8d2174df93a82'),
#  ObjectId('5b9aad759bd8d2174df93a83'),
#  ObjectId('5b9aad759bd8d2174df93a84'),
#  ObjectId('5b9aad759bd8d2174df93a85'),
#  ObjectId('5b9aad759bd8d2174df93a86'),
#  ObjectId('5b9aad759bd8d2174df93a87'),
#  ObjectId('5b9aad759bd8d2174df93a88'),
#  ObjectId('5b9aad759bd8d2174df93a89'),
#  ObjectId('5b9aad759bd8d2174df93a8a'),
#  ObjectId('5b9aad759bd8d2174df93a8b'),
#  ObjectId('5b9aad759bd8d2174df93a8c'),
#  ObjectId('5b9aad759bd8d2174df93a8d'),
#  ObjectId('5b9aad759bd8d2174df93a8e'),
#  ObjectId('5b9aad759bd8d2174df93a8f'),
#  ObjectId('5b9aad759bd8d2174df93a90'),
#  ObjectId('5b9aad759bd8d2174df93a91'),
#  ObjectId('5b9aad759bd8d2174df93a92'),
#  ObjectId('5b9aad759bd8d2174df93a93'),
#  ObjectId('5b9aad759bd8d2174df93a94'),
#  ObjectId('5b9aad759bd8d2174df93a95'),
#  ObjectId('5b9aad759bd8d2174df93a96'),
#  ObjectId('5b9aad759bd8d2174df93a97'),
#  ObjectId('5b9aad759bd8d2174df93a98'),
#  ObjectId('5b9aad759bd8d2174df93a99'),
#  ObjectId('5b9aad759bd8d2174df93a9a'),
#  ObjectId('5b9aad759bd8d2174df93a9b'),
#  ObjectId('5b9aad759bd8d2174df93a9c'),
#  ObjectId('5b9aad759bd8d2174df93a9d'),
#  ObjectId('5b9aad759bd8d2174df93a9e'),
#  ObjectId('5b9aad759bd8d2174df93a9f'),
#  ObjectId('5b9aad759bd8d2174df93aa0'),
#  ObjectId('5b9aad759bd8d2174df93aa1'),
#  ObjectId('5b9aad759bd8d2174df93aa2'),
#  ObjectId('5b9aad759bd8d2174df93aa3'),
#  ObjectId('5b9aad759bd8d2174df93aa4'),
#  ObjectId('5b9aad759bd8d2174df93aa5'),
#  ObjectId('5b9aad759bd8d2174df93aa6'),
#  ObjectId('5b9aad759bd8d2174df93aa7'),
#  ObjectId('5b9aad759bd8d2174df93aa8'),
#  ObjectId('5b9aad759bd8d2174df93aa9'),
#  ObjectId('5b9aad759bd8d2174df93aaa'),
#  ObjectId('5b9aad759bd8d2174df93aab'),
#  ObjectId('5b9aad759bd8d2174df93aac'),
#  ObjectId('5b9aad759bd8d2174df93aad'),
#  ObjectId('5b9aad759bd8d2174df93aae'),
#  ObjectId('5b9aad759bd8d2174df93aaf'),
#  ObjectId('5b9aad759bd8d2174df93ab0'),
#  ObjectId('5b9aad759bd8d2174df93ab1'),
#  ObjectId('5b9aad759bd8d2174df93ab2'),
#  ObjectId('5b9aad759bd8d2174df93ab3'),
#  ObjectId('5b9aad759bd8d2174df93ab4'),
#  ObjectId('5b9aad759bd8d2174df93ab5'),
#  ObjectId('5b9aad759bd8d2174df93ab6'),
#  ObjectId('5b9aad759bd8d2174df93ab7'),
#  ObjectId('5b9aad759bd8d2174df93ab8'),
#  ObjectId('5b9aad759bd8d2174df93ab9'),
#  ObjectId('5b9aad759bd8d2174df93aba'),
#  ObjectId('5b9aad759bd8d2174df93abb'),
#  ObjectId('5b9aad759bd8d2174df93abc'),
#  ObjectId('5b9aad759bd8d2174df93abd'),
#  ObjectId('5b9aad759bd8d2174df93abe'),
#  ObjectId('5b9aad759bd8d2174df93abf'),
#  ObjectId('5b9aad759bd8d2174df93ac0'),
#  ObjectId('5b9aad759bd8d2174df93ac1'),
#  ObjectId('5b9aad759bd8d2174df93ac2'),
#  ObjectId('5b9aad759bd8d2174df93ac3'),
#  ObjectId('5b9aad759bd8d2174df93ac4'),
#  ObjectId('5b9aad759bd8d2174df93ac5'),
#  ObjectId('5b9aad759bd8d2174df93ac6'),
#  ObjectId('5b9aad759bd8d2174df93ac7'),
#  ObjectId('5b9aad759bd8d2174df93ac8'),
#  ObjectId('5b9aad759bd8d2174df93ac9'),
#  ObjectId('5b9aad759bd8d2174df93aca'),
#  ObjectId('5b9aad759bd8d2174df93acb'),
#  ObjectId('5b9aad759bd8d2174df93acc'),
#  ObjectId('5b9aad759bd8d2174df93acd'),
#  ObjectId('5b9aad759bd8d2174df93ace'),
#  ObjectId('5b9aad759bd8d2174df93acf'),
#  ObjectId('5b9aad759bd8d2174df93ad0'),
#  ObjectId('5b9aad759bd8d2174df93ad1'),
#  ObjectId('5b9aad759bd8d2174df93ad2'),
#  ObjectId('5b9aad759bd8d2174df93ad3'),
#  ObjectId('5b9aad759bd8d2174df93ad4'),
#  ObjectId('5b9aad759bd8d2174df93ad5'),
#  ObjectId('5b9aad759bd8d2174df93ad6'),
#  ObjectId('5b9aad759bd8d2174df93ad7'),
#  ObjectId('5b9aad759bd8d2174df93ad8'),
#  ObjectId('5b9aad759bd8d2174df93ad9'),
#  ObjectId('5b9aad759bd8d2174df93ada'),
#  ObjectId('5b9aad759bd8d2174df93adb'),
#  ObjectId('5b9aad759bd8d2174df93adc'),
#  ObjectId('5b9aad759bd8d2174df93add'),
#  ObjectId('5b9aad759bd8d2174df93ade'),
#  ObjectId('5b9aad759bd8d2174df93adf'),
#  ObjectId('5b9aad759bd8d2174df93ae0'),
#  ObjectId('5b9aad759bd8d2174df93ae1'),
#  ObjectId('5b9aad759bd8d2174df93ae2'),
#  ObjectId('5b9aad759bd8d2174df93ae3'),
#  ObjectId('5b9aad759bd8d2174df93ae4'),
#  ObjectId('5b9aad759bd8d2174df93ae5'),
#  ObjectId('5b9aad759bd8d2174df93ae6'),
#  ObjectId('5b9aad759bd8d2174df93ae7'),
#  ObjectId('5b9aad759bd8d2174df93ae8'),
#  ObjectId('5b9aad759bd8d2174df93ae9'),
#  ObjectId('5b9aad759bd8d2174df93aea'),
#  ObjectId('5b9aad759bd8d2174df93aeb'),
#  ObjectId('5b9aad759bd8d2174df93aec'),
#  ObjectId('5b9aad759bd8d2174df93aed'),
#  ObjectId('5b9aad759bd8d2174df93aee'),
#  ObjectId('5b9aad759bd8d2174df93aef'),
#  ObjectId('5b9aad759bd8d2174df93af0'),
#  ObjectId('5b9aad759bd8d2174df93af1'),
#  ObjectId('5b9aad759bd8d2174df93af2'),
#  ObjectId('5b9aad759bd8d2174df93af3'),
#  ObjectId('5b9aad759bd8d2174df93af4'),
#  ObjectId('5b9aad759bd8d2174df93af5'),
#  ObjectId('5b9aad759bd8d2174df93af6'),
#  ObjectId('5b9aad759bd8d2174df93af7'),
#  ObjectId('5b9aad759bd8d2174df93af8'),
#  ObjectId('5b9aad759bd8d2174df93af9'),
#  ObjectId('5b9aad759bd8d2174df93afa'),
#  ObjectId('5b9aad759bd8d2174df93afb'),
#  ObjectId('5b9aad759bd8d2174df93afc'),
#  ObjectId('5b9aad759bd8d2174df93afd'),
#  ObjectId('5b9aad759bd8d2174df93afe'),
#  ObjectId('5b9aad759bd8d2174df93aff'),
#  ObjectId('5b9aad759bd8d2174df93b00'),
#  ObjectId('5b9aad759bd8d2174df93b01'),
#  ObjectId('5b9aad759bd8d2174df93b02'),
#  ObjectId('5b9aad759bd8d2174df93b03'),
#  ObjectId('5b9aad759bd8d2174df93b04'),
#  ObjectId('5b9aad759bd8d2174df93b05'),
#  ObjectId('5b9aad759bd8d2174df93b06'),
#  ObjectId('5b9aad759bd8d2174df93b07'),
#  ObjectId('5b9aad759bd8d2174df93b08'),
#  ObjectId('5b9aad759bd8d2174df93b09'),
#  ObjectId('5b9aad759bd8d2174df93b0a'),
#  ObjectId('5b9aad759bd8d2174df93b0b'),
#  ObjectId('5b9aad759bd8d2174df93b0c'),
#  ObjectId('5b9aad759bd8d2174df93b0d'),
#  ObjectId('5b9aad759bd8d2174df93b0e'),
#  ObjectId('5b9aad759bd8d2174df93b0f'),
#  ObjectId('5b9aad759bd8d2174df93b10'),
#  ObjectId('5b9aad759bd8d2174df93b11'),
#  ObjectId('5b9aad759bd8d2174df93b12'),
#  ObjectId('5b9aad759bd8d2174df93b13'),
#  ObjectId('5b9aad759bd8d2174df93b14'),
#  ObjectId('5b9aad759bd8d2174df93b15'),
#  ObjectId('5b9aad759bd8d2174df93b16'),
#  ObjectId('5b9aad759bd8d2174df93b17'),
#  ObjectId('5b9aad759bd8d2174df93b18'),
#  ObjectId('5b9aad759bd8d2174df93b19'),
#  ObjectId('5b9aad759bd8d2174df93b1a'),
#  ObjectId('5b9aad759bd8d2174df93b1b'),
#  ObjectId('5b9aad759bd8d2174df93b1c'),
#  ObjectId('5b9aad759bd8d2174df93b1d'),
#  ObjectId('5b9aad759bd8d2174df93b1e'),
#  ObjectId('5b9aad759bd8d2174df93b1f'),
#  ObjectId('5b9aad759bd8d2174df93b20'),
#  ObjectId('5b9aad759bd8d2174df93b21'),
#  ObjectId('5b9aad759bd8d2174df93b22'),
#  ObjectId('5b9aad759bd8d2174df93b23'),
#  ObjectId('5b9aad759bd8d2174df93b24'),
#  ObjectId('5b9aad759bd8d2174df93b25'),
#  ObjectId('5b9aad759bd8d2174df93b26'),
#  ObjectId('5b9aad759bd8d2174df93b27'),
#  ObjectId('5b9aad759bd8d2174df93b28'),
#  ObjectId('5b9aad759bd8d2174df93b29'),
#  ObjectId('5b9aad759bd8d2174df93b2a'),
#  ObjectId('5b9aad759bd8d2174df93b2b'),
#  ObjectId('5b9aad759bd8d2174df93b2c'),
#  ObjectId('5b9aad759bd8d2174df93b2d'),
#  ObjectId('5b9aad759bd8d2174df93b2e'),
#  ObjectId('5b9aad759bd8d2174df93b2f'),
#  ObjectId('5b9aad759bd8d2174df93b30'),
#  ObjectId('5b9aad759bd8d2174df93b31'),
#  ObjectId('5b9aad759bd8d2174df93b32'),
#  ObjectId('5b9aad759bd8d2174df93b33'),
#  ObjectId('5b9aad759bd8d2174df93b34'),
#  ObjectId('5b9aad759bd8d2174df93b35'),
#  ObjectId('5b9aad759bd8d2174df93b36'),
#  ObjectId('5b9aad759bd8d2174df93b37'),
#  ObjectId('5b9aad759bd8d2174df93b38'),
#  ObjectId('5b9aad759bd8d2174df93b39'),
#  ObjectId('5b9aad759bd8d2174df93b3a'),
#  ObjectId('5b9aad759bd8d2174df93b3b'),
#  ObjectId('5b9aad759bd8d2174df93b3c'),
#  ObjectId('5b9aad759bd8d2174df93b3d'),
#  ObjectId('5b9aad759bd8d2174df93b3e'),
#  ObjectId('5b9aad759bd8d2174df93b3f'),
#  ObjectId('5b9aad759bd8d2174df93b40'),
#  ObjectId('5b9aad759bd8d2174df93b41'),
#  ObjectId('5b9aad759bd8d2174df93b42'),
#  ObjectId('5b9aad759bd8d2174df93b43'),
#  ObjectId('5b9aad759bd8d2174df93b44'),
#  ObjectId('5b9aad759bd8d2174df93b45'),
#  ObjectId('5b9aad759bd8d2174df93b46'),
#  ObjectId('5b9aad759bd8d2174df93b47'),
#  ObjectId('5b9aad759bd8d2174df93b48'),
#  ObjectId('5b9aad759bd8d2174df93b49'),
#  ObjectId('5b9aad759bd8d2174df93b4a'),
#  ObjectId('5b9aad759bd8d2174df93b4b'),
#  ObjectId('5b9aad759bd8d2174df93b4c'),
#  ObjectId('5b9aad759bd8d2174df93b4d'),
#  ObjectId('5b9aad759bd8d2174df93b4e'),
#  ...]

# %%
with open('W2V.pkl','wb') as file:
    pickle.dump(model,file)

# %%
with open('W2V_data.pkl','wb') as file:
    pickle.dump(w2v_data,file)

# %% [markdown]
# ### Count Vectorizer

# %%
# set ngram range, stop words only english, regex patterns, set to lowercase
count_vectorizer = CountVectorizer(ngram_range=(1, 2),  
                                   stop_words='english', 
                                   token_pattern="\\b[a-z][a-z]+\\b",
                                   lowercase=True)

# fit and transform the text
cv_data = count_vectorizer.fit_transform(df_combined['text'])

# %% [markdown]
# #### LSA

# %%
lsa_cv = TruncatedSVD(n_components=100) # set to 100 dimensions

# fit and transform the text
lsa_cv_data = lsa_cv.fit_transform(cv_data)

# %%
# combine the lsa_cv text with the non-vectorized features
CV_LSA = pd.concat([pd.DataFrame(lsa_cv_data),df[['y','Analyst','Scientist','Engineer','Start Dates','Bachelors',
                                                'Masters','PhD']]],axis=1)

# %%
CV_LSA.head()
# Out:
#            0          1          2         3         4         5         6  \
# 0   8.338605   5.322429   4.703971 -3.301757 -2.369379  1.787536  0.355131
# 1  16.898709  -1.338696  13.986113 -0.990019 -3.746873 -2.221212  3.844439
# 2  57.576805  13.517422  -1.897632  0.838416  1.465622 -7.855823 -1.659711
# 3   5.408049   1.395045   1.935934 -1.420569 -1.844288 -0.799884  2.049063
# 4  14.585224   5.018236   7.206179 -3.417568  0.346719 -4.410483 -2.474445
#
#           7         8         9 ...         98        99         y  Analyst  \
# 0 -2.653454 -0.439998 -2.412284 ...   0.586919  0.530225   Analyst        1
# 1 -0.669413 -0.592488 -1.099078 ...  -0.029255  1.751036   Analyst        1
# 2 -0.591778  7.723553 -3.061332 ...  -1.461940 -0.486254  Engineer        0
# 3  0.853001  0.657492 -1.677186 ...  -0.379710 -0.350758   Analyst        1
# 4  1.600515 -3.146223  7.442911 ...  -0.527037 -2.555981  Engineer        0
#
#    Scientist  Engineer  Start Dates  Bachelors  Masters  PhD
# 0          0         0            6          1        0    0
# 1          0         0            2          1        0    0
# 2          0         1           18          1        1    0
# 3          0         0            5          1        0    0
# 4          0         1            8          1        1    0
#
# [5 rows x 108 columns]

# %% [markdown]
# #### Store data in MongoDB and pickle files.

# %%
# save the model
with open('LSA_CV.pkl','wb') as file:
    pickle.dump(lsa_cv,file)

# save the data
with open('LSA_CV_data.pkl','wb') as file:
    pickle.dump(CV_LSA,file)

# %%
# store the data in MongoDB
client = MongoClient('localhost', 27017)
db = client['resumes']

CV_LSA_coll = json.loads(CV_LSA.T.to_json()).values()
db.lsa_cv.insert(CV_LSA_coll)
# Out:
# [ObjectId('5b9aadaa9bd8d2174df98999'),
#  ObjectId('5b9aadaa9bd8d2174df9899a'),
#  ObjectId('5b9aadaa9bd8d2174df9899b'),
#  ObjectId('5b9aadaa9bd8d2174df9899c'),
#  ObjectId('5b9aadaa9bd8d2174df9899d'),
#  ObjectId('5b9aadaa9bd8d2174df9899e'),
#  ObjectId('5b9aadaa9bd8d2174df9899f'),
#  ObjectId('5b9aadaa9bd8d2174df989a0'),
#  ObjectId('5b9aadaa9bd8d2174df989a1'),
#  ObjectId('5b9aadaa9bd8d2174df989a2'),
#  ObjectId('5b9aadaa9bd8d2174df989a3'),
#  ObjectId('5b9aadaa9bd8d2174df989a4'),
#  ObjectId('5b9aadaa9bd8d2174df989a5'),
#  ObjectId('5b9aadaa9bd8d2174df989a6'),
#  ObjectId('5b9aadaa9bd8d2174df989a7'),
#  ObjectId('5b9aadaa9bd8d2174df989a8'),
#  ObjectId('5b9aadaa9bd8d2174df989a9'),
#  ObjectId('5b9aadaa9bd8d2174df989aa'),
#  ObjectId('5b9aadaa9bd8d2174df989ab'),
#  ObjectId('5b9aadaa9bd8d2174df989ac'),
#  ObjectId('5b9aadaa9bd8d2174df989ad'),
#  ObjectId('5b9aadaa9bd8d2174df989ae'),
#  ObjectId('5b9aadaa9bd8d2174df989af'),
#  ObjectId('5b9aadaa9bd8d2174df989b0'),
#  ObjectId('5b9aadaa9bd8d2174df989b1'),
#  ObjectId('5b9aadaa9bd8d2174df989b2'),
#  ObjectId('5b9aadaa9bd8d2174df989b3'),
#  ObjectId('5b9aadaa9bd8d2174df989b4'),
#  ObjectId('5b9aadaa9bd8d2174df989b5'),
#  ObjectId('5b9aadaa9bd8d2174df989b6'),
#  ObjectId('5b9aadaa9bd8d2174df989b7'),
#  ObjectId('5b9aadaa9bd8d2174df989b8'),
#  ObjectId('5b9aadaa9bd8d2174df989b9'),
#  ObjectId('5b9aadaa9bd8d2174df989ba'),
#  ObjectId('5b9aadaa9bd8d2174df989bb'),
#  ObjectId('5b9aadaa9bd8d2174df989bc'),
#  ObjectId('5b9aadaa9bd8d2174df989bd'),
#  ObjectId('5b9aadaa9bd8d2174df989be'),
#  ObjectId('5b9aadaa9bd8d2174df989bf'),
#  ObjectId('5b9aadaa9bd8d2174df989c0'),
#  ObjectId('5b9aadaa9bd8d2174df989c1'),
#  ObjectId('5b9aadaa9bd8d2174df989c2'),
#  ObjectId('5b9aadaa9bd8d2174df989c3'),
#  ObjectId('5b9aadaa9bd8d2174df989c4'),
#  ObjectId('5b9aadaa9bd8d2174df989c5'),
#  ObjectId('5b9aadaa9bd8d2174df989c6'),
#  ObjectId('5b9aadaa9bd8d2174df989c7'),
#  ObjectId('5b9aadaa9bd8d2174df989c8'),
#  ObjectId('5b9aadaa9bd8d2174df989c9'),
#  ObjectId('5b9aadaa9bd8d2174df989ca'),
#  ObjectId('5b9aadaa9bd8d2174df989cb'),
#  ObjectId('5b9aadaa9bd8d2174df989cc'),
#  ObjectId('5b9aadaa9bd8d2174df989cd'),
#  ObjectId('5b9aadaa9bd8d2174df989ce'),
#  ObjectId('5b9aadaa9bd8d2174df989cf'),
#  ObjectId('5b9aadaa9bd8d2174df989d0'),
#  ObjectId('5b9aadaa9bd8d2174df989d1'),
#  ObjectId('5b9aadaa9bd8d2174df989d2'),
#  ObjectId('5b9aadaa9bd8d2174df989d3'),
#  ObjectId('5b9aadaa9bd8d2174df989d4'),
#  ObjectId('5b9aadaa9bd8d2174df989d5'),
#  ObjectId('5b9aadaa9bd8d2174df989d6'),
#  ObjectId('5b9aadaa9bd8d2174df989d7'),
#  ObjectId('5b9aadaa9bd8d2174df989d8'),
#  ObjectId('5b9aadaa9bd8d2174df989d9'),
#  ObjectId('5b9aadaa9bd8d2174df989da'),
#  ObjectId('5b9aadaa9bd8d2174df989db'),
#  ObjectId('5b9aadaa9bd8d2174df989dc'),
#  ObjectId('5b9aadaa9bd8d2174df989dd'),
#  ObjectId('5b9aadaa9bd8d2174df989de'),
#  ObjectId('5b9aadaa9bd8d2174df989df'),
#  ObjectId('5b9aadaa9bd8d2174df989e0'),
#  ObjectId('5b9aadaa9bd8d2174df989e1'),
#  ObjectId('5b9aadaa9bd8d2174df989e2'),
#  ObjectId('5b9aadaa9bd8d2174df989e3'),
#  ObjectId('5b9aadaa9bd8d2174df989e4'),
#  ObjectId('5b9aadaa9bd8d2174df989e5'),
#  ObjectId('5b9aadaa9bd8d2174df989e6'),
#  ObjectId('5b9aadaa9bd8d2174df989e7'),
#  ObjectId('5b9aadaa9bd8d2174df989e8'),
#  ObjectId('5b9aadaa9bd8d2174df989e9'),
#  ObjectId('5b9aadaa9bd8d2174df989ea'),
#  ObjectId('5b9aadaa9bd8d2174df989eb'),
#  ObjectId('5b9aadaa9bd8d2174df989ec'),
#  ObjectId('5b9aadaa9bd8d2174df989ed'),
#  ObjectId('5b9aadaa9bd8d2174df989ee'),
#  ObjectId('5b9aadaa9bd8d2174df989ef'),
#  ObjectId('5b9aadaa9bd8d2174df989f0'),
#  ObjectId('5b9aadaa9bd8d2174df989f1'),
#  ObjectId('5b9aadaa9bd8d2174df989f2'),
#  ObjectId('5b9aadaa9bd8d2174df989f3'),
#  ObjectId('5b9aadaa9bd8d2174df989f4'),
#  ObjectId('5b9aadaa9bd8d2174df989f5'),
#  ObjectId('5b9aadaa9bd8d2174df989f6'),
#  ObjectId('5b9aadaa9bd8d2174df989f7'),
#  ObjectId('5b9aadaa9bd8d2174df989f8'),
#  ObjectId('5b9aadaa9bd8d2174df989f9'),
#  ObjectId('5b9aadaa9bd8d2174df989fa'),
#  ObjectId('5b9aadaa9bd8d2174df989fb'),
#  ObjectId('5b9aadaa9bd8d2174df989fc'),
#  ObjectId('5b9aadaa9bd8d2174df989fd'),
#  ObjectId('5b9aadaa9bd8d2174df989fe'),
#  ObjectId('5b9aadaa9bd8d2174df989ff'),
#  ObjectId('5b9aadaa9bd8d2174df98a00'),
#  ObjectId('5b9aadaa9bd8d2174df98a01'),
#  ObjectId('5b9aadaa9bd8d2174df98a02'),
#  ObjectId('5b9aadaa9bd8d2174df98a03'),
#  ObjectId('5b9aadaa9bd8d2174df98a04'),
#  ObjectId('5b9aadaa9bd8d2174df98a05'),
#  ObjectId('5b9aadaa9bd8d2174df98a06'),
#  ObjectId('5b9aadaa9bd8d2174df98a07'),
#  ObjectId('5b9aadaa9bd8d2174df98a08'),
#  ObjectId('5b9aadaa9bd8d2174df98a09'),
#  ObjectId('5b9aadaa9bd8d2174df98a0a'),
#  ObjectId('5b9aadaa9bd8d2174df98a0b'),
#  ObjectId('5b9aadaa9bd8d2174df98a0c'),
#  ObjectId('5b9aadaa9bd8d2174df98a0d'),
#  ObjectId('5b9aadaa9bd8d2174df98a0e'),
#  ObjectId('5b9aadaa9bd8d2174df98a0f'),
#  ObjectId('5b9aadaa9bd8d2174df98a10'),
#  ObjectId('5b9aadaa9bd8d2174df98a11'),
#  ObjectId('5b9aadaa9bd8d2174df98a12'),
#  ObjectId('5b9aadaa9bd8d2174df98a13'),
#  ObjectId('5b9aadaa9bd8d2174df98a14'),
#  ObjectId('5b9aadaa9bd8d2174df98a15'),
#  ObjectId('5b9aadaa9bd8d2174df98a16'),
#  ObjectId('5b9aadaa9bd8d2174df98a17'),
#  ObjectId('5b9aadaa9bd8d2174df98a18'),
#  ObjectId('5b9aadaa9bd8d2174df98a19'),
#  ObjectId('5b9aadaa9bd8d2174df98a1a'),
#  ObjectId('5b9aadaa9bd8d2174df98a1b'),
#  ObjectId('5b9aadaa9bd8d2174df98a1c'),
#  ObjectId('5b9aadaa9bd8d2174df98a1d'),
#  ObjectId('5b9aadaa9bd8d2174df98a1e'),
#  ObjectId('5b9aadaa9bd8d2174df98a1f'),
#  ObjectId('5b9aadaa9bd8d2174df98a20'),
#  ObjectId('5b9aadaa9bd8d2174df98a21'),
#  ObjectId('5b9aadaa9bd8d2174df98a22'),
#  ObjectId('5b9aadaa9bd8d2174df98a23'),
#  ObjectId('5b9aadaa9bd8d2174df98a24'),
#  ObjectId('5b9aadaa9bd8d2174df98a25'),
#  ObjectId('5b9aadaa9bd8d2174df98a26'),
#  ObjectId('5b9aadaa9bd8d2174df98a27'),
#  ObjectId('5b9aadaa9bd8d2174df98a28'),
#  ObjectId('5b9aadaa9bd8d2174df98a29'),
#  ObjectId('5b9aadaa9bd8d2174df98a2a'),
#  ObjectId('5b9aadaa9bd8d2174df98a2b'),
#  ObjectId('5b9aadaa9bd8d2174df98a2c'),
#  ObjectId('5b9aadaa9bd8d2174df98a2d'),
#  ObjectId('5b9aadaa9bd8d2174df98a2e'),
#  ObjectId('5b9aadaa9bd8d2174df98a2f'),
#  ObjectId('5b9aadaa9bd8d2174df98a30'),
#  ObjectId('5b9aadaa9bd8d2174df98a31'),
#  ObjectId('5b9aadaa9bd8d2174df98a32'),
#  ObjectId('5b9aadaa9bd8d2174df98a33'),
#  ObjectId('5b9aadaa9bd8d2174df98a34'),
#  ObjectId('5b9aadaa9bd8d2174df98a35'),
#  ObjectId('5b9aadaa9bd8d2174df98a36'),
#  ObjectId('5b9aadaa9bd8d2174df98a37'),
#  ObjectId('5b9aadaa9bd8d2174df98a38'),
#  ObjectId('5b9aadaa9bd8d2174df98a39'),
#  ObjectId('5b9aadaa9bd8d2174df98a3a'),
#  ObjectId('5b9aadaa9bd8d2174df98a3b'),
#  ObjectId('5b9aadaa9bd8d2174df98a3c'),
#  ObjectId('5b9aadaa9bd8d2174df98a3d'),
#  ObjectId('5b9aadaa9bd8d2174df98a3e'),
#  ObjectId('5b9aadaa9bd8d2174df98a3f'),
#  ObjectId('5b9aadaa9bd8d2174df98a40'),
#  ObjectId('5b9aadaa9bd8d2174df98a41'),
#  ObjectId('5b9aadaa9bd8d2174df98a42'),
#  ObjectId('5b9aadaa9bd8d2174df98a43'),
#  ObjectId('5b9aadaa9bd8d2174df98a44'),
#  ObjectId('5b9aadaa9bd8d2174df98a45'),
#  ObjectId('5b9aadaa9bd8d2174df98a46'),
#  ObjectId('5b9aadaa9bd8d2174df98a47'),
#  ObjectId('5b9aadaa9bd8d2174df98a48'),
#  ObjectId('5b9aadaa9bd8d2174df98a49'),
#  ObjectId('5b9aadaa9bd8d2174df98a4a'),
#  ObjectId('5b9aadaa9bd8d2174df98a4b'),
#  ObjectId('5b9aadaa9bd8d2174df98a4c'),
#  ObjectId('5b9aadaa9bd8d2174df98a4d'),
#  ObjectId('5b9aadaa9bd8d2174df98a4e'),
#  ObjectId('5b9aadaa9bd8d2174df98a4f'),
#  ObjectId('5b9aadaa9bd8d2174df98a50'),
#  ObjectId('5b9aadaa9bd8d2174df98a51'),
#  ObjectId('5b9aadaa9bd8d2174df98a52'),
#  ObjectId('5b9aadaa9bd8d2174df98a53'),
#  ObjectId('5b9aadaa9bd8d2174df98a54'),
#  ObjectId('5b9aadaa9bd8d2174df98a55'),
#  ObjectId('5b9aadaa9bd8d2174df98a56'),
#  ObjectId('5b9aadaa9bd8d2174df98a57'),
#  ObjectId('5b9aadaa9bd8d2174df98a58'),
#  ObjectId('5b9aadaa9bd8d2174df98a59'),
#  ObjectId('5b9aadaa9bd8d2174df98a5a'),
#  ObjectId('5b9aadaa9bd8d2174df98a5b'),
#  ObjectId('5b9aadaa9bd8d2174df98a5c'),
#  ObjectId('5b9aadaa9bd8d2174df98a5d'),
#  ObjectId('5b9aadaa9bd8d2174df98a5e'),
#  ObjectId('5b9aadaa9bd8d2174df98a5f'),
#  ObjectId('5b9aadaa9bd8d2174df98a60'),
#  ObjectId('5b9aadaa9bd8d2174df98a61'),
#  ObjectId('5b9aadaa9bd8d2174df98a62'),
#  ObjectId('5b9aadaa9bd8d2174df98a63'),
#  ObjectId('5b9aadaa9bd8d2174df98a64'),
#  ObjectId('5b9aadaa9bd8d2174df98a65'),
#  ObjectId('5b9aadaa9bd8d2174df98a66'),
#  ObjectId('5b9aadaa9bd8d2174df98a67'),
#  ObjectId('5b9aadaa9bd8d2174df98a68'),
#  ObjectId('5b9aadaa9bd8d2174df98a69'),
#  ObjectId('5b9aadaa9bd8d2174df98a6a'),
#  ObjectId('5b9aadaa9bd8d2174df98a6b'),
#  ObjectId('5b9aadaa9bd8d2174df98a6c'),
#  ObjectId('5b9aadaa9bd8d2174df98a6d'),
#  ObjectId('5b9aadaa9bd8d2174df98a6e'),
#  ObjectId('5b9aadaa9bd8d2174df98a6f'),
#  ObjectId('5b9aadaa9bd8d2174df98a70'),
#  ObjectId('5b9aadaa9bd8d2174df98a71'),
#  ObjectId('5b9aadaa9bd8d2174df98a72'),
#  ObjectId('5b9aadaa9bd8d2174df98a73'),
#  ObjectId('5b9aadaa9bd8d2174df98a74'),
#  ObjectId('5b9aadaa9bd8d2174df98a75'),
#  ObjectId('5b9aadaa9bd8d2174df98a76'),
#  ObjectId('5b9aadaa9bd8d2174df98a77'),
#  ObjectId('5b9aadaa9bd8d2174df98a78'),
#  ObjectId('5b9aadaa9bd8d2174df98a79'),
#  ObjectId('5b9aadaa9bd8d2174df98a7a'),
#  ObjectId('5b9aadaa9bd8d2174df98a7b'),
#  ObjectId('5b9aadaa9bd8d2174df98a7c'),
#  ObjectId('5b9aadaa9bd8d2174df98a7d'),
#  ObjectId('5b9aadaa9bd8d2174df98a7e'),
#  ObjectId('5b9aadaa9bd8d2174df98a7f'),
#  ObjectId('5b9aadaa9bd8d2174df98a80'),
#  ObjectId('5b9aadaa9bd8d2174df98a81'),
#  ObjectId('5b9aadaa9bd8d2174df98a82'),
#  ObjectId('5b9aadaa9bd8d2174df98a83'),
#  ObjectId('5b9aadaa9bd8d2174df98a84'),
#  ObjectId('5b9aadaa9bd8d2174df98a85'),
#  ObjectId('5b9aadaa9bd8d2174df98a86'),
#  ObjectId('5b9aadaa9bd8d2174df98a87'),
#  ObjectId('5b9aadaa9bd8d2174df98a88'),
#  ObjectId('5b9aadaa9bd8d2174df98a89'),
#  ObjectId('5b9aadaa9bd8d2174df98a8a'),
#  ObjectId('5b9aadaa9bd8d2174df98a8b'),
#  ObjectId('5b9aadaa9bd8d2174df98a8c'),
#  ObjectId('5b9aadaa9bd8d2174df98a8d'),
#  ObjectId('5b9aadaa9bd8d2174df98a8e'),
#  ObjectId('5b9aadaa9bd8d2174df98a8f'),
#  ObjectId('5b9aadaa9bd8d2174df98a90'),
#  ObjectId('5b9aadaa9bd8d2174df98a91'),
#  ObjectId('5b9aadaa9bd8d2174df98a92'),
#  ObjectId('5b9aadaa9bd8d2174df98a93'),
#  ObjectId('5b9aadaa9bd8d2174df98a94'),
#  ObjectId('5b9aadaa9bd8d2174df98a95'),
#  ObjectId('5b9aadaa9bd8d2174df98a96'),
#  ObjectId('5b9aadaa9bd8d2174df98a97'),
#  ObjectId('5b9aadaa9bd8d2174df98a98'),
#  ObjectId('5b9aadaa9bd8d2174df98a99'),
#  ObjectId('5b9aadaa9bd8d2174df98a9a'),
#  ObjectId('5b9aadaa9bd8d2174df98a9b'),
#  ObjectId('5b9aadaa9bd8d2174df98a9c'),
#  ObjectId('5b9aadaa9bd8d2174df98a9d'),
#  ObjectId('5b9aadaa9bd8d2174df98a9e'),
#  ObjectId('5b9aadaa9bd8d2174df98a9f'),
#  ObjectId('5b9aadaa9bd8d2174df98aa0'),
#  ObjectId('5b9aadaa9bd8d2174df98aa1'),
#  ObjectId('5b9aadaa9bd8d2174df98aa2'),
#  ObjectId('5b9aadaa9bd8d2174df98aa3'),
#  ObjectId('5b9aadaa9bd8d2174df98aa4'),
#  ObjectId('5b9aadaa9bd8d2174df98aa5'),
#  ObjectId('5b9aadaa9bd8d2174df98aa6'),
#  ObjectId('5b9aadaa9bd8d2174df98aa7'),
#  ObjectId('5b9aadaa9bd8d2174df98aa8'),
#  ObjectId('5b9aadaa9bd8d2174df98aa9'),
#  ObjectId('5b9aadaa9bd8d2174df98aaa'),
#  ObjectId('5b9aadaa9bd8d2174df98aab'),
#  ObjectId('5b9aadaa9bd8d2174df98aac'),
#  ObjectId('5b9aadaa9bd8d2174df98aad'),
#  ObjectId('5b9aadaa9bd8d2174df98aae'),
#  ObjectId('5b9aadaa9bd8d2174df98aaf'),
#  ObjectId('5b9aadaa9bd8d2174df98ab0'),
#  ObjectId('5b9aadaa9bd8d2174df98ab1'),
#  ObjectId('5b9aadaa9bd8d2174df98ab2'),
#  ObjectId('5b9aadaa9bd8d2174df98ab3'),
#  ObjectId('5b9aadaa9bd8d2174df98ab4'),
#  ObjectId('5b9aadaa9bd8d2174df98ab5'),
#  ObjectId('5b9aadaa9bd8d2174df98ab6'),
#  ObjectId('5b9aadaa9bd8d2174df98ab7'),
#  ObjectId('5b9aadaa9bd8d2174df98ab8'),
#  ObjectId('5b9aadaa9bd8d2174df98ab9'),
#  ObjectId('5b9aadaa9bd8d2174df98aba'),
#  ObjectId('5b9aadaa9bd8d2174df98abb'),
#  ObjectId('5b9aadaa9bd8d2174df98abc'),
#  ObjectId('5b9aadaa9bd8d2174df98abd'),
#  ObjectId('5b9aadaa9bd8d2174df98abe'),
#  ObjectId('5b9aadaa9bd8d2174df98abf'),
#  ObjectId('5b9aadaa9bd8d2174df98ac0'),
#  ObjectId('5b9aadaa9bd8d2174df98ac1'),
#  ObjectId('5b9aadaa9bd8d2174df98ac2'),
#  ObjectId('5b9aadaa9bd8d2174df98ac3'),
#  ObjectId('5b9aadaa9bd8d2174df98ac4'),
#  ObjectId('5b9aadaa9bd8d2174df98ac5'),
#  ObjectId('5b9aadaa9bd8d2174df98ac6'),
#  ObjectId('5b9aadaa9bd8d2174df98ac7'),
#  ObjectId('5b9aadaa9bd8d2174df98ac8'),
#  ObjectId('5b9aadaa9bd8d2174df98ac9'),
#  ObjectId('5b9aadaa9bd8d2174df98aca'),
#  ObjectId('5b9aadaa9bd8d2174df98acb'),
#  ObjectId('5b9aadaa9bd8d2174df98acc'),
#  ObjectId('5b9aadaa9bd8d2174df98acd'),
#  ObjectId('5b9aadaa9bd8d2174df98ace'),
#  ObjectId('5b9aadaa9bd8d2174df98acf'),
#  ObjectId('5b9aadaa9bd8d2174df98ad0'),
#  ObjectId('5b9aadaa9bd8d2174df98ad1'),
#  ObjectId('5b9aadaa9bd8d2174df98ad2'),
#  ObjectId('5b9aadaa9bd8d2174df98ad3'),
#  ObjectId('5b9aadaa9bd8d2174df98ad4'),
#  ObjectId('5b9aadaa9bd8d2174df98ad5'),
#  ObjectId('5b9aadaa9bd8d2174df98ad6'),
#  ObjectId('5b9aadaa9bd8d2174df98ad7'),
#  ObjectId('5b9aadaa9bd8d2174df98ad8'),
#  ObjectId('5b9aadaa9bd8d2174df98ad9'),
#  ObjectId('5b9aadaa9bd8d2174df98ada'),
#  ObjectId('5b9aadaa9bd8d2174df98adb'),
#  ObjectId('5b9aadaa9bd8d2174df98adc'),
#  ObjectId('5b9aadaa9bd8d2174df98add'),
#  ObjectId('5b9aadaa9bd8d2174df98ade'),
#  ObjectId('5b9aadaa9bd8d2174df98adf'),
#  ObjectId('5b9aadaa9bd8d2174df98ae0'),
#  ObjectId('5b9aadaa9bd8d2174df98ae1'),
#  ObjectId('5b9aadaa9bd8d2174df98ae2'),
#  ObjectId('5b9aadaa9bd8d2174df98ae3'),
#  ObjectId('5b9aadaa9bd8d2174df98ae4'),
#  ObjectId('5b9aadaa9bd8d2174df98ae5'),
#  ObjectId('5b9aadaa9bd8d2174df98ae6'),
#  ObjectId('5b9aadaa9bd8d2174df98ae7'),
#  ObjectId('5b9aadaa9bd8d2174df98ae8'),
#  ObjectId('5b9aadaa9bd8d2174df98ae9'),
#  ObjectId('5b9aadaa9bd8d2174df98aea'),
#  ObjectId('5b9aadaa9bd8d2174df98aeb'),
#  ObjectId('5b9aadaa9bd8d2174df98aec'),
#  ObjectId('5b9aadaa9bd8d2174df98aed'),
#  ObjectId('5b9aadaa9bd8d2174df98aee'),
#  ObjectId('5b9aadaa9bd8d2174df98aef'),
#  ObjectId('5b9aadaa9bd8d2174df98af0'),
#  ObjectId('5b9aadaa9bd8d2174df98af1'),
#  ObjectId('5b9aadaa9bd8d2174df98af2'),
#  ObjectId('5b9aadaa9bd8d2174df98af3'),
#  ObjectId('5b9aadaa9bd8d2174df98af4'),
#  ObjectId('5b9aadaa9bd8d2174df98af5'),
#  ObjectId('5b9aadaa9bd8d2174df98af6'),
#  ObjectId('5b9aadaa9bd8d2174df98af7'),
#  ObjectId('5b9aadaa9bd8d2174df98af8'),
#  ObjectId('5b9aadaa9bd8d2174df98af9'),
#  ObjectId('5b9aadaa9bd8d2174df98afa'),
#  ObjectId('5b9aadaa9bd8d2174df98afb'),
#  ObjectId('5b9aadaa9bd8d2174df98afc'),
#  ObjectId('5b9aadaa9bd8d2174df98afd'),
#  ObjectId('5b9aadaa9bd8d2174df98afe'),
#  ObjectId('5b9aadaa9bd8d2174df98aff'),
#  ObjectId('5b9aadaa9bd8d2174df98b00'),
#  ObjectId('5b9aadaa9bd8d2174df98b01'),
#  ObjectId('5b9aadaa9bd8d2174df98b02'),
#  ObjectId('5b9aadaa9bd8d2174df98b03'),
#  ObjectId('5b9aadaa9bd8d2174df98b04'),
#  ObjectId('5b9aadaa9bd8d2174df98b05'),
#  ObjectId('5b9aadaa9bd8d2174df98b06'),
#  ObjectId('5b9aadaa9bd8d2174df98b07'),
#  ObjectId('5b9aadaa9bd8d2174df98b08'),
#  ObjectId('5b9aadaa9bd8d2174df98b09'),
#  ObjectId('5b9aadaa9bd8d2174df98b0a'),
#  ObjectId('5b9aadaa9bd8d2174df98b0b'),
#  ObjectId('5b9aadaa9bd8d2174df98b0c'),
#  ObjectId('5b9aadaa9bd8d2174df98b0d'),
#  ObjectId('5b9aadaa9bd8d2174df98b0e'),
#  ObjectId('5b9aadaa9bd8d2174df98b0f'),
#  ObjectId('5b9aadaa9bd8d2174df98b10'),
#  ObjectId('5b9aadaa9bd8d2174df98b11'),
#  ObjectId('5b9aadaa9bd8d2174df98b12'),
#  ObjectId('5b9aadaa9bd8d2174df98b13'),
#  ObjectId('5b9aadaa9bd8d2174df98b14'),
#  ObjectId('5b9aadaa9bd8d2174df98b15'),
#  ObjectId('5b9aadaa9bd8d2174df98b16'),
#  ObjectId('5b9aadaa9bd8d2174df98b17'),
#  ObjectId('5b9aadaa9bd8d2174df98b18'),
#  ObjectId('5b9aadaa9bd8d2174df98b19'),
#  ObjectId('5b9aadaa9bd8d2174df98b1a'),
#  ObjectId('5b9aadaa9bd8d2174df98b1b'),
#  ObjectId('5b9aadaa9bd8d2174df98b1c'),
#  ObjectId('5b9aadaa9bd8d2174df98b1d'),
#  ObjectId('5b9aadaa9bd8d2174df98b1e'),
#  ObjectId('5b9aadaa9bd8d2174df98b1f'),
#  ObjectId('5b9aadaa9bd8d2174df98b20'),
#  ObjectId('5b9aadaa9bd8d2174df98b21'),
#  ObjectId('5b9aadaa9bd8d2174df98b22'),
#  ObjectId('5b9aadaa9bd8d2174df98b23'),
#  ObjectId('5b9aadaa9bd8d2174df98b24'),
#  ObjectId('5b9aadaa9bd8d2174df98b25'),
#  ObjectId('5b9aadaa9bd8d2174df98b26'),
#  ObjectId('5b9aadaa9bd8d2174df98b27'),
#  ObjectId('5b9aadaa9bd8d2174df98b28'),
#  ObjectId('5b9aadaa9bd8d2174df98b29'),
#  ObjectId('5b9aadaa9bd8d2174df98b2a'),
#  ObjectId('5b9aadaa9bd8d2174df98b2b'),
#  ObjectId('5b9aadaa9bd8d2174df98b2c'),
#  ObjectId('5b9aadaa9bd8d2174df98b2d'),
#  ObjectId('5b9aadaa9bd8d2174df98b2e'),
#  ObjectId('5b9aadaa9bd8d2174df98b2f'),
#  ObjectId('5b9aadaa9bd8d2174df98b30'),
#  ObjectId('5b9aadaa9bd8d2174df98b31'),
#  ObjectId('5b9aadaa9bd8d2174df98b32'),
#  ObjectId('5b9aadaa9bd8d2174df98b33'),
#  ObjectId('5b9aadaa9bd8d2174df98b34'),
#  ObjectId('5b9aadaa9bd8d2174df98b35'),
#  ObjectId('5b9aadaa9bd8d2174df98b36'),
#  ObjectId('5b9aadaa9bd8d2174df98b37'),
#  ObjectId('5b9aadaa9bd8d2174df98b38'),
#  ObjectId('5b9aadaa9bd8d2174df98b39'),
#  ObjectId('5b9aadaa9bd8d2174df98b3a'),
#  ObjectId('5b9aadaa9bd8d2174df98b3b'),
#  ObjectId('5b9aadaa9bd8d2174df98b3c'),
#  ObjectId('5b9aadaa9bd8d2174df98b3d'),
#  ObjectId('5b9aadaa9bd8d2174df98b3e'),
#  ObjectId('5b9aadaa9bd8d2174df98b3f'),
#  ObjectId('5b9aadaa9bd8d2174df98b40'),
#  ObjectId('5b9aadaa9bd8d2174df98b41'),
#  ObjectId('5b9aadaa9bd8d2174df98b42'),
#  ObjectId('5b9aadaa9bd8d2174df98b43'),
#  ObjectId('5b9aadaa9bd8d2174df98b44'),
#  ObjectId('5b9aadaa9bd8d2174df98b45'),
#  ObjectId('5b9aadaa9bd8d2174df98b46'),
#  ObjectId('5b9aadaa9bd8d2174df98b47'),
#  ObjectId('5b9aadaa9bd8d2174df98b48'),
#  ObjectId('5b9aadaa9bd8d2174df98b49'),
#  ObjectId('5b9aadaa9bd8d2174df98b4a'),
#  ObjectId('5b9aadaa9bd8d2174df98b4b'),
#  ObjectId('5b9aadaa9bd8d2174df98b4c'),
#  ObjectId('5b9aadaa9bd8d2174df98b4d'),
#  ObjectId('5b9aadaa9bd8d2174df98b4e'),
#  ObjectId('5b9aadaa9bd8d2174df98b4f'),
#  ObjectId('5b9aadaa9bd8d2174df98b50'),
#  ObjectId('5b9aadaa9bd8d2174df98b51'),
#  ObjectId('5b9aadaa9bd8d2174df98b52'),
#  ObjectId('5b9aadaa9bd8d2174df98b53'),
#  ObjectId('5b9aadaa9bd8d2174df98b54'),
#  ObjectId('5b9aadaa9bd8d2174df98b55'),
#  ObjectId('5b9aadaa9bd8d2174df98b56'),
#  ObjectId('5b9aadaa9bd8d2174df98b57'),
#  ObjectId('5b9aadaa9bd8d2174df98b58'),
#  ObjectId('5b9aadaa9bd8d2174df98b59'),
#  ObjectId('5b9aadaa9bd8d2174df98b5a'),
#  ObjectId('5b9aadaa9bd8d2174df98b5b'),
#  ObjectId('5b9aadaa9bd8d2174df98b5c'),
#  ObjectId('5b9aadaa9bd8d2174df98b5d'),
#  ObjectId('5b9aadaa9bd8d2174df98b5e'),
#  ObjectId('5b9aadaa9bd8d2174df98b5f'),
#  ObjectId('5b9aadaa9bd8d2174df98b60'),
#  ObjectId('5b9aadaa9bd8d2174df98b61'),
#  ObjectId('5b9aadaa9bd8d2174df98b62'),
#  ObjectId('5b9aadaa9bd8d2174df98b63'),
#  ObjectId('5b9aadaa9bd8d2174df98b64'),
#  ObjectId('5b9aadaa9bd8d2174df98b65'),
#  ObjectId('5b9aadaa9bd8d2174df98b66'),
#  ObjectId('5b9aadaa9bd8d2174df98b67'),
#  ObjectId('5b9aadaa9bd8d2174df98b68'),
#  ObjectId('5b9aadaa9bd8d2174df98b69'),
#  ObjectId('5b9aadaa9bd8d2174df98b6a'),
#  ObjectId('5b9aadaa9bd8d2174df98b6b'),
#  ObjectId('5b9aadaa9bd8d2174df98b6c'),
#  ObjectId('5b9aadaa9bd8d2174df98b6d'),
#  ObjectId('5b9aadaa9bd8d2174df98b6e'),
#  ObjectId('5b9aadaa9bd8d2174df98b6f'),
#  ObjectId('5b9aadaa9bd8d2174df98b70'),
#  ObjectId('5b9aadaa9bd8d2174df98b71'),
#  ObjectId('5b9aadaa9bd8d2174df98b72'),
#  ObjectId('5b9aadaa9bd8d2174df98b73'),
#  ObjectId('5b9aadaa9bd8d2174df98b74'),
#  ObjectId('5b9aadaa9bd8d2174df98b75'),
#  ObjectId('5b9aadaa9bd8d2174df98b76'),
#  ObjectId('5b9aadaa9bd8d2174df98b77'),
#  ObjectId('5b9aadaa9bd8d2174df98b78'),
#  ObjectId('5b9aadaa9bd8d2174df98b79'),
#  ObjectId('5b9aadaa9bd8d2174df98b7a'),
#  ObjectId('5b9aadaa9bd8d2174df98b7b'),
#  ObjectId('5b9aadaa9bd8d2174df98b7c'),
#  ObjectId('5b9aadaa9bd8d2174df98b7d'),
#  ObjectId('5b9aadaa9bd8d2174df98b7e'),
#  ObjectId('5b9aadaa9bd8d2174df98b7f'),
#  ObjectId('5b9aadaa9bd8d2174df98b80'),
#  ObjectId('5b9aadaa9bd8d2174df98b81'),
#  ObjectId('5b9aadaa9bd8d2174df98b82'),
#  ObjectId('5b9aadaa9bd8d2174df98b83'),
#  ObjectId('5b9aadaa9bd8d2174df98b84'),
#  ObjectId('5b9aadaa9bd8d2174df98b85'),
#  ObjectId('5b9aadaa9bd8d2174df98b86'),
#  ObjectId('5b9aadaa9bd8d2174df98b87'),
#  ObjectId('5b9aadaa9bd8d2174df98b88'),
#  ObjectId('5b9aadaa9bd8d2174df98b89'),
#  ObjectId('5b9aadaa9bd8d2174df98b8a'),
#  ObjectId('5b9aadaa9bd8d2174df98b8b'),
#  ObjectId('5b9aadaa9bd8d2174df98b8c'),
#  ObjectId('5b9aadaa9bd8d2174df98b8d'),
#  ObjectId('5b9aadaa9bd8d2174df98b8e'),
#  ObjectId('5b9aadaa9bd8d2174df98b8f'),
#  ObjectId('5b9aadaa9bd8d2174df98b90'),
#  ObjectId('5b9aadaa9bd8d2174df98b91'),
#  ObjectId('5b9aadaa9bd8d2174df98b92'),
#  ObjectId('5b9aadaa9bd8d2174df98b93'),
#  ObjectId('5b9aadaa9bd8d2174df98b94'),
#  ObjectId('5b9aadaa9bd8d2174df98b95'),
#  ObjectId('5b9aadaa9bd8d2174df98b96'),
#  ObjectId('5b9aadaa9bd8d2174df98b97'),
#  ObjectId('5b9aadaa9bd8d2174df98b98'),
#  ObjectId('5b9aadaa9bd8d2174df98b99'),
#  ObjectId('5b9aadaa9bd8d2174df98b9a'),
#  ObjectId('5b9aadaa9bd8d2174df98b9b'),
#  ObjectId('5b9aadaa9bd8d2174df98b9c'),
#  ObjectId('5b9aadaa9bd8d2174df98b9d'),
#  ObjectId('5b9aadaa9bd8d2174df98b9e'),
#  ObjectId('5b9aadaa9bd8d2174df98b9f'),
#  ObjectId('5b9aadaa9bd8d2174df98ba0'),
#  ObjectId('5b9aadaa9bd8d2174df98ba1'),
#  ObjectId('5b9aadaa9bd8d2174df98ba2'),
#  ObjectId('5b9aadaa9bd8d2174df98ba3'),
#  ObjectId('5b9aadaa9bd8d2174df98ba4'),
#  ObjectId('5b9aadaa9bd8d2174df98ba5'),
#  ObjectId('5b9aadaa9bd8d2174df98ba6'),
#  ObjectId('5b9aadaa9bd8d2174df98ba7'),
#  ObjectId('5b9aadaa9bd8d2174df98ba8'),
#  ObjectId('5b9aadaa9bd8d2174df98ba9'),
#  ObjectId('5b9aadaa9bd8d2174df98baa'),
#  ObjectId('5b9aadaa9bd8d2174df98bab'),
#  ObjectId('5b9aadaa9bd8d2174df98bac'),
#  ObjectId('5b9aadaa9bd8d2174df98bad'),
#  ObjectId('5b9aadaa9bd8d2174df98bae'),
#  ObjectId('5b9aadaa9bd8d2174df98baf'),
#  ObjectId('5b9aadaa9bd8d2174df98bb0'),
#  ObjectId('5b9aadaa9bd8d2174df98bb1'),
#  ObjectId('5b9aadaa9bd8d2174df98bb2'),
#  ObjectId('5b9aadaa9bd8d2174df98bb3'),
#  ObjectId('5b9aadaa9bd8d2174df98bb4'),
#  ObjectId('5b9aadaa9bd8d2174df98bb5'),
#  ObjectId('5b9aadaa9bd8d2174df98bb6'),
#  ObjectId('5b9aadaa9bd8d2174df98bb7'),
#  ObjectId('5b9aadaa9bd8d2174df98bb8'),
#  ObjectId('5b9aadaa9bd8d2174df98bb9'),
#  ObjectId('5b9aadaa9bd8d2174df98bba'),
#  ObjectId('5b9aadaa9bd8d2174df98bbb'),
#  ObjectId('5b9aadaa9bd8d2174df98bbc'),
#  ObjectId('5b9aadaa9bd8d2174df98bbd'),
#  ObjectId('5b9aadaa9bd8d2174df98bbe'),
#  ObjectId('5b9aadaa9bd8d2174df98bbf'),
#  ObjectId('5b9aadaa9bd8d2174df98bc0'),
#  ObjectId('5b9aadaa9bd8d2174df98bc1'),
#  ObjectId('5b9aadaa9bd8d2174df98bc2'),
#  ObjectId('5b9aadaa9bd8d2174df98bc3'),
#  ObjectId('5b9aadaa9bd8d2174df98bc4'),
#  ObjectId('5b9aadaa9bd8d2174df98bc5'),
#  ObjectId('5b9aadaa9bd8d2174df98bc6'),
#  ObjectId('5b9aadaa9bd8d2174df98bc7'),
#  ObjectId('5b9aadaa9bd8d2174df98bc8'),
#  ObjectId('5b9aadaa9bd8d2174df98bc9'),
#  ObjectId('5b9aadaa9bd8d2174df98bca'),
#  ObjectId('5b9aadaa9bd8d2174df98bcb'),
#  ObjectId('5b9aadaa9bd8d2174df98bcc'),
#  ObjectId('5b9aadaa9bd8d2174df98bcd'),
#  ObjectId('5b9aadaa9bd8d2174df98bce'),
#  ObjectId('5b9aadaa9bd8d2174df98bcf'),
#  ObjectId('5b9aadaa9bd8d2174df98bd0'),
#  ObjectId('5b9aadaa9bd8d2174df98bd1'),
#  ObjectId('5b9aadaa9bd8d2174df98bd2'),
#  ObjectId('5b9aadaa9bd8d2174df98bd3'),
#  ObjectId('5b9aadaa9bd8d2174df98bd4'),
#  ObjectId('5b9aadaa9bd8d2174df98bd5'),
#  ObjectId('5b9aadaa9bd8d2174df98bd6'),
#  ObjectId('5b9aadaa9bd8d2174df98bd7'),
#  ObjectId('5b9aadaa9bd8d2174df98bd8'),
#  ObjectId('5b9aadaa9bd8d2174df98bd9'),
#  ObjectId('5b9aadaa9bd8d2174df98bda'),
#  ObjectId('5b9aadaa9bd8d2174df98bdb'),
#  ObjectId('5b9aadaa9bd8d2174df98bdc'),
#  ObjectId('5b9aadaa9bd8d2174df98bdd'),
#  ObjectId('5b9aadaa9bd8d2174df98bde'),
#  ObjectId('5b9aadaa9bd8d2174df98bdf'),
#  ObjectId('5b9aadaa9bd8d2174df98be0'),
#  ObjectId('5b9aadaa9bd8d2174df98be1'),
#  ObjectId('5b9aadaa9bd8d2174df98be2'),
#  ObjectId('5b9aadaa9bd8d2174df98be3'),
#  ObjectId('5b9aadaa9bd8d2174df98be4'),
#  ObjectId('5b9aadaa9bd8d2174df98be5'),
#  ObjectId('5b9aadaa9bd8d2174df98be6'),
#  ObjectId('5b9aadaa9bd8d2174df98be7'),
#  ObjectId('5b9aadaa9bd8d2174df98be8'),
#  ObjectId('5b9aadaa9bd8d2174df98be9'),
#  ObjectId('5b9aadaa9bd8d2174df98bea'),
#  ObjectId('5b9aadaa9bd8d2174df98beb'),
#  ObjectId('5b9aadaa9bd8d2174df98bec'),
#  ObjectId('5b9aadaa9bd8d2174df98bed'),
#  ObjectId('5b9aadaa9bd8d2174df98bee'),
#  ObjectId('5b9aadaa9bd8d2174df98bef'),
#  ObjectId('5b9aadaa9bd8d2174df98bf0'),
#  ObjectId('5b9aadaa9bd8d2174df98bf1'),
#  ObjectId('5b9aadaa9bd8d2174df98bf2'),
#  ObjectId('5b9aadaa9bd8d2174df98bf3'),
#  ObjectId('5b9aadaa9bd8d2174df98bf4'),
#  ObjectId('5b9aadaa9bd8d2174df98bf5'),
#  ObjectId('5b9aadaa9bd8d2174df98bf6'),
#  ObjectId('5b9aadaa9bd8d2174df98bf7'),
#  ObjectId('5b9aadaa9bd8d2174df98bf8'),
#  ObjectId('5b9aadaa9bd8d2174df98bf9'),
#  ObjectId('5b9aadaa9bd8d2174df98bfa'),
#  ObjectId('5b9aadaa9bd8d2174df98bfb'),
#  ObjectId('5b9aadaa9bd8d2174df98bfc'),
#  ObjectId('5b9aadaa9bd8d2174df98bfd'),
#  ObjectId('5b9aadaa9bd8d2174df98bfe'),
#  ObjectId('5b9aadaa9bd8d2174df98bff'),
#  ObjectId('5b9aadaa9bd8d2174df98c00'),
#  ObjectId('5b9aadaa9bd8d2174df98c01'),
#  ObjectId('5b9aadaa9bd8d2174df98c02'),
#  ObjectId('5b9aadaa9bd8d2174df98c03'),
#  ObjectId('5b9aadaa9bd8d2174df98c04'),
#  ObjectId('5b9aadaa9bd8d2174df98c05'),
#  ObjectId('5b9aadaa9bd8d2174df98c06'),
#  ObjectId('5b9aadaa9bd8d2174df98c07'),
#  ObjectId('5b9aadaa9bd8d2174df98c08'),
#  ObjectId('5b9aadaa9bd8d2174df98c09'),
#  ObjectId('5b9aadaa9bd8d2174df98c0a'),
#  ObjectId('5b9aadaa9bd8d2174df98c0b'),
#  ObjectId('5b9aadaa9bd8d2174df98c0c'),
#  ObjectId('5b9aadaa9bd8d2174df98c0d'),
#  ObjectId('5b9aadaa9bd8d2174df98c0e'),
#  ObjectId('5b9aadaa9bd8d2174df98c0f'),
#  ObjectId('5b9aadaa9bd8d2174df98c10'),
#  ObjectId('5b9aadaa9bd8d2174df98c11'),
#  ObjectId('5b9aadaa9bd8d2174df98c12'),
#  ObjectId('5b9aadaa9bd8d2174df98c13'),
#  ObjectId('5b9aadaa9bd8d2174df98c14'),
#  ObjectId('5b9aadaa9bd8d2174df98c15'),
#  ObjectId('5b9aadaa9bd8d2174df98c16'),
#  ObjectId('5b9aadaa9bd8d2174df98c17'),
#  ObjectId('5b9aadaa9bd8d2174df98c18'),
#  ObjectId('5b9aadaa9bd8d2174df98c19'),
#  ObjectId('5b9aadaa9bd8d2174df98c1a'),
#  ObjectId('5b9aadaa9bd8d2174df98c1b'),
#  ObjectId('5b9aadaa9bd8d2174df98c1c'),
#  ObjectId('5b9aadaa9bd8d2174df98c1d'),
#  ObjectId('5b9aadaa9bd8d2174df98c1e'),
#  ObjectId('5b9aadaa9bd8d2174df98c1f'),
#  ObjectId('5b9aadaa9bd8d2174df98c20'),
#  ObjectId('5b9aadaa9bd8d2174df98c21'),
#  ObjectId('5b9aadaa9bd8d2174df98c22'),
#  ObjectId('5b9aadaa9bd8d2174df98c23'),
#  ObjectId('5b9aadaa9bd8d2174df98c24'),
#  ObjectId('5b9aadaa9bd8d2174df98c25'),
#  ObjectId('5b9aadaa9bd8d2174df98c26'),
#  ObjectId('5b9aadaa9bd8d2174df98c27'),
#  ObjectId('5b9aadaa9bd8d2174df98c28'),
#  ObjectId('5b9aadaa9bd8d2174df98c29'),
#  ObjectId('5b9aadaa9bd8d2174df98c2a'),
#  ObjectId('5b9aadaa9bd8d2174df98c2b'),
#  ObjectId('5b9aadaa9bd8d2174df98c2c'),
#  ObjectId('5b9aadaa9bd8d2174df98c2d'),
#  ObjectId('5b9aadaa9bd8d2174df98c2e'),
#  ObjectId('5b9aadaa9bd8d2174df98c2f'),
#  ObjectId('5b9aadaa9bd8d2174df98c30'),
#  ObjectId('5b9aadaa9bd8d2174df98c31'),
#  ObjectId('5b9aadaa9bd8d2174df98c32'),
#  ObjectId('5b9aadaa9bd8d2174df98c33'),
#  ObjectId('5b9aadaa9bd8d2174df98c34'),
#  ObjectId('5b9aadaa9bd8d2174df98c35'),
#  ObjectId('5b9aadaa9bd8d2174df98c36'),
#  ObjectId('5b9aadaa9bd8d2174df98c37'),
#  ObjectId('5b9aadaa9bd8d2174df98c38'),
#  ObjectId('5b9aadaa9bd8d2174df98c39'),
#  ObjectId('5b9aadaa9bd8d2174df98c3a'),
#  ObjectId('5b9aadaa9bd8d2174df98c3b'),
#  ObjectId('5b9aadaa9bd8d2174df98c3c'),
#  ObjectId('5b9aadaa9bd8d2174df98c3d'),
#  ObjectId('5b9aadaa9bd8d2174df98c3e'),
#  ObjectId('5b9aadaa9bd8d2174df98c3f'),
#  ObjectId('5b9aadaa9bd8d2174df98c40'),
#  ObjectId('5b9aadaa9bd8d2174df98c41'),
#  ObjectId('5b9aadaa9bd8d2174df98c42'),
#  ObjectId('5b9aadaa9bd8d2174df98c43'),
#  ObjectId('5b9aadaa9bd8d2174df98c44'),
#  ObjectId('5b9aadaa9bd8d2174df98c45'),
#  ObjectId('5b9aadaa9bd8d2174df98c46'),
#  ObjectId('5b9aadaa9bd8d2174df98c47'),
#  ObjectId('5b9aadaa9bd8d2174df98c48'),
#  ObjectId('5b9aadaa9bd8d2174df98c49'),
#  ObjectId('5b9aadaa9bd8d2174df98c4a'),
#  ObjectId('5b9aadaa9bd8d2174df98c4b'),
#  ObjectId('5b9aadaa9bd8d2174df98c4c'),
#  ObjectId('5b9aadaa9bd8d2174df98c4d'),
#  ObjectId('5b9aadaa9bd8d2174df98c4e'),
#  ObjectId('5b9aadaa9bd8d2174df98c4f'),
#  ObjectId('5b9aadaa9bd8d2174df98c50'),
#  ObjectId('5b9aadaa9bd8d2174df98c51'),
#  ObjectId('5b9aadaa9bd8d2174df98c52'),
#  ObjectId('5b9aadaa9bd8d2174df98c53'),
#  ObjectId('5b9aadaa9bd8d2174df98c54'),
#  ObjectId('5b9aadaa9bd8d2174df98c55'),
#  ObjectId('5b9aadaa9bd8d2174df98c56'),
#  ObjectId('5b9aadaa9bd8d2174df98c57'),
#  ObjectId('5b9aadaa9bd8d2174df98c58'),
#  ObjectId('5b9aadaa9bd8d2174df98c59'),
#  ObjectId('5b9aadaa9bd8d2174df98c5a'),
#  ObjectId('5b9aadaa9bd8d2174df98c5b'),
#  ObjectId('5b9aadaa9bd8d2174df98c5c'),
#  ObjectId('5b9aadaa9bd8d2174df98c5d'),
#  ObjectId('5b9aadaa9bd8d2174df98c5e'),
#  ObjectId('5b9aadaa9bd8d2174df98c5f'),
#  ObjectId('5b9aadaa9bd8d2174df98c60'),
#  ObjectId('5b9aadaa9bd8d2174df98c61'),
#  ObjectId('5b9aadaa9bd8d2174df98c62'),
#  ObjectId('5b9aadaa9bd8d2174df98c63'),
#  ObjectId('5b9aadaa9bd8d2174df98c64'),
#  ObjectId('5b9aadaa9bd8d2174df98c65'),
#  ObjectId('5b9aadaa9bd8d2174df98c66'),
#  ObjectId('5b9aadaa9bd8d2174df98c67'),
#  ObjectId('5b9aadaa9bd8d2174df98c68'),
#  ObjectId('5b9aadaa9bd8d2174df98c69'),
#  ObjectId('5b9aadaa9bd8d2174df98c6a'),
#  ObjectId('5b9aadaa9bd8d2174df98c6b'),
#  ObjectId('5b9aadaa9bd8d2174df98c6c'),
#  ObjectId('5b9aadaa9bd8d2174df98c6d'),
#  ObjectId('5b9aadaa9bd8d2174df98c6e'),
#  ObjectId('5b9aadaa9bd8d2174df98c6f'),
#  ObjectId('5b9aadaa9bd8d2174df98c70'),
#  ObjectId('5b9aadaa9bd8d2174df98c71'),
#  ObjectId('5b9aadaa9bd8d2174df98c72'),
#  ObjectId('5b9aadaa9bd8d2174df98c73'),
#  ObjectId('5b9aadaa9bd8d2174df98c74'),
#  ObjectId('5b9aadaa9bd8d2174df98c75'),
#  ObjectId('5b9aadaa9bd8d2174df98c76'),
#  ObjectId('5b9aadaa9bd8d2174df98c77'),
#  ObjectId('5b9aadaa9bd8d2174df98c78'),
#  ObjectId('5b9aadaa9bd8d2174df98c79'),
#  ObjectId('5b9aadaa9bd8d2174df98c7a'),
#  ObjectId('5b9aadaa9bd8d2174df98c7b'),
#  ObjectId('5b9aadaa9bd8d2174df98c7c'),
#  ObjectId('5b9aadaa9bd8d2174df98c7d'),
#  ObjectId('5b9aadaa9bd8d2174df98c7e'),
#  ObjectId('5b9aadaa9bd8d2174df98c7f'),
#  ObjectId('5b9aadaa9bd8d2174df98c80'),
#  ObjectId('5b9aadaa9bd8d2174df98c81'),
#  ObjectId('5b9aadaa9bd8d2174df98c82'),
#  ObjectId('5b9aadaa9bd8d2174df98c83'),
#  ObjectId('5b9aadaa9bd8d2174df98c84'),
#  ObjectId('5b9aadaa9bd8d2174df98c85'),
#  ObjectId('5b9aadaa9bd8d2174df98c86'),
#  ObjectId('5b9aadaa9bd8d2174df98c87'),
#  ObjectId('5b9aadaa9bd8d2174df98c88'),
#  ObjectId('5b9aadaa9bd8d2174df98c89'),
#  ObjectId('5b9aadaa9bd8d2174df98c8a'),
#  ObjectId('5b9aadaa9bd8d2174df98c8b'),
#  ObjectId('5b9aadaa9bd8d2174df98c8c'),
#  ObjectId('5b9aadaa9bd8d2174df98c8d'),
#  ObjectId('5b9aadaa9bd8d2174df98c8e'),
#  ObjectId('5b9aadaa9bd8d2174df98c8f'),
#  ObjectId('5b9aadaa9bd8d2174df98c90'),
#  ObjectId('5b9aadaa9bd8d2174df98c91'),
#  ObjectId('5b9aadaa9bd8d2174df98c92'),
#  ObjectId('5b9aadaa9bd8d2174df98c93'),
#  ObjectId('5b9aadaa9bd8d2174df98c94'),
#  ObjectId('5b9aadaa9bd8d2174df98c95'),
#  ObjectId('5b9aadaa9bd8d2174df98c96'),
#  ObjectId('5b9aadaa9bd8d2174df98c97'),
#  ObjectId('5b9aadaa9bd8d2174df98c98'),
#  ObjectId('5b9aadaa9bd8d2174df98c99'),
#  ObjectId('5b9aadaa9bd8d2174df98c9a'),
#  ObjectId('5b9aadaa9bd8d2174df98c9b'),
#  ObjectId('5b9aadaa9bd8d2174df98c9c'),
#  ObjectId('5b9aadaa9bd8d2174df98c9d'),
#  ObjectId('5b9aadaa9bd8d2174df98c9e'),
#  ObjectId('5b9aadaa9bd8d2174df98c9f'),
#  ObjectId('5b9aadaa9bd8d2174df98ca0'),
#  ObjectId('5b9aadaa9bd8d2174df98ca1'),
#  ObjectId('5b9aadaa9bd8d2174df98ca2'),
#  ObjectId('5b9aadaa9bd8d2174df98ca3'),
#  ObjectId('5b9aadaa9bd8d2174df98ca4'),
#  ObjectId('5b9aadaa9bd8d2174df98ca5'),
#  ObjectId('5b9aadaa9bd8d2174df98ca6'),
#  ObjectId('5b9aadaa9bd8d2174df98ca7'),
#  ObjectId('5b9aadaa9bd8d2174df98ca8'),
#  ObjectId('5b9aadaa9bd8d2174df98ca9'),
#  ObjectId('5b9aadaa9bd8d2174df98caa'),
#  ObjectId('5b9aadaa9bd8d2174df98cab'),
#  ObjectId('5b9aadaa9bd8d2174df98cac'),
#  ObjectId('5b9aadaa9bd8d2174df98cad'),
#  ObjectId('5b9aadaa9bd8d2174df98cae'),
#  ObjectId('5b9aadaa9bd8d2174df98caf'),
#  ObjectId('5b9aadaa9bd8d2174df98cb0'),
#  ObjectId('5b9aadaa9bd8d2174df98cb1'),
#  ObjectId('5b9aadaa9bd8d2174df98cb2'),
#  ObjectId('5b9aadaa9bd8d2174df98cb3'),
#  ObjectId('5b9aadaa9bd8d2174df98cb4'),
#  ObjectId('5b9aadaa9bd8d2174df98cb5'),
#  ObjectId('5b9aadaa9bd8d2174df98cb6'),
#  ObjectId('5b9aadaa9bd8d2174df98cb7'),
#  ObjectId('5b9aadaa9bd8d2174df98cb8'),
#  ObjectId('5b9aadaa9bd8d2174df98cb9'),
#  ObjectId('5b9aadaa9bd8d2174df98cba'),
#  ObjectId('5b9aadaa9bd8d2174df98cbb'),
#  ObjectId('5b9aadaa9bd8d2174df98cbc'),
#  ObjectId('5b9aadaa9bd8d2174df98cbd'),
#  ObjectId('5b9aadaa9bd8d2174df98cbe'),
#  ObjectId('5b9aadaa9bd8d2174df98cbf'),
#  ObjectId('5b9aadaa9bd8d2174df98cc0'),
#  ObjectId('5b9aadaa9bd8d2174df98cc1'),
#  ObjectId('5b9aadaa9bd8d2174df98cc2'),
#  ObjectId('5b9aadaa9bd8d2174df98cc3'),
#  ObjectId('5b9aadaa9bd8d2174df98cc4'),
#  ObjectId('5b9aadaa9bd8d2174df98cc5'),
#  ObjectId('5b9aadaa9bd8d2174df98cc6'),
#  ObjectId('5b9aadaa9bd8d2174df98cc7'),
#  ObjectId('5b9aadaa9bd8d2174df98cc8'),
#  ObjectId('5b9aadaa9bd8d2174df98cc9'),
#  ObjectId('5b9aadaa9bd8d2174df98cca'),
#  ObjectId('5b9aadaa9bd8d2174df98ccb'),
#  ObjectId('5b9aadaa9bd8d2174df98ccc'),
#  ObjectId('5b9aadaa9bd8d2174df98ccd'),
#  ObjectId('5b9aadaa9bd8d2174df98cce'),
#  ObjectId('5b9aadaa9bd8d2174df98ccf'),
#  ObjectId('5b9aadaa9bd8d2174df98cd0'),
#  ObjectId('5b9aadaa9bd8d2174df98cd1'),
#  ObjectId('5b9aadaa9bd8d2174df98cd2'),
#  ObjectId('5b9aadaa9bd8d2174df98cd3'),
#  ObjectId('5b9aadaa9bd8d2174df98cd4'),
#  ObjectId('5b9aadaa9bd8d2174df98cd5'),
#  ObjectId('5b9aadaa9bd8d2174df98cd6'),
#  ObjectId('5b9aadaa9bd8d2174df98cd7'),
#  ObjectId('5b9aadaa9bd8d2174df98cd8'),
#  ObjectId('5b9aadaa9bd8d2174df98cd9'),
#  ObjectId('5b9aadaa9bd8d2174df98cda'),
#  ObjectId('5b9aadaa9bd8d2174df98cdb'),
#  ObjectId('5b9aadaa9bd8d2174df98cdc'),
#  ObjectId('5b9aadaa9bd8d2174df98cdd'),
#  ObjectId('5b9aadaa9bd8d2174df98cde'),
#  ObjectId('5b9aadaa9bd8d2174df98cdf'),
#  ObjectId('5b9aadaa9bd8d2174df98ce0'),
#  ObjectId('5b9aadaa9bd8d2174df98ce1'),
#  ObjectId('5b9aadaa9bd8d2174df98ce2'),
#  ObjectId('5b9aadaa9bd8d2174df98ce3'),
#  ObjectId('5b9aadaa9bd8d2174df98ce4'),
#  ObjectId('5b9aadaa9bd8d2174df98ce5'),
#  ObjectId('5b9aadaa9bd8d2174df98ce6'),
#  ObjectId('5b9aadaa9bd8d2174df98ce7'),
#  ObjectId('5b9aadaa9bd8d2174df98ce8'),
#  ObjectId('5b9aadaa9bd8d2174df98ce9'),
#  ObjectId('5b9aadaa9bd8d2174df98cea'),
#  ObjectId('5b9aadaa9bd8d2174df98ceb'),
#  ObjectId('5b9aadaa9bd8d2174df98cec'),
#  ObjectId('5b9aadaa9bd8d2174df98ced'),
#  ObjectId('5b9aadaa9bd8d2174df98cee'),
#  ObjectId('5b9aadaa9bd8d2174df98cef'),
#  ObjectId('5b9aadaa9bd8d2174df98cf0'),
#  ObjectId('5b9aadaa9bd8d2174df98cf1'),
#  ObjectId('5b9aadaa9bd8d2174df98cf2'),
#  ObjectId('5b9aadaa9bd8d2174df98cf3'),
#  ObjectId('5b9aadaa9bd8d2174df98cf4'),
#  ObjectId('5b9aadaa9bd8d2174df98cf5'),
#  ObjectId('5b9aadaa9bd8d2174df98cf6'),
#  ObjectId('5b9aadaa9bd8d2174df98cf7'),
#  ObjectId('5b9aadaa9bd8d2174df98cf8'),
#  ObjectId('5b9aadaa9bd8d2174df98cf9'),
#  ObjectId('5b9aadaa9bd8d2174df98cfa'),
#  ObjectId('5b9aadaa9bd8d2174df98cfb'),
#  ObjectId('5b9aadaa9bd8d2174df98cfc'),
#  ObjectId('5b9aadaa9bd8d2174df98cfd'),
#  ObjectId('5b9aadaa9bd8d2174df98cfe'),
#  ObjectId('5b9aadaa9bd8d2174df98cff'),
#  ObjectId('5b9aadaa9bd8d2174df98d00'),
#  ObjectId('5b9aadaa9bd8d2174df98d01'),
#  ObjectId('5b9aadaa9bd8d2174df98d02'),
#  ObjectId('5b9aadaa9bd8d2174df98d03'),
#  ObjectId('5b9aadaa9bd8d2174df98d04'),
#  ObjectId('5b9aadaa9bd8d2174df98d05'),
#  ObjectId('5b9aadaa9bd8d2174df98d06'),
#  ObjectId('5b9aadaa9bd8d2174df98d07'),
#  ObjectId('5b9aadaa9bd8d2174df98d08'),
#  ObjectId('5b9aadaa9bd8d2174df98d09'),
#  ObjectId('5b9aadaa9bd8d2174df98d0a'),
#  ObjectId('5b9aadaa9bd8d2174df98d0b'),
#  ObjectId('5b9aadaa9bd8d2174df98d0c'),
#  ObjectId('5b9aadaa9bd8d2174df98d0d'),
#  ObjectId('5b9aadaa9bd8d2174df98d0e'),
#  ObjectId('5b9aadaa9bd8d2174df98d0f'),
#  ObjectId('5b9aadaa9bd8d2174df98d10'),
#  ObjectId('5b9aadaa9bd8d2174df98d11'),
#  ObjectId('5b9aadaa9bd8d2174df98d12'),
#  ObjectId('5b9aadaa9bd8d2174df98d13'),
#  ObjectId('5b9aadaa9bd8d2174df98d14'),
#  ObjectId('5b9aadaa9bd8d2174df98d15'),
#  ObjectId('5b9aadaa9bd8d2174df98d16'),
#  ObjectId('5b9aadaa9bd8d2174df98d17'),
#  ObjectId('5b9aadaa9bd8d2174df98d18'),
#  ObjectId('5b9aadaa9bd8d2174df98d19'),
#  ObjectId('5b9aadaa9bd8d2174df98d1a'),
#  ObjectId('5b9aadaa9bd8d2174df98d1b'),
#  ObjectId('5b9aadaa9bd8d2174df98d1c'),
#  ObjectId('5b9aadaa9bd8d2174df98d1d'),
#  ObjectId('5b9aadaa9bd8d2174df98d1e'),
#  ObjectId('5b9aadaa9bd8d2174df98d1f'),
#  ObjectId('5b9aadaa9bd8d2174df98d20'),
#  ObjectId('5b9aadaa9bd8d2174df98d21'),
#  ObjectId('5b9aadaa9bd8d2174df98d22'),
#  ObjectId('5b9aadaa9bd8d2174df98d23'),
#  ObjectId('5b9aadaa9bd8d2174df98d24'),
#  ObjectId('5b9aadaa9bd8d2174df98d25'),
#  ObjectId('5b9aadaa9bd8d2174df98d26'),
#  ObjectId('5b9aadaa9bd8d2174df98d27'),
#  ObjectId('5b9aadaa9bd8d2174df98d28'),
#  ObjectId('5b9aadaa9bd8d2174df98d29'),
#  ObjectId('5b9aadaa9bd8d2174df98d2a'),
#  ObjectId('5b9aadaa9bd8d2174df98d2b'),
#  ObjectId('5b9aadaa9bd8d2174df98d2c'),
#  ObjectId('5b9aadaa9bd8d2174df98d2d'),
#  ObjectId('5b9aadaa9bd8d2174df98d2e'),
#  ObjectId('5b9aadaa9bd8d2174df98d2f'),
#  ObjectId('5b9aadaa9bd8d2174df98d30'),
#  ObjectId('5b9aadaa9bd8d2174df98d31'),
#  ObjectId('5b9aadaa9bd8d2174df98d32'),
#  ObjectId('5b9aadaa9bd8d2174df98d33'),
#  ObjectId('5b9aadaa9bd8d2174df98d34'),
#  ObjectId('5b9aadaa9bd8d2174df98d35'),
#  ObjectId('5b9aadaa9bd8d2174df98d36'),
#  ObjectId('5b9aadaa9bd8d2174df98d37'),
#  ObjectId('5b9aadaa9bd8d2174df98d38'),
#  ObjectId('5b9aadaa9bd8d2174df98d39'),
#  ObjectId('5b9aadaa9bd8d2174df98d3a'),
#  ObjectId('5b9aadaa9bd8d2174df98d3b'),
#  ObjectId('5b9aadaa9bd8d2174df98d3c'),
#  ObjectId('5b9aadaa9bd8d2174df98d3d'),
#  ObjectId('5b9aadaa9bd8d2174df98d3e'),
#  ObjectId('5b9aadaa9bd8d2174df98d3f'),
#  ObjectId('5b9aadaa9bd8d2174df98d40'),
#  ObjectId('5b9aadaa9bd8d2174df98d41'),
#  ObjectId('5b9aadaa9bd8d2174df98d42'),
#  ObjectId('5b9aadaa9bd8d2174df98d43'),
#  ObjectId('5b9aadaa9bd8d2174df98d44'),
#  ObjectId('5b9aadaa9bd8d2174df98d45'),
#  ObjectId('5b9aadaa9bd8d2174df98d46'),
#  ObjectId('5b9aadaa9bd8d2174df98d47'),
#  ObjectId('5b9aadaa9bd8d2174df98d48'),
#  ObjectId('5b9aadaa9bd8d2174df98d49'),
#  ObjectId('5b9aadaa9bd8d2174df98d4a'),
#  ObjectId('5b9aadaa9bd8d2174df98d4b'),
#  ObjectId('5b9aadaa9bd8d2174df98d4c'),
#  ObjectId('5b9aadaa9bd8d2174df98d4d'),
#  ObjectId('5b9aadaa9bd8d2174df98d4e'),
#  ObjectId('5b9aadaa9bd8d2174df98d4f'),
#  ObjectId('5b9aadaa9bd8d2174df98d50'),
#  ObjectId('5b9aadaa9bd8d2174df98d51'),
#  ObjectId('5b9aadaa9bd8d2174df98d52'),
#  ObjectId('5b9aadaa9bd8d2174df98d53'),
#  ObjectId('5b9aadaa9bd8d2174df98d54'),
#  ObjectId('5b9aadaa9bd8d2174df98d55'),
#  ObjectId('5b9aadaa9bd8d2174df98d56'),
#  ObjectId('5b9aadaa9bd8d2174df98d57'),
#  ObjectId('5b9aadaa9bd8d2174df98d58'),
#  ObjectId('5b9aadaa9bd8d2174df98d59'),
#  ObjectId('5b9aadaa9bd8d2174df98d5a'),
#  ObjectId('5b9aadaa9bd8d2174df98d5b'),
#  ObjectId('5b9aadaa9bd8d2174df98d5c'),
#  ObjectId('5b9aadaa9bd8d2174df98d5d'),
#  ObjectId('5b9aadaa9bd8d2174df98d5e'),
#  ObjectId('5b9aadaa9bd8d2174df98d5f'),
#  ObjectId('5b9aadaa9bd8d2174df98d60'),
#  ObjectId('5b9aadaa9bd8d2174df98d61'),
#  ObjectId('5b9aadaa9bd8d2174df98d62'),
#  ObjectId('5b9aadaa9bd8d2174df98d63'),
#  ObjectId('5b9aadaa9bd8d2174df98d64'),
#  ObjectId('5b9aadaa9bd8d2174df98d65'),
#  ObjectId('5b9aadaa9bd8d2174df98d66'),
#  ObjectId('5b9aadaa9bd8d2174df98d67'),
#  ObjectId('5b9aadaa9bd8d2174df98d68'),
#  ObjectId('5b9aadaa9bd8d2174df98d69'),
#  ObjectId('5b9aadaa9bd8d2174df98d6a'),
#  ObjectId('5b9aadaa9bd8d2174df98d6b'),
#  ObjectId('5b9aadaa9bd8d2174df98d6c'),
#  ObjectId('5b9aadaa9bd8d2174df98d6d'),
#  ObjectId('5b9aadaa9bd8d2174df98d6e'),
#  ObjectId('5b9aadaa9bd8d2174df98d6f'),
#  ObjectId('5b9aadaa9bd8d2174df98d70'),
#  ObjectId('5b9aadaa9bd8d2174df98d71'),
#  ObjectId('5b9aadaa9bd8d2174df98d72'),
#  ObjectId('5b9aadaa9bd8d2174df98d73'),
#  ObjectId('5b9aadaa9bd8d2174df98d74'),
#  ObjectId('5b9aadaa9bd8d2174df98d75'),
#  ObjectId('5b9aadaa9bd8d2174df98d76'),
#  ObjectId('5b9aadaa9bd8d2174df98d77'),
#  ObjectId('5b9aadaa9bd8d2174df98d78'),
#  ObjectId('5b9aadaa9bd8d2174df98d79'),
#  ObjectId('5b9aadaa9bd8d2174df98d7a'),
#  ObjectId('5b9aadaa9bd8d2174df98d7b'),
#  ObjectId('5b9aadaa9bd8d2174df98d7c'),
#  ObjectId('5b9aadaa9bd8d2174df98d7d'),
#  ObjectId('5b9aadaa9bd8d2174df98d7e'),
#  ObjectId('5b9aadaa9bd8d2174df98d7f'),
#  ObjectId('5b9aadaa9bd8d2174df98d80'),
#  ...]

# %% [markdown]
# ### TFIDF Vectorizer

# %%
# set ngram range, stop words only english, regex patterns, set to lowercase
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 2),  
                                   stop_words='english', 
                                   token_pattern="\\b[a-z][a-z]+\\b",
                                   lowercase=True)

tfidf_data = tfidf_vectorizer.fit_transform(df_combined['text'])

# %%
with open('tfidf_vectorizer.pkl','wb') as file:
    pickle.dump(tfidf_vectorizer,file)

# %% [markdown]
# #### LSA

# %%
lsa_tfidf = TruncatedSVD(n_components=100) # set to 100 dimensions

# fit and transform the text
lsa_tfidf_data = lsa_tfidf.fit_transform(tfidf_data)

# %%
# combine the lsa_tfidf text with the non-vectorized features
TFIDF_LSA = pd.concat([pd.DataFrame(lsa_tfidf_data),df[['y','Analyst','Scientist','Engineer','Start Dates','Bachelors',
                                                'Masters','PhD']]],axis=1)

# %%
TFIDF_LSA.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.116538  0.064366 -0.048105  0.031719 -0.016665  0.017482 -0.034778
# 1  0.142568  0.124692  0.021172 -0.040459  0.040853 -0.019980 -0.037097
# 2  0.296641 -0.054903 -0.090104  0.000666  0.012748 -0.012809  0.027657
# 3  0.104624  0.012313 -0.016656 -0.013489  0.014368  0.027677 -0.005994
# 4  0.111532  0.030344 -0.037361  0.048654  0.012509  0.025820  0.000665
#
#           7         8         9 ...         98        99         y  Analyst  \
# 0 -0.048679 -0.017124 -0.001049 ...  -0.002355 -0.015654   Analyst        1
# 1 -0.008927  0.024049 -0.008748 ...   0.013125  0.015625   Analyst        1
# 2  0.037692 -0.057642 -0.070316 ...  -0.018806 -0.005984  Engineer        0
# 3 -0.018574 -0.008545 -0.037078 ...   0.006485 -0.011479   Analyst        1
# 4  0.112654 -0.025883  0.088656 ...   0.002234 -0.019777  Engineer        0
#
#    Scientist  Engineer  Start Dates  Bachelors  Masters  PhD
# 0          0         0            6          1        0    0
# 1          0         0            2          1        0    0
# 2          0         1           18          1        1    0
# 3          0         0            5          1        0    0
# 4          0         1            8          1        1    0
#
# [5 rows x 108 columns]

# %% [markdown]
# #### Store data in MongoDB and pickle files.

# %%
with open('LSA_TFIDF.pkl','wb') as file:
    pickle.dump(lsa_tfidf,file)
with open('TFIDF_LSA_data.pkl','wb') as file:
    pickle.dump(TFIDF_LSA,file)

# %%
client = MongoClient('localhost', 27017)
db = client['resumes']

TFIDF_LSA_coll = json.loads(TFIDF_LSA.T.to_json()).values()
db.lsa_tfidf.insert(TFIDF_LSA_coll)
# Out:
# [ObjectId('5b9aadb39bd8d2174df9dbe6'),
#  ObjectId('5b9aadb39bd8d2174df9dbe7'),
#  ObjectId('5b9aadb39bd8d2174df9dbe8'),
#  ObjectId('5b9aadb39bd8d2174df9dbe9'),
#  ObjectId('5b9aadb39bd8d2174df9dbea'),
#  ObjectId('5b9aadb39bd8d2174df9dbeb'),
#  ObjectId('5b9aadb39bd8d2174df9dbec'),
#  ObjectId('5b9aadb39bd8d2174df9dbed'),
#  ObjectId('5b9aadb39bd8d2174df9dbee'),
#  ObjectId('5b9aadb39bd8d2174df9dbef'),
#  ObjectId('5b9aadb39bd8d2174df9dbf0'),
#  ObjectId('5b9aadb39bd8d2174df9dbf1'),
#  ObjectId('5b9aadb39bd8d2174df9dbf2'),
#  ObjectId('5b9aadb39bd8d2174df9dbf3'),
#  ObjectId('5b9aadb39bd8d2174df9dbf4'),
#  ObjectId('5b9aadb39bd8d2174df9dbf5'),
#  ObjectId('5b9aadb39bd8d2174df9dbf6'),
#  ObjectId('5b9aadb39bd8d2174df9dbf7'),
#  ObjectId('5b9aadb39bd8d2174df9dbf8'),
#  ObjectId('5b9aadb39bd8d2174df9dbf9'),
#  ObjectId('5b9aadb39bd8d2174df9dbfa'),
#  ObjectId('5b9aadb39bd8d2174df9dbfb'),
#  ObjectId('5b9aadb39bd8d2174df9dbfc'),
#  ObjectId('5b9aadb39bd8d2174df9dbfd'),
#  ObjectId('5b9aadb39bd8d2174df9dbfe'),
#  ObjectId('5b9aadb39bd8d2174df9dbff'),
#  ObjectId('5b9aadb39bd8d2174df9dc00'),
#  ObjectId('5b9aadb39bd8d2174df9dc01'),
#  ObjectId('5b9aadb39bd8d2174df9dc02'),
#  ObjectId('5b9aadb39bd8d2174df9dc03'),
#  ObjectId('5b9aadb39bd8d2174df9dc04'),
#  ObjectId('5b9aadb39bd8d2174df9dc05'),
#  ObjectId('5b9aadb39bd8d2174df9dc06'),
#  ObjectId('5b9aadb39bd8d2174df9dc07'),
#  ObjectId('5b9aadb39bd8d2174df9dc08'),
#  ObjectId('5b9aadb39bd8d2174df9dc09'),
#  ObjectId('5b9aadb39bd8d2174df9dc0a'),
#  ObjectId('5b9aadb39bd8d2174df9dc0b'),
#  ObjectId('5b9aadb39bd8d2174df9dc0c'),
#  ObjectId('5b9aadb39bd8d2174df9dc0d'),
#  ObjectId('5b9aadb39bd8d2174df9dc0e'),
#  ObjectId('5b9aadb39bd8d2174df9dc0f'),
#  ObjectId('5b9aadb39bd8d2174df9dc10'),
#  ObjectId('5b9aadb39bd8d2174df9dc11'),
#  ObjectId('5b9aadb39bd8d2174df9dc12'),
#  ObjectId('5b9aadb39bd8d2174df9dc13'),
#  ObjectId('5b9aadb39bd8d2174df9dc14'),
#  ObjectId('5b9aadb39bd8d2174df9dc15'),
#  ObjectId('5b9aadb39bd8d2174df9dc16'),
#  ObjectId('5b9aadb39bd8d2174df9dc17'),
#  ObjectId('5b9aadb39bd8d2174df9dc18'),
#  ObjectId('5b9aadb39bd8d2174df9dc19'),
#  ObjectId('5b9aadb39bd8d2174df9dc1a'),
#  ObjectId('5b9aadb39bd8d2174df9dc1b'),
#  ObjectId('5b9aadb39bd8d2174df9dc1c'),
#  ObjectId('5b9aadb39bd8d2174df9dc1d'),
#  ObjectId('5b9aadb39bd8d2174df9dc1e'),
#  ObjectId('5b9aadb39bd8d2174df9dc1f'),
#  ObjectId('5b9aadb39bd8d2174df9dc20'),
#  ObjectId('5b9aadb39bd8d2174df9dc21'),
#  ObjectId('5b9aadb39bd8d2174df9dc22'),
#  ObjectId('5b9aadb39bd8d2174df9dc23'),
#  ObjectId('5b9aadb39bd8d2174df9dc24'),
#  ObjectId('5b9aadb39bd8d2174df9dc25'),
#  ObjectId('5b9aadb39bd8d2174df9dc26'),
#  ObjectId('5b9aadb39bd8d2174df9dc27'),
#  ObjectId('5b9aadb39bd8d2174df9dc28'),
#  ObjectId('5b9aadb39bd8d2174df9dc29'),
#  ObjectId('5b9aadb39bd8d2174df9dc2a'),
#  ObjectId('5b9aadb39bd8d2174df9dc2b'),
#  ObjectId('5b9aadb39bd8d2174df9dc2c'),
#  ObjectId('5b9aadb39bd8d2174df9dc2d'),
#  ObjectId('5b9aadb39bd8d2174df9dc2e'),
#  ObjectId('5b9aadb39bd8d2174df9dc2f'),
#  ObjectId('5b9aadb39bd8d2174df9dc30'),
#  ObjectId('5b9aadb39bd8d2174df9dc31'),
#  ObjectId('5b9aadb39bd8d2174df9dc32'),
#  ObjectId('5b9aadb39bd8d2174df9dc33'),
#  ObjectId('5b9aadb39bd8d2174df9dc34'),
#  ObjectId('5b9aadb39bd8d2174df9dc35'),
#  ObjectId('5b9aadb39bd8d2174df9dc36'),
#  ObjectId('5b9aadb39bd8d2174df9dc37'),
#  ObjectId('5b9aadb39bd8d2174df9dc38'),
#  ObjectId('5b9aadb39bd8d2174df9dc39'),
#  ObjectId('5b9aadb39bd8d2174df9dc3a'),
#  ObjectId('5b9aadb39bd8d2174df9dc3b'),
#  ObjectId('5b9aadb39bd8d2174df9dc3c'),
#  ObjectId('5b9aadb39bd8d2174df9dc3d'),
#  ObjectId('5b9aadb39bd8d2174df9dc3e'),
#  ObjectId('5b9aadb39bd8d2174df9dc3f'),
#  ObjectId('5b9aadb39bd8d2174df9dc40'),
#  ObjectId('5b9aadb39bd8d2174df9dc41'),
#  ObjectId('5b9aadb39bd8d2174df9dc42'),
#  ObjectId('5b9aadb39bd8d2174df9dc43'),
#  ObjectId('5b9aadb39bd8d2174df9dc44'),
#  ObjectId('5b9aadb39bd8d2174df9dc45'),
#  ObjectId('5b9aadb39bd8d2174df9dc46'),
#  ObjectId('5b9aadb39bd8d2174df9dc47'),
#  ObjectId('5b9aadb39bd8d2174df9dc48'),
#  ObjectId('5b9aadb39bd8d2174df9dc49'),
#  ObjectId('5b9aadb39bd8d2174df9dc4a'),
#  ObjectId('5b9aadb39bd8d2174df9dc4b'),
#  ObjectId('5b9aadb39bd8d2174df9dc4c'),
#  ObjectId('5b9aadb39bd8d2174df9dc4d'),
#  ObjectId('5b9aadb39bd8d2174df9dc4e'),
#  ObjectId('5b9aadb39bd8d2174df9dc4f'),
#  ObjectId('5b9aadb39bd8d2174df9dc50'),
#  ObjectId('5b9aadb39bd8d2174df9dc51'),
#  ObjectId('5b9aadb39bd8d2174df9dc52'),
#  ObjectId('5b9aadb39bd8d2174df9dc53'),
#  ObjectId('5b9aadb39bd8d2174df9dc54'),
#  ObjectId('5b9aadb39bd8d2174df9dc55'),
#  ObjectId('5b9aadb39bd8d2174df9dc56'),
#  ObjectId('5b9aadb39bd8d2174df9dc57'),
#  ObjectId('5b9aadb39bd8d2174df9dc58'),
#  ObjectId('5b9aadb39bd8d2174df9dc59'),
#  ObjectId('5b9aadb39bd8d2174df9dc5a'),
#  ObjectId('5b9aadb39bd8d2174df9dc5b'),
#  ObjectId('5b9aadb39bd8d2174df9dc5c'),
#  ObjectId('5b9aadb39bd8d2174df9dc5d'),
#  ObjectId('5b9aadb39bd8d2174df9dc5e'),
#  ObjectId('5b9aadb39bd8d2174df9dc5f'),
#  ObjectId('5b9aadb39bd8d2174df9dc60'),
#  ObjectId('5b9aadb39bd8d2174df9dc61'),
#  ObjectId('5b9aadb39bd8d2174df9dc62'),
#  ObjectId('5b9aadb39bd8d2174df9dc63'),
#  ObjectId('5b9aadb39bd8d2174df9dc64'),
#  ObjectId('5b9aadb39bd8d2174df9dc65'),
#  ObjectId('5b9aadb39bd8d2174df9dc66'),
#  ObjectId('5b9aadb39bd8d2174df9dc67'),
#  ObjectId('5b9aadb39bd8d2174df9dc68'),
#  ObjectId('5b9aadb39bd8d2174df9dc69'),
#  ObjectId('5b9aadb39bd8d2174df9dc6a'),
#  ObjectId('5b9aadb39bd8d2174df9dc6b'),
#  ObjectId('5b9aadb39bd8d2174df9dc6c'),
#  ObjectId('5b9aadb39bd8d2174df9dc6d'),
#  ObjectId('5b9aadb39bd8d2174df9dc6e'),
#  ObjectId('5b9aadb39bd8d2174df9dc6f'),
#  ObjectId('5b9aadb39bd8d2174df9dc70'),
#  ObjectId('5b9aadb39bd8d2174df9dc71'),
#  ObjectId('5b9aadb39bd8d2174df9dc72'),
#  ObjectId('5b9aadb39bd8d2174df9dc73'),
#  ObjectId('5b9aadb39bd8d2174df9dc74'),
#  ObjectId('5b9aadb39bd8d2174df9dc75'),
#  ObjectId('5b9aadb39bd8d2174df9dc76'),
#  ObjectId('5b9aadb39bd8d2174df9dc77'),
#  ObjectId('5b9aadb39bd8d2174df9dc78'),
#  ObjectId('5b9aadb39bd8d2174df9dc79'),
#  ObjectId('5b9aadb39bd8d2174df9dc7a'),
#  ObjectId('5b9aadb39bd8d2174df9dc7b'),
#  ObjectId('5b9aadb39bd8d2174df9dc7c'),
#  ObjectId('5b9aadb39bd8d2174df9dc7d'),
#  ObjectId('5b9aadb39bd8d2174df9dc7e'),
#  ObjectId('5b9aadb39bd8d2174df9dc7f'),
#  ObjectId('5b9aadb39bd8d2174df9dc80'),
#  ObjectId('5b9aadb39bd8d2174df9dc81'),
#  ObjectId('5b9aadb39bd8d2174df9dc82'),
#  ObjectId('5b9aadb39bd8d2174df9dc83'),
#  ObjectId('5b9aadb39bd8d2174df9dc84'),
#  ObjectId('5b9aadb39bd8d2174df9dc85'),
#  ObjectId('5b9aadb39bd8d2174df9dc86'),
#  ObjectId('5b9aadb39bd8d2174df9dc87'),
#  ObjectId('5b9aadb39bd8d2174df9dc88'),
#  ObjectId('5b9aadb39bd8d2174df9dc89'),
#  ObjectId('5b9aadb39bd8d2174df9dc8a'),
#  ObjectId('5b9aadb39bd8d2174df9dc8b'),
#  ObjectId('5b9aadb39bd8d2174df9dc8c'),
#  ObjectId('5b9aadb39bd8d2174df9dc8d'),
#  ObjectId('5b9aadb39bd8d2174df9dc8e'),
#  ObjectId('5b9aadb39bd8d2174df9dc8f'),
#  ObjectId('5b9aadb39bd8d2174df9dc90'),
#  ObjectId('5b9aadb39bd8d2174df9dc91'),
#  ObjectId('5b9aadb39bd8d2174df9dc92'),
#  ObjectId('5b9aadb39bd8d2174df9dc93'),
#  ObjectId('5b9aadb39bd8d2174df9dc94'),
#  ObjectId('5b9aadb39bd8d2174df9dc95'),
#  ObjectId('5b9aadb39bd8d2174df9dc96'),
#  ObjectId('5b9aadb39bd8d2174df9dc97'),
#  ObjectId('5b9aadb39bd8d2174df9dc98'),
#  ObjectId('5b9aadb39bd8d2174df9dc99'),
#  ObjectId('5b9aadb39bd8d2174df9dc9a'),
#  ObjectId('5b9aadb39bd8d2174df9dc9b'),
#  ObjectId('5b9aadb39bd8d2174df9dc9c'),
#  ObjectId('5b9aadb39bd8d2174df9dc9d'),
#  ObjectId('5b9aadb39bd8d2174df9dc9e'),
#  ObjectId('5b9aadb39bd8d2174df9dc9f'),
#  ObjectId('5b9aadb39bd8d2174df9dca0'),
#  ObjectId('5b9aadb39bd8d2174df9dca1'),
#  ObjectId('5b9aadb39bd8d2174df9dca2'),
#  ObjectId('5b9aadb39bd8d2174df9dca3'),
#  ObjectId('5b9aadb39bd8d2174df9dca4'),
#  ObjectId('5b9aadb39bd8d2174df9dca5'),
#  ObjectId('5b9aadb39bd8d2174df9dca6'),
#  ObjectId('5b9aadb39bd8d2174df9dca7'),
#  ObjectId('5b9aadb39bd8d2174df9dca8'),
#  ObjectId('5b9aadb39bd8d2174df9dca9'),
#  ObjectId('5b9aadb39bd8d2174df9dcaa'),
#  ObjectId('5b9aadb39bd8d2174df9dcab'),
#  ObjectId('5b9aadb39bd8d2174df9dcac'),
#  ObjectId('5b9aadb39bd8d2174df9dcad'),
#  ObjectId('5b9aadb39bd8d2174df9dcae'),
#  ObjectId('5b9aadb39bd8d2174df9dcaf'),
#  ObjectId('5b9aadb39bd8d2174df9dcb0'),
#  ObjectId('5b9aadb39bd8d2174df9dcb1'),
#  ObjectId('5b9aadb39bd8d2174df9dcb2'),
#  ObjectId('5b9aadb39bd8d2174df9dcb3'),
#  ObjectId('5b9aadb39bd8d2174df9dcb4'),
#  ObjectId('5b9aadb39bd8d2174df9dcb5'),
#  ObjectId('5b9aadb39bd8d2174df9dcb6'),
#  ObjectId('5b9aadb39bd8d2174df9dcb7'),
#  ObjectId('5b9aadb39bd8d2174df9dcb8'),
#  ObjectId('5b9aadb39bd8d2174df9dcb9'),
#  ObjectId('5b9aadb39bd8d2174df9dcba'),
#  ObjectId('5b9aadb39bd8d2174df9dcbb'),
#  ObjectId('5b9aadb39bd8d2174df9dcbc'),
#  ObjectId('5b9aadb39bd8d2174df9dcbd'),
#  ObjectId('5b9aadb39bd8d2174df9dcbe'),
#  ObjectId('5b9aadb39bd8d2174df9dcbf'),
#  ObjectId('5b9aadb39bd8d2174df9dcc0'),
#  ObjectId('5b9aadb39bd8d2174df9dcc1'),
#  ObjectId('5b9aadb39bd8d2174df9dcc2'),
#  ObjectId('5b9aadb39bd8d2174df9dcc3'),
#  ObjectId('5b9aadb39bd8d2174df9dcc4'),
#  ObjectId('5b9aadb39bd8d2174df9dcc5'),
#  ObjectId('5b9aadb39bd8d2174df9dcc6'),
#  ObjectId('5b9aadb39bd8d2174df9dcc7'),
#  ObjectId('5b9aadb39bd8d2174df9dcc8'),
#  ObjectId('5b9aadb39bd8d2174df9dcc9'),
#  ObjectId('5b9aadb39bd8d2174df9dcca'),
#  ObjectId('5b9aadb39bd8d2174df9dccb'),
#  ObjectId('5b9aadb39bd8d2174df9dccc'),
#  ObjectId('5b9aadb39bd8d2174df9dccd'),
#  ObjectId('5b9aadb39bd8d2174df9dcce'),
#  ObjectId('5b9aadb39bd8d2174df9dccf'),
#  ObjectId('5b9aadb39bd8d2174df9dcd0'),
#  ObjectId('5b9aadb39bd8d2174df9dcd1'),
#  ObjectId('5b9aadb39bd8d2174df9dcd2'),
#  ObjectId('5b9aadb39bd8d2174df9dcd3'),
#  ObjectId('5b9aadb39bd8d2174df9dcd4'),
#  ObjectId('5b9aadb39bd8d2174df9dcd5'),
#  ObjectId('5b9aadb39bd8d2174df9dcd6'),
#  ObjectId('5b9aadb39bd8d2174df9dcd7'),
#  ObjectId('5b9aadb39bd8d2174df9dcd8'),
#  ObjectId('5b9aadb39bd8d2174df9dcd9'),
#  ObjectId('5b9aadb39bd8d2174df9dcda'),
#  ObjectId('5b9aadb39bd8d2174df9dcdb'),
#  ObjectId('5b9aadb39bd8d2174df9dcdc'),
#  ObjectId('5b9aadb39bd8d2174df9dcdd'),
#  ObjectId('5b9aadb39bd8d2174df9dcde'),
#  ObjectId('5b9aadb39bd8d2174df9dcdf'),
#  ObjectId('5b9aadb39bd8d2174df9dce0'),
#  ObjectId('5b9aadb39bd8d2174df9dce1'),
#  ObjectId('5b9aadb39bd8d2174df9dce2'),
#  ObjectId('5b9aadb39bd8d2174df9dce3'),
#  ObjectId('5b9aadb39bd8d2174df9dce4'),
#  ObjectId('5b9aadb39bd8d2174df9dce5'),
#  ObjectId('5b9aadb39bd8d2174df9dce6'),
#  ObjectId('5b9aadb39bd8d2174df9dce7'),
#  ObjectId('5b9aadb39bd8d2174df9dce8'),
#  ObjectId('5b9aadb39bd8d2174df9dce9'),
#  ObjectId('5b9aadb39bd8d2174df9dcea'),
#  ObjectId('5b9aadb39bd8d2174df9dceb'),
#  ObjectId('5b9aadb39bd8d2174df9dcec'),
#  ObjectId('5b9aadb39bd8d2174df9dced'),
#  ObjectId('5b9aadb39bd8d2174df9dcee'),
#  ObjectId('5b9aadb39bd8d2174df9dcef'),
#  ObjectId('5b9aadb39bd8d2174df9dcf0'),
#  ObjectId('5b9aadb39bd8d2174df9dcf1'),
#  ObjectId('5b9aadb39bd8d2174df9dcf2'),
#  ObjectId('5b9aadb39bd8d2174df9dcf3'),
#  ObjectId('5b9aadb39bd8d2174df9dcf4'),
#  ObjectId('5b9aadb39bd8d2174df9dcf5'),
#  ObjectId('5b9aadb39bd8d2174df9dcf6'),
#  ObjectId('5b9aadb39bd8d2174df9dcf7'),
#  ObjectId('5b9aadb39bd8d2174df9dcf8'),
#  ObjectId('5b9aadb39bd8d2174df9dcf9'),
#  ObjectId('5b9aadb39bd8d2174df9dcfa'),
#  ObjectId('5b9aadb39bd8d2174df9dcfb'),
#  ObjectId('5b9aadb39bd8d2174df9dcfc'),
#  ObjectId('5b9aadb39bd8d2174df9dcfd'),
#  ObjectId('5b9aadb39bd8d2174df9dcfe'),
#  ObjectId('5b9aadb39bd8d2174df9dcff'),
#  ObjectId('5b9aadb39bd8d2174df9dd00'),
#  ObjectId('5b9aadb39bd8d2174df9dd01'),
#  ObjectId('5b9aadb39bd8d2174df9dd02'),
#  ObjectId('5b9aadb39bd8d2174df9dd03'),
#  ObjectId('5b9aadb39bd8d2174df9dd04'),
#  ObjectId('5b9aadb39bd8d2174df9dd05'),
#  ObjectId('5b9aadb39bd8d2174df9dd06'),
#  ObjectId('5b9aadb39bd8d2174df9dd07'),
#  ObjectId('5b9aadb39bd8d2174df9dd08'),
#  ObjectId('5b9aadb39bd8d2174df9dd09'),
#  ObjectId('5b9aadb39bd8d2174df9dd0a'),
#  ObjectId('5b9aadb39bd8d2174df9dd0b'),
#  ObjectId('5b9aadb39bd8d2174df9dd0c'),
#  ObjectId('5b9aadb39bd8d2174df9dd0d'),
#  ObjectId('5b9aadb39bd8d2174df9dd0e'),
#  ObjectId('5b9aadb39bd8d2174df9dd0f'),
#  ObjectId('5b9aadb39bd8d2174df9dd10'),
#  ObjectId('5b9aadb39bd8d2174df9dd11'),
#  ObjectId('5b9aadb39bd8d2174df9dd12'),
#  ObjectId('5b9aadb39bd8d2174df9dd13'),
#  ObjectId('5b9aadb39bd8d2174df9dd14'),
#  ObjectId('5b9aadb39bd8d2174df9dd15'),
#  ObjectId('5b9aadb39bd8d2174df9dd16'),
#  ObjectId('5b9aadb39bd8d2174df9dd17'),
#  ObjectId('5b9aadb39bd8d2174df9dd18'),
#  ObjectId('5b9aadb39bd8d2174df9dd19'),
#  ObjectId('5b9aadb39bd8d2174df9dd1a'),
#  ObjectId('5b9aadb39bd8d2174df9dd1b'),
#  ObjectId('5b9aadb39bd8d2174df9dd1c'),
#  ObjectId('5b9aadb39bd8d2174df9dd1d'),
#  ObjectId('5b9aadb39bd8d2174df9dd1e'),
#  ObjectId('5b9aadb39bd8d2174df9dd1f'),
#  ObjectId('5b9aadb39bd8d2174df9dd20'),
#  ObjectId('5b9aadb39bd8d2174df9dd21'),
#  ObjectId('5b9aadb39bd8d2174df9dd22'),
#  ObjectId('5b9aadb39bd8d2174df9dd23'),
#  ObjectId('5b9aadb39bd8d2174df9dd24'),
#  ObjectId('5b9aadb39bd8d2174df9dd25'),
#  ObjectId('5b9aadb39bd8d2174df9dd26'),
#  ObjectId('5b9aadb39bd8d2174df9dd27'),
#  ObjectId('5b9aadb39bd8d2174df9dd28'),
#  ObjectId('5b9aadb39bd8d2174df9dd29'),
#  ObjectId('5b9aadb39bd8d2174df9dd2a'),
#  ObjectId('5b9aadb39bd8d2174df9dd2b'),
#  ObjectId('5b9aadb39bd8d2174df9dd2c'),
#  ObjectId('5b9aadb39bd8d2174df9dd2d'),
#  ObjectId('5b9aadb39bd8d2174df9dd2e'),
#  ObjectId('5b9aadb39bd8d2174df9dd2f'),
#  ObjectId('5b9aadb39bd8d2174df9dd30'),
#  ObjectId('5b9aadb39bd8d2174df9dd31'),
#  ObjectId('5b9aadb39bd8d2174df9dd32'),
#  ObjectId('5b9aadb39bd8d2174df9dd33'),
#  ObjectId('5b9aadb39bd8d2174df9dd34'),
#  ObjectId('5b9aadb39bd8d2174df9dd35'),
#  ObjectId('5b9aadb39bd8d2174df9dd36'),
#  ObjectId('5b9aadb39bd8d2174df9dd37'),
#  ObjectId('5b9aadb39bd8d2174df9dd38'),
#  ObjectId('5b9aadb39bd8d2174df9dd39'),
#  ObjectId('5b9aadb39bd8d2174df9dd3a'),
#  ObjectId('5b9aadb39bd8d2174df9dd3b'),
#  ObjectId('5b9aadb39bd8d2174df9dd3c'),
#  ObjectId('5b9aadb39bd8d2174df9dd3d'),
#  ObjectId('5b9aadb39bd8d2174df9dd3e'),
#  ObjectId('5b9aadb39bd8d2174df9dd3f'),
#  ObjectId('5b9aadb39bd8d2174df9dd40'),
#  ObjectId('5b9aadb39bd8d2174df9dd41'),
#  ObjectId('5b9aadb39bd8d2174df9dd42'),
#  ObjectId('5b9aadb39bd8d2174df9dd43'),
#  ObjectId('5b9aadb39bd8d2174df9dd44'),
#  ObjectId('5b9aadb39bd8d2174df9dd45'),
#  ObjectId('5b9aadb39bd8d2174df9dd46'),
#  ObjectId('5b9aadb39bd8d2174df9dd47'),
#  ObjectId('5b9aadb39bd8d2174df9dd48'),
#  ObjectId('5b9aadb39bd8d2174df9dd49'),
#  ObjectId('5b9aadb39bd8d2174df9dd4a'),
#  ObjectId('5b9aadb39bd8d2174df9dd4b'),
#  ObjectId('5b9aadb39bd8d2174df9dd4c'),
#  ObjectId('5b9aadb39bd8d2174df9dd4d'),
#  ObjectId('5b9aadb39bd8d2174df9dd4e'),
#  ObjectId('5b9aadb39bd8d2174df9dd4f'),
#  ObjectId('5b9aadb39bd8d2174df9dd50'),
#  ObjectId('5b9aadb39bd8d2174df9dd51'),
#  ObjectId('5b9aadb39bd8d2174df9dd52'),
#  ObjectId('5b9aadb39bd8d2174df9dd53'),
#  ObjectId('5b9aadb39bd8d2174df9dd54'),
#  ObjectId('5b9aadb39bd8d2174df9dd55'),
#  ObjectId('5b9aadb39bd8d2174df9dd56'),
#  ObjectId('5b9aadb39bd8d2174df9dd57'),
#  ObjectId('5b9aadb39bd8d2174df9dd58'),
#  ObjectId('5b9aadb39bd8d2174df9dd59'),
#  ObjectId('5b9aadb39bd8d2174df9dd5a'),
#  ObjectId('5b9aadb39bd8d2174df9dd5b'),
#  ObjectId('5b9aadb39bd8d2174df9dd5c'),
#  ObjectId('5b9aadb39bd8d2174df9dd5d'),
#  ObjectId('5b9aadb39bd8d2174df9dd5e'),
#  ObjectId('5b9aadb39bd8d2174df9dd5f'),
#  ObjectId('5b9aadb39bd8d2174df9dd60'),
#  ObjectId('5b9aadb39bd8d2174df9dd61'),
#  ObjectId('5b9aadb39bd8d2174df9dd62'),
#  ObjectId('5b9aadb39bd8d2174df9dd63'),
#  ObjectId('5b9aadb39bd8d2174df9dd64'),
#  ObjectId('5b9aadb39bd8d2174df9dd65'),
#  ObjectId('5b9aadb39bd8d2174df9dd66'),
#  ObjectId('5b9aadb39bd8d2174df9dd67'),
#  ObjectId('5b9aadb39bd8d2174df9dd68'),
#  ObjectId('5b9aadb39bd8d2174df9dd69'),
#  ObjectId('5b9aadb39bd8d2174df9dd6a'),
#  ObjectId('5b9aadb39bd8d2174df9dd6b'),
#  ObjectId('5b9aadb39bd8d2174df9dd6c'),
#  ObjectId('5b9aadb39bd8d2174df9dd6d'),
#  ObjectId('5b9aadb39bd8d2174df9dd6e'),
#  ObjectId('5b9aadb39bd8d2174df9dd6f'),
#  ObjectId('5b9aadb39bd8d2174df9dd70'),
#  ObjectId('5b9aadb39bd8d2174df9dd71'),
#  ObjectId('5b9aadb39bd8d2174df9dd72'),
#  ObjectId('5b9aadb39bd8d2174df9dd73'),
#  ObjectId('5b9aadb39bd8d2174df9dd74'),
#  ObjectId('5b9aadb39bd8d2174df9dd75'),
#  ObjectId('5b9aadb39bd8d2174df9dd76'),
#  ObjectId('5b9aadb39bd8d2174df9dd77'),
#  ObjectId('5b9aadb39bd8d2174df9dd78'),
#  ObjectId('5b9aadb39bd8d2174df9dd79'),
#  ObjectId('5b9aadb39bd8d2174df9dd7a'),
#  ObjectId('5b9aadb39bd8d2174df9dd7b'),
#  ObjectId('5b9aadb39bd8d2174df9dd7c'),
#  ObjectId('5b9aadb39bd8d2174df9dd7d'),
#  ObjectId('5b9aadb39bd8d2174df9dd7e'),
#  ObjectId('5b9aadb39bd8d2174df9dd7f'),
#  ObjectId('5b9aadb39bd8d2174df9dd80'),
#  ObjectId('5b9aadb39bd8d2174df9dd81'),
#  ObjectId('5b9aadb39bd8d2174df9dd82'),
#  ObjectId('5b9aadb39bd8d2174df9dd83'),
#  ObjectId('5b9aadb39bd8d2174df9dd84'),
#  ObjectId('5b9aadb39bd8d2174df9dd85'),
#  ObjectId('5b9aadb39bd8d2174df9dd86'),
#  ObjectId('5b9aadb39bd8d2174df9dd87'),
#  ObjectId('5b9aadb39bd8d2174df9dd88'),
#  ObjectId('5b9aadb39bd8d2174df9dd89'),
#  ObjectId('5b9aadb39bd8d2174df9dd8a'),
#  ObjectId('5b9aadb39bd8d2174df9dd8b'),
#  ObjectId('5b9aadb39bd8d2174df9dd8c'),
#  ObjectId('5b9aadb39bd8d2174df9dd8d'),
#  ObjectId('5b9aadb39bd8d2174df9dd8e'),
#  ObjectId('5b9aadb39bd8d2174df9dd8f'),
#  ObjectId('5b9aadb39bd8d2174df9dd90'),
#  ObjectId('5b9aadb39bd8d2174df9dd91'),
#  ObjectId('5b9aadb39bd8d2174df9dd92'),
#  ObjectId('5b9aadb39bd8d2174df9dd93'),
#  ObjectId('5b9aadb39bd8d2174df9dd94'),
#  ObjectId('5b9aadb39bd8d2174df9dd95'),
#  ObjectId('5b9aadb39bd8d2174df9dd96'),
#  ObjectId('5b9aadb39bd8d2174df9dd97'),
#  ObjectId('5b9aadb39bd8d2174df9dd98'),
#  ObjectId('5b9aadb39bd8d2174df9dd99'),
#  ObjectId('5b9aadb39bd8d2174df9dd9a'),
#  ObjectId('5b9aadb39bd8d2174df9dd9b'),
#  ObjectId('5b9aadb39bd8d2174df9dd9c'),
#  ObjectId('5b9aadb39bd8d2174df9dd9d'),
#  ObjectId('5b9aadb39bd8d2174df9dd9e'),
#  ObjectId('5b9aadb39bd8d2174df9dd9f'),
#  ObjectId('5b9aadb39bd8d2174df9dda0'),
#  ObjectId('5b9aadb39bd8d2174df9dda1'),
#  ObjectId('5b9aadb39bd8d2174df9dda2'),
#  ObjectId('5b9aadb39bd8d2174df9dda3'),
#  ObjectId('5b9aadb39bd8d2174df9dda4'),
#  ObjectId('5b9aadb39bd8d2174df9dda5'),
#  ObjectId('5b9aadb39bd8d2174df9dda6'),
#  ObjectId('5b9aadb39bd8d2174df9dda7'),
#  ObjectId('5b9aadb39bd8d2174df9dda8'),
#  ObjectId('5b9aadb39bd8d2174df9dda9'),
#  ObjectId('5b9aadb39bd8d2174df9ddaa'),
#  ObjectId('5b9aadb39bd8d2174df9ddab'),
#  ObjectId('5b9aadb39bd8d2174df9ddac'),
#  ObjectId('5b9aadb39bd8d2174df9ddad'),
#  ObjectId('5b9aadb39bd8d2174df9ddae'),
#  ObjectId('5b9aadb39bd8d2174df9ddaf'),
#  ObjectId('5b9aadb39bd8d2174df9ddb0'),
#  ObjectId('5b9aadb39bd8d2174df9ddb1'),
#  ObjectId('5b9aadb39bd8d2174df9ddb2'),
#  ObjectId('5b9aadb39bd8d2174df9ddb3'),
#  ObjectId('5b9aadb39bd8d2174df9ddb4'),
#  ObjectId('5b9aadb39bd8d2174df9ddb5'),
#  ObjectId('5b9aadb39bd8d2174df9ddb6'),
#  ObjectId('5b9aadb39bd8d2174df9ddb7'),
#  ObjectId('5b9aadb39bd8d2174df9ddb8'),
#  ObjectId('5b9aadb39bd8d2174df9ddb9'),
#  ObjectId('5b9aadb39bd8d2174df9ddba'),
#  ObjectId('5b9aadb39bd8d2174df9ddbb'),
#  ObjectId('5b9aadb39bd8d2174df9ddbc'),
#  ObjectId('5b9aadb39bd8d2174df9ddbd'),
#  ObjectId('5b9aadb39bd8d2174df9ddbe'),
#  ObjectId('5b9aadb39bd8d2174df9ddbf'),
#  ObjectId('5b9aadb39bd8d2174df9ddc0'),
#  ObjectId('5b9aadb39bd8d2174df9ddc1'),
#  ObjectId('5b9aadb39bd8d2174df9ddc2'),
#  ObjectId('5b9aadb39bd8d2174df9ddc3'),
#  ObjectId('5b9aadb39bd8d2174df9ddc4'),
#  ObjectId('5b9aadb39bd8d2174df9ddc5'),
#  ObjectId('5b9aadb39bd8d2174df9ddc6'),
#  ObjectId('5b9aadb39bd8d2174df9ddc7'),
#  ObjectId('5b9aadb39bd8d2174df9ddc8'),
#  ObjectId('5b9aadb39bd8d2174df9ddc9'),
#  ObjectId('5b9aadb39bd8d2174df9ddca'),
#  ObjectId('5b9aadb39bd8d2174df9ddcb'),
#  ObjectId('5b9aadb39bd8d2174df9ddcc'),
#  ObjectId('5b9aadb39bd8d2174df9ddcd'),
#  ObjectId('5b9aadb39bd8d2174df9ddce'),
#  ObjectId('5b9aadb39bd8d2174df9ddcf'),
#  ObjectId('5b9aadb39bd8d2174df9ddd0'),
#  ObjectId('5b9aadb39bd8d2174df9ddd1'),
#  ObjectId('5b9aadb39bd8d2174df9ddd2'),
#  ObjectId('5b9aadb39bd8d2174df9ddd3'),
#  ObjectId('5b9aadb39bd8d2174df9ddd4'),
#  ObjectId('5b9aadb39bd8d2174df9ddd5'),
#  ObjectId('5b9aadb39bd8d2174df9ddd6'),
#  ObjectId('5b9aadb39bd8d2174df9ddd7'),
#  ObjectId('5b9aadb39bd8d2174df9ddd8'),
#  ObjectId('5b9aadb39bd8d2174df9ddd9'),
#  ObjectId('5b9aadb39bd8d2174df9ddda'),
#  ObjectId('5b9aadb39bd8d2174df9dddb'),
#  ObjectId('5b9aadb39bd8d2174df9dddc'),
#  ObjectId('5b9aadb39bd8d2174df9dddd'),
#  ObjectId('5b9aadb39bd8d2174df9ddde'),
#  ObjectId('5b9aadb39bd8d2174df9dddf'),
#  ObjectId('5b9aadb39bd8d2174df9dde0'),
#  ObjectId('5b9aadb39bd8d2174df9dde1'),
#  ObjectId('5b9aadb39bd8d2174df9dde2'),
#  ObjectId('5b9aadb39bd8d2174df9dde3'),
#  ObjectId('5b9aadb39bd8d2174df9dde4'),
#  ObjectId('5b9aadb39bd8d2174df9dde5'),
#  ObjectId('5b9aadb39bd8d2174df9dde6'),
#  ObjectId('5b9aadb39bd8d2174df9dde7'),
#  ObjectId('5b9aadb39bd8d2174df9dde8'),
#  ObjectId('5b9aadb39bd8d2174df9dde9'),
#  ObjectId('5b9aadb39bd8d2174df9ddea'),
#  ObjectId('5b9aadb39bd8d2174df9ddeb'),
#  ObjectId('5b9aadb39bd8d2174df9ddec'),
#  ObjectId('5b9aadb39bd8d2174df9dded'),
#  ObjectId('5b9aadb39bd8d2174df9ddee'),
#  ObjectId('5b9aadb39bd8d2174df9ddef'),
#  ObjectId('5b9aadb39bd8d2174df9ddf0'),
#  ObjectId('5b9aadb39bd8d2174df9ddf1'),
#  ObjectId('5b9aadb39bd8d2174df9ddf2'),
#  ObjectId('5b9aadb39bd8d2174df9ddf3'),
#  ObjectId('5b9aadb39bd8d2174df9ddf4'),
#  ObjectId('5b9aadb39bd8d2174df9ddf5'),
#  ObjectId('5b9aadb39bd8d2174df9ddf6'),
#  ObjectId('5b9aadb39bd8d2174df9ddf7'),
#  ObjectId('5b9aadb39bd8d2174df9ddf8'),
#  ObjectId('5b9aadb39bd8d2174df9ddf9'),
#  ObjectId('5b9aadb39bd8d2174df9ddfa'),
#  ObjectId('5b9aadb39bd8d2174df9ddfb'),
#  ObjectId('5b9aadb39bd8d2174df9ddfc'),
#  ObjectId('5b9aadb39bd8d2174df9ddfd'),
#  ObjectId('5b9aadb39bd8d2174df9ddfe'),
#  ObjectId('5b9aadb39bd8d2174df9ddff'),
#  ObjectId('5b9aadb39bd8d2174df9de00'),
#  ObjectId('5b9aadb39bd8d2174df9de01'),
#  ObjectId('5b9aadb39bd8d2174df9de02'),
#  ObjectId('5b9aadb39bd8d2174df9de03'),
#  ObjectId('5b9aadb39bd8d2174df9de04'),
#  ObjectId('5b9aadb39bd8d2174df9de05'),
#  ObjectId('5b9aadb39bd8d2174df9de06'),
#  ObjectId('5b9aadb39bd8d2174df9de07'),
#  ObjectId('5b9aadb39bd8d2174df9de08'),
#  ObjectId('5b9aadb39bd8d2174df9de09'),
#  ObjectId('5b9aadb39bd8d2174df9de0a'),
#  ObjectId('5b9aadb39bd8d2174df9de0b'),
#  ObjectId('5b9aadb39bd8d2174df9de0c'),
#  ObjectId('5b9aadb39bd8d2174df9de0d'),
#  ObjectId('5b9aadb39bd8d2174df9de0e'),
#  ObjectId('5b9aadb39bd8d2174df9de0f'),
#  ObjectId('5b9aadb39bd8d2174df9de10'),
#  ObjectId('5b9aadb39bd8d2174df9de11'),
#  ObjectId('5b9aadb39bd8d2174df9de12'),
#  ObjectId('5b9aadb39bd8d2174df9de13'),
#  ObjectId('5b9aadb39bd8d2174df9de14'),
#  ObjectId('5b9aadb39bd8d2174df9de15'),
#  ObjectId('5b9aadb39bd8d2174df9de16'),
#  ObjectId('5b9aadb39bd8d2174df9de17'),
#  ObjectId('5b9aadb39bd8d2174df9de18'),
#  ObjectId('5b9aadb39bd8d2174df9de19'),
#  ObjectId('5b9aadb39bd8d2174df9de1a'),
#  ObjectId('5b9aadb39bd8d2174df9de1b'),
#  ObjectId('5b9aadb39bd8d2174df9de1c'),
#  ObjectId('5b9aadb39bd8d2174df9de1d'),
#  ObjectId('5b9aadb39bd8d2174df9de1e'),
#  ObjectId('5b9aadb39bd8d2174df9de1f'),
#  ObjectId('5b9aadb39bd8d2174df9de20'),
#  ObjectId('5b9aadb39bd8d2174df9de21'),
#  ObjectId('5b9aadb39bd8d2174df9de22'),
#  ObjectId('5b9aadb39bd8d2174df9de23'),
#  ObjectId('5b9aadb39bd8d2174df9de24'),
#  ObjectId('5b9aadb39bd8d2174df9de25'),
#  ObjectId('5b9aadb39bd8d2174df9de26'),
#  ObjectId('5b9aadb39bd8d2174df9de27'),
#  ObjectId('5b9aadb39bd8d2174df9de28'),
#  ObjectId('5b9aadb39bd8d2174df9de29'),
#  ObjectId('5b9aadb39bd8d2174df9de2a'),
#  ObjectId('5b9aadb39bd8d2174df9de2b'),
#  ObjectId('5b9aadb39bd8d2174df9de2c'),
#  ObjectId('5b9aadb39bd8d2174df9de2d'),
#  ObjectId('5b9aadb39bd8d2174df9de2e'),
#  ObjectId('5b9aadb39bd8d2174df9de2f'),
#  ObjectId('5b9aadb39bd8d2174df9de30'),
#  ObjectId('5b9aadb39bd8d2174df9de31'),
#  ObjectId('5b9aadb39bd8d2174df9de32'),
#  ObjectId('5b9aadb39bd8d2174df9de33'),
#  ObjectId('5b9aadb39bd8d2174df9de34'),
#  ObjectId('5b9aadb39bd8d2174df9de35'),
#  ObjectId('5b9aadb39bd8d2174df9de36'),
#  ObjectId('5b9aadb39bd8d2174df9de37'),
#  ObjectId('5b9aadb39bd8d2174df9de38'),
#  ObjectId('5b9aadb39bd8d2174df9de39'),
#  ObjectId('5b9aadb39bd8d2174df9de3a'),
#  ObjectId('5b9aadb39bd8d2174df9de3b'),
#  ObjectId('5b9aadb39bd8d2174df9de3c'),
#  ObjectId('5b9aadb39bd8d2174df9de3d'),
#  ObjectId('5b9aadb39bd8d2174df9de3e'),
#  ObjectId('5b9aadb39bd8d2174df9de3f'),
#  ObjectId('5b9aadb39bd8d2174df9de40'),
#  ObjectId('5b9aadb39bd8d2174df9de41'),
#  ObjectId('5b9aadb39bd8d2174df9de42'),
#  ObjectId('5b9aadb39bd8d2174df9de43'),
#  ObjectId('5b9aadb39bd8d2174df9de44'),
#  ObjectId('5b9aadb39bd8d2174df9de45'),
#  ObjectId('5b9aadb39bd8d2174df9de46'),
#  ObjectId('5b9aadb39bd8d2174df9de47'),
#  ObjectId('5b9aadb39bd8d2174df9de48'),
#  ObjectId('5b9aadb39bd8d2174df9de49'),
#  ObjectId('5b9aadb39bd8d2174df9de4a'),
#  ObjectId('5b9aadb39bd8d2174df9de4b'),
#  ObjectId('5b9aadb39bd8d2174df9de4c'),
#  ObjectId('5b9aadb39bd8d2174df9de4d'),
#  ObjectId('5b9aadb39bd8d2174df9de4e'),
#  ObjectId('5b9aadb39bd8d2174df9de4f'),
#  ObjectId('5b9aadb39bd8d2174df9de50'),
#  ObjectId('5b9aadb39bd8d2174df9de51'),
#  ObjectId('5b9aadb39bd8d2174df9de52'),
#  ObjectId('5b9aadb39bd8d2174df9de53'),
#  ObjectId('5b9aadb39bd8d2174df9de54'),
#  ObjectId('5b9aadb39bd8d2174df9de55'),
#  ObjectId('5b9aadb39bd8d2174df9de56'),
#  ObjectId('5b9aadb39bd8d2174df9de57'),
#  ObjectId('5b9aadb39bd8d2174df9de58'),
#  ObjectId('5b9aadb39bd8d2174df9de59'),
#  ObjectId('5b9aadb39bd8d2174df9de5a'),
#  ObjectId('5b9aadb39bd8d2174df9de5b'),
#  ObjectId('5b9aadb39bd8d2174df9de5c'),
#  ObjectId('5b9aadb39bd8d2174df9de5d'),
#  ObjectId('5b9aadb39bd8d2174df9de5e'),
#  ObjectId('5b9aadb39bd8d2174df9de5f'),
#  ObjectId('5b9aadb39bd8d2174df9de60'),
#  ObjectId('5b9aadb39bd8d2174df9de61'),
#  ObjectId('5b9aadb39bd8d2174df9de62'),
#  ObjectId('5b9aadb39bd8d2174df9de63'),
#  ObjectId('5b9aadb39bd8d2174df9de64'),
#  ObjectId('5b9aadb39bd8d2174df9de65'),
#  ObjectId('5b9aadb39bd8d2174df9de66'),
#  ObjectId('5b9aadb39bd8d2174df9de67'),
#  ObjectId('5b9aadb39bd8d2174df9de68'),
#  ObjectId('5b9aadb39bd8d2174df9de69'),
#  ObjectId('5b9aadb39bd8d2174df9de6a'),
#  ObjectId('5b9aadb39bd8d2174df9de6b'),
#  ObjectId('5b9aadb39bd8d2174df9de6c'),
#  ObjectId('5b9aadb39bd8d2174df9de6d'),
#  ObjectId('5b9aadb39bd8d2174df9de6e'),
#  ObjectId('5b9aadb39bd8d2174df9de6f'),
#  ObjectId('5b9aadb39bd8d2174df9de70'),
#  ObjectId('5b9aadb39bd8d2174df9de71'),
#  ObjectId('5b9aadb39bd8d2174df9de72'),
#  ObjectId('5b9aadb39bd8d2174df9de73'),
#  ObjectId('5b9aadb39bd8d2174df9de74'),
#  ObjectId('5b9aadb39bd8d2174df9de75'),
#  ObjectId('5b9aadb39bd8d2174df9de76'),
#  ObjectId('5b9aadb39bd8d2174df9de77'),
#  ObjectId('5b9aadb39bd8d2174df9de78'),
#  ObjectId('5b9aadb39bd8d2174df9de79'),
#  ObjectId('5b9aadb39bd8d2174df9de7a'),
#  ObjectId('5b9aadb39bd8d2174df9de7b'),
#  ObjectId('5b9aadb39bd8d2174df9de7c'),
#  ObjectId('5b9aadb39bd8d2174df9de7d'),
#  ObjectId('5b9aadb39bd8d2174df9de7e'),
#  ObjectId('5b9aadb39bd8d2174df9de7f'),
#  ObjectId('5b9aadb39bd8d2174df9de80'),
#  ObjectId('5b9aadb39bd8d2174df9de81'),
#  ObjectId('5b9aadb39bd8d2174df9de82'),
#  ObjectId('5b9aadb39bd8d2174df9de83'),
#  ObjectId('5b9aadb39bd8d2174df9de84'),
#  ObjectId('5b9aadb39bd8d2174df9de85'),
#  ObjectId('5b9aadb39bd8d2174df9de86'),
#  ObjectId('5b9aadb39bd8d2174df9de87'),
#  ObjectId('5b9aadb39bd8d2174df9de88'),
#  ObjectId('5b9aadb39bd8d2174df9de89'),
#  ObjectId('5b9aadb39bd8d2174df9de8a'),
#  ObjectId('5b9aadb39bd8d2174df9de8b'),
#  ObjectId('5b9aadb39bd8d2174df9de8c'),
#  ObjectId('5b9aadb39bd8d2174df9de8d'),
#  ObjectId('5b9aadb39bd8d2174df9de8e'),
#  ObjectId('5b9aadb39bd8d2174df9de8f'),
#  ObjectId('5b9aadb39bd8d2174df9de90'),
#  ObjectId('5b9aadb39bd8d2174df9de91'),
#  ObjectId('5b9aadb39bd8d2174df9de92'),
#  ObjectId('5b9aadb39bd8d2174df9de93'),
#  ObjectId('5b9aadb39bd8d2174df9de94'),
#  ObjectId('5b9aadb39bd8d2174df9de95'),
#  ObjectId('5b9aadb39bd8d2174df9de96'),
#  ObjectId('5b9aadb39bd8d2174df9de97'),
#  ObjectId('5b9aadb39bd8d2174df9de98'),
#  ObjectId('5b9aadb39bd8d2174df9de99'),
#  ObjectId('5b9aadb39bd8d2174df9de9a'),
#  ObjectId('5b9aadb39bd8d2174df9de9b'),
#  ObjectId('5b9aadb39bd8d2174df9de9c'),
#  ObjectId('5b9aadb39bd8d2174df9de9d'),
#  ObjectId('5b9aadb39bd8d2174df9de9e'),
#  ObjectId('5b9aadb39bd8d2174df9de9f'),
#  ObjectId('5b9aadb39bd8d2174df9dea0'),
#  ObjectId('5b9aadb39bd8d2174df9dea1'),
#  ObjectId('5b9aadb39bd8d2174df9dea2'),
#  ObjectId('5b9aadb39bd8d2174df9dea3'),
#  ObjectId('5b9aadb39bd8d2174df9dea4'),
#  ObjectId('5b9aadb39bd8d2174df9dea5'),
#  ObjectId('5b9aadb39bd8d2174df9dea6'),
#  ObjectId('5b9aadb39bd8d2174df9dea7'),
#  ObjectId('5b9aadb39bd8d2174df9dea8'),
#  ObjectId('5b9aadb39bd8d2174df9dea9'),
#  ObjectId('5b9aadb39bd8d2174df9deaa'),
#  ObjectId('5b9aadb39bd8d2174df9deab'),
#  ObjectId('5b9aadb39bd8d2174df9deac'),
#  ObjectId('5b9aadb39bd8d2174df9dead'),
#  ObjectId('5b9aadb39bd8d2174df9deae'),
#  ObjectId('5b9aadb39bd8d2174df9deaf'),
#  ObjectId('5b9aadb39bd8d2174df9deb0'),
#  ObjectId('5b9aadb39bd8d2174df9deb1'),
#  ObjectId('5b9aadb39bd8d2174df9deb2'),
#  ObjectId('5b9aadb39bd8d2174df9deb3'),
#  ObjectId('5b9aadb39bd8d2174df9deb4'),
#  ObjectId('5b9aadb39bd8d2174df9deb5'),
#  ObjectId('5b9aadb39bd8d2174df9deb6'),
#  ObjectId('5b9aadb39bd8d2174df9deb7'),
#  ObjectId('5b9aadb39bd8d2174df9deb8'),
#  ObjectId('5b9aadb39bd8d2174df9deb9'),
#  ObjectId('5b9aadb39bd8d2174df9deba'),
#  ObjectId('5b9aadb39bd8d2174df9debb'),
#  ObjectId('5b9aadb39bd8d2174df9debc'),
#  ObjectId('5b9aadb39bd8d2174df9debd'),
#  ObjectId('5b9aadb39bd8d2174df9debe'),
#  ObjectId('5b9aadb39bd8d2174df9debf'),
#  ObjectId('5b9aadb39bd8d2174df9dec0'),
#  ObjectId('5b9aadb39bd8d2174df9dec1'),
#  ObjectId('5b9aadb39bd8d2174df9dec2'),
#  ObjectId('5b9aadb39bd8d2174df9dec3'),
#  ObjectId('5b9aadb39bd8d2174df9dec4'),
#  ObjectId('5b9aadb39bd8d2174df9dec5'),
#  ObjectId('5b9aadb39bd8d2174df9dec6'),
#  ObjectId('5b9aadb39bd8d2174df9dec7'),
#  ObjectId('5b9aadb39bd8d2174df9dec8'),
#  ObjectId('5b9aadb39bd8d2174df9dec9'),
#  ObjectId('5b9aadb39bd8d2174df9deca'),
#  ObjectId('5b9aadb39bd8d2174df9decb'),
#  ObjectId('5b9aadb39bd8d2174df9decc'),
#  ObjectId('5b9aadb39bd8d2174df9decd'),
#  ObjectId('5b9aadb39bd8d2174df9dece'),
#  ObjectId('5b9aadb39bd8d2174df9decf'),
#  ObjectId('5b9aadb39bd8d2174df9ded0'),
#  ObjectId('5b9aadb39bd8d2174df9ded1'),
#  ObjectId('5b9aadb39bd8d2174df9ded2'),
#  ObjectId('5b9aadb39bd8d2174df9ded3'),
#  ObjectId('5b9aadb39bd8d2174df9ded4'),
#  ObjectId('5b9aadb39bd8d2174df9ded5'),
#  ObjectId('5b9aadb39bd8d2174df9ded6'),
#  ObjectId('5b9aadb39bd8d2174df9ded7'),
#  ObjectId('5b9aadb39bd8d2174df9ded8'),
#  ObjectId('5b9aadb39bd8d2174df9ded9'),
#  ObjectId('5b9aadb39bd8d2174df9deda'),
#  ObjectId('5b9aadb39bd8d2174df9dedb'),
#  ObjectId('5b9aadb39bd8d2174df9dedc'),
#  ObjectId('5b9aadb39bd8d2174df9dedd'),
#  ObjectId('5b9aadb39bd8d2174df9dede'),
#  ObjectId('5b9aadb39bd8d2174df9dedf'),
#  ObjectId('5b9aadb39bd8d2174df9dee0'),
#  ObjectId('5b9aadb39bd8d2174df9dee1'),
#  ObjectId('5b9aadb39bd8d2174df9dee2'),
#  ObjectId('5b9aadb39bd8d2174df9dee3'),
#  ObjectId('5b9aadb39bd8d2174df9dee4'),
#  ObjectId('5b9aadb39bd8d2174df9dee5'),
#  ObjectId('5b9aadb39bd8d2174df9dee6'),
#  ObjectId('5b9aadb39bd8d2174df9dee7'),
#  ObjectId('5b9aadb39bd8d2174df9dee8'),
#  ObjectId('5b9aadb39bd8d2174df9dee9'),
#  ObjectId('5b9aadb39bd8d2174df9deea'),
#  ObjectId('5b9aadb39bd8d2174df9deeb'),
#  ObjectId('5b9aadb39bd8d2174df9deec'),
#  ObjectId('5b9aadb39bd8d2174df9deed'),
#  ObjectId('5b9aadb39bd8d2174df9deee'),
#  ObjectId('5b9aadb39bd8d2174df9deef'),
#  ObjectId('5b9aadb39bd8d2174df9def0'),
#  ObjectId('5b9aadb39bd8d2174df9def1'),
#  ObjectId('5b9aadb39bd8d2174df9def2'),
#  ObjectId('5b9aadb39bd8d2174df9def3'),
#  ObjectId('5b9aadb39bd8d2174df9def4'),
#  ObjectId('5b9aadb39bd8d2174df9def5'),
#  ObjectId('5b9aadb39bd8d2174df9def6'),
#  ObjectId('5b9aadb39bd8d2174df9def7'),
#  ObjectId('5b9aadb39bd8d2174df9def8'),
#  ObjectId('5b9aadb39bd8d2174df9def9'),
#  ObjectId('5b9aadb39bd8d2174df9defa'),
#  ObjectId('5b9aadb39bd8d2174df9defb'),
#  ObjectId('5b9aadb39bd8d2174df9defc'),
#  ObjectId('5b9aadb39bd8d2174df9defd'),
#  ObjectId('5b9aadb39bd8d2174df9defe'),
#  ObjectId('5b9aadb39bd8d2174df9deff'),
#  ObjectId('5b9aadb39bd8d2174df9df00'),
#  ObjectId('5b9aadb39bd8d2174df9df01'),
#  ObjectId('5b9aadb39bd8d2174df9df02'),
#  ObjectId('5b9aadb39bd8d2174df9df03'),
#  ObjectId('5b9aadb39bd8d2174df9df04'),
#  ObjectId('5b9aadb39bd8d2174df9df05'),
#  ObjectId('5b9aadb39bd8d2174df9df06'),
#  ObjectId('5b9aadb39bd8d2174df9df07'),
#  ObjectId('5b9aadb39bd8d2174df9df08'),
#  ObjectId('5b9aadb39bd8d2174df9df09'),
#  ObjectId('5b9aadb39bd8d2174df9df0a'),
#  ObjectId('5b9aadb39bd8d2174df9df0b'),
#  ObjectId('5b9aadb39bd8d2174df9df0c'),
#  ObjectId('5b9aadb39bd8d2174df9df0d'),
#  ObjectId('5b9aadb39bd8d2174df9df0e'),
#  ObjectId('5b9aadb39bd8d2174df9df0f'),
#  ObjectId('5b9aadb39bd8d2174df9df10'),
#  ObjectId('5b9aadb39bd8d2174df9df11'),
#  ObjectId('5b9aadb39bd8d2174df9df12'),
#  ObjectId('5b9aadb39bd8d2174df9df13'),
#  ObjectId('5b9aadb39bd8d2174df9df14'),
#  ObjectId('5b9aadb39bd8d2174df9df15'),
#  ObjectId('5b9aadb39bd8d2174df9df16'),
#  ObjectId('5b9aadb39bd8d2174df9df17'),
#  ObjectId('5b9aadb39bd8d2174df9df18'),
#  ObjectId('5b9aadb39bd8d2174df9df19'),
#  ObjectId('5b9aadb39bd8d2174df9df1a'),
#  ObjectId('5b9aadb39bd8d2174df9df1b'),
#  ObjectId('5b9aadb39bd8d2174df9df1c'),
#  ObjectId('5b9aadb39bd8d2174df9df1d'),
#  ObjectId('5b9aadb39bd8d2174df9df1e'),
#  ObjectId('5b9aadb39bd8d2174df9df1f'),
#  ObjectId('5b9aadb39bd8d2174df9df20'),
#  ObjectId('5b9aadb39bd8d2174df9df21'),
#  ObjectId('5b9aadb39bd8d2174df9df22'),
#  ObjectId('5b9aadb39bd8d2174df9df23'),
#  ObjectId('5b9aadb39bd8d2174df9df24'),
#  ObjectId('5b9aadb39bd8d2174df9df25'),
#  ObjectId('5b9aadb39bd8d2174df9df26'),
#  ObjectId('5b9aadb39bd8d2174df9df27'),
#  ObjectId('5b9aadb39bd8d2174df9df28'),
#  ObjectId('5b9aadb39bd8d2174df9df29'),
#  ObjectId('5b9aadb39bd8d2174df9df2a'),
#  ObjectId('5b9aadb39bd8d2174df9df2b'),
#  ObjectId('5b9aadb39bd8d2174df9df2c'),
#  ObjectId('5b9aadb39bd8d2174df9df2d'),
#  ObjectId('5b9aadb39bd8d2174df9df2e'),
#  ObjectId('5b9aadb39bd8d2174df9df2f'),
#  ObjectId('5b9aadb39bd8d2174df9df30'),
#  ObjectId('5b9aadb39bd8d2174df9df31'),
#  ObjectId('5b9aadb39bd8d2174df9df32'),
#  ObjectId('5b9aadb39bd8d2174df9df33'),
#  ObjectId('5b9aadb39bd8d2174df9df34'),
#  ObjectId('5b9aadb39bd8d2174df9df35'),
#  ObjectId('5b9aadb39bd8d2174df9df36'),
#  ObjectId('5b9aadb39bd8d2174df9df37'),
#  ObjectId('5b9aadb39bd8d2174df9df38'),
#  ObjectId('5b9aadb39bd8d2174df9df39'),
#  ObjectId('5b9aadb39bd8d2174df9df3a'),
#  ObjectId('5b9aadb39bd8d2174df9df3b'),
#  ObjectId('5b9aadb39bd8d2174df9df3c'),
#  ObjectId('5b9aadb39bd8d2174df9df3d'),
#  ObjectId('5b9aadb39bd8d2174df9df3e'),
#  ObjectId('5b9aadb39bd8d2174df9df3f'),
#  ObjectId('5b9aadb39bd8d2174df9df40'),
#  ObjectId('5b9aadb39bd8d2174df9df41'),
#  ObjectId('5b9aadb39bd8d2174df9df42'),
#  ObjectId('5b9aadb39bd8d2174df9df43'),
#  ObjectId('5b9aadb39bd8d2174df9df44'),
#  ObjectId('5b9aadb39bd8d2174df9df45'),
#  ObjectId('5b9aadb39bd8d2174df9df46'),
#  ObjectId('5b9aadb39bd8d2174df9df47'),
#  ObjectId('5b9aadb39bd8d2174df9df48'),
#  ObjectId('5b9aadb39bd8d2174df9df49'),
#  ObjectId('5b9aadb39bd8d2174df9df4a'),
#  ObjectId('5b9aadb39bd8d2174df9df4b'),
#  ObjectId('5b9aadb39bd8d2174df9df4c'),
#  ObjectId('5b9aadb39bd8d2174df9df4d'),
#  ObjectId('5b9aadb39bd8d2174df9df4e'),
#  ObjectId('5b9aadb39bd8d2174df9df4f'),
#  ObjectId('5b9aadb39bd8d2174df9df50'),
#  ObjectId('5b9aadb39bd8d2174df9df51'),
#  ObjectId('5b9aadb39bd8d2174df9df52'),
#  ObjectId('5b9aadb39bd8d2174df9df53'),
#  ObjectId('5b9aadb39bd8d2174df9df54'),
#  ObjectId('5b9aadb39bd8d2174df9df55'),
#  ObjectId('5b9aadb39bd8d2174df9df56'),
#  ObjectId('5b9aadb39bd8d2174df9df57'),
#  ObjectId('5b9aadb39bd8d2174df9df58'),
#  ObjectId('5b9aadb39bd8d2174df9df59'),
#  ObjectId('5b9aadb39bd8d2174df9df5a'),
#  ObjectId('5b9aadb39bd8d2174df9df5b'),
#  ObjectId('5b9aadb39bd8d2174df9df5c'),
#  ObjectId('5b9aadb39bd8d2174df9df5d'),
#  ObjectId('5b9aadb39bd8d2174df9df5e'),
#  ObjectId('5b9aadb39bd8d2174df9df5f'),
#  ObjectId('5b9aadb39bd8d2174df9df60'),
#  ObjectId('5b9aadb39bd8d2174df9df61'),
#  ObjectId('5b9aadb39bd8d2174df9df62'),
#  ObjectId('5b9aadb39bd8d2174df9df63'),
#  ObjectId('5b9aadb39bd8d2174df9df64'),
#  ObjectId('5b9aadb39bd8d2174df9df65'),
#  ObjectId('5b9aadb39bd8d2174df9df66'),
#  ObjectId('5b9aadb39bd8d2174df9df67'),
#  ObjectId('5b9aadb39bd8d2174df9df68'),
#  ObjectId('5b9aadb39bd8d2174df9df69'),
#  ObjectId('5b9aadb39bd8d2174df9df6a'),
#  ObjectId('5b9aadb39bd8d2174df9df6b'),
#  ObjectId('5b9aadb39bd8d2174df9df6c'),
#  ObjectId('5b9aadb39bd8d2174df9df6d'),
#  ObjectId('5b9aadb39bd8d2174df9df6e'),
#  ObjectId('5b9aadb39bd8d2174df9df6f'),
#  ObjectId('5b9aadb39bd8d2174df9df70'),
#  ObjectId('5b9aadb39bd8d2174df9df71'),
#  ObjectId('5b9aadb39bd8d2174df9df72'),
#  ObjectId('5b9aadb39bd8d2174df9df73'),
#  ObjectId('5b9aadb39bd8d2174df9df74'),
#  ObjectId('5b9aadb39bd8d2174df9df75'),
#  ObjectId('5b9aadb39bd8d2174df9df76'),
#  ObjectId('5b9aadb39bd8d2174df9df77'),
#  ObjectId('5b9aadb39bd8d2174df9df78'),
#  ObjectId('5b9aadb39bd8d2174df9df79'),
#  ObjectId('5b9aadb39bd8d2174df9df7a'),
#  ObjectId('5b9aadb39bd8d2174df9df7b'),
#  ObjectId('5b9aadb39bd8d2174df9df7c'),
#  ObjectId('5b9aadb39bd8d2174df9df7d'),
#  ObjectId('5b9aadb39bd8d2174df9df7e'),
#  ObjectId('5b9aadb39bd8d2174df9df7f'),
#  ObjectId('5b9aadb39bd8d2174df9df80'),
#  ObjectId('5b9aadb39bd8d2174df9df81'),
#  ObjectId('5b9aadb39bd8d2174df9df82'),
#  ObjectId('5b9aadb39bd8d2174df9df83'),
#  ObjectId('5b9aadb39bd8d2174df9df84'),
#  ObjectId('5b9aadb39bd8d2174df9df85'),
#  ObjectId('5b9aadb39bd8d2174df9df86'),
#  ObjectId('5b9aadb39bd8d2174df9df87'),
#  ObjectId('5b9aadb39bd8d2174df9df88'),
#  ObjectId('5b9aadb39bd8d2174df9df89'),
#  ObjectId('5b9aadb39bd8d2174df9df8a'),
#  ObjectId('5b9aadb39bd8d2174df9df8b'),
#  ObjectId('5b9aadb39bd8d2174df9df8c'),
#  ObjectId('5b9aadb39bd8d2174df9df8d'),
#  ObjectId('5b9aadb39bd8d2174df9df8e'),
#  ObjectId('5b9aadb39bd8d2174df9df8f'),
#  ObjectId('5b9aadb39bd8d2174df9df90'),
#  ObjectId('5b9aadb39bd8d2174df9df91'),
#  ObjectId('5b9aadb39bd8d2174df9df92'),
#  ObjectId('5b9aadb39bd8d2174df9df93'),
#  ObjectId('5b9aadb39bd8d2174df9df94'),
#  ObjectId('5b9aadb39bd8d2174df9df95'),
#  ObjectId('5b9aadb39bd8d2174df9df96'),
#  ObjectId('5b9aadb39bd8d2174df9df97'),
#  ObjectId('5b9aadb39bd8d2174df9df98'),
#  ObjectId('5b9aadb39bd8d2174df9df99'),
#  ObjectId('5b9aadb39bd8d2174df9df9a'),
#  ObjectId('5b9aadb39bd8d2174df9df9b'),
#  ObjectId('5b9aadb39bd8d2174df9df9c'),
#  ObjectId('5b9aadb39bd8d2174df9df9d'),
#  ObjectId('5b9aadb39bd8d2174df9df9e'),
#  ObjectId('5b9aadb39bd8d2174df9df9f'),
#  ObjectId('5b9aadb39bd8d2174df9dfa0'),
#  ObjectId('5b9aadb39bd8d2174df9dfa1'),
#  ObjectId('5b9aadb39bd8d2174df9dfa2'),
#  ObjectId('5b9aadb39bd8d2174df9dfa3'),
#  ObjectId('5b9aadb39bd8d2174df9dfa4'),
#  ObjectId('5b9aadb39bd8d2174df9dfa5'),
#  ObjectId('5b9aadb39bd8d2174df9dfa6'),
#  ObjectId('5b9aadb39bd8d2174df9dfa7'),
#  ObjectId('5b9aadb39bd8d2174df9dfa8'),
#  ObjectId('5b9aadb39bd8d2174df9dfa9'),
#  ObjectId('5b9aadb39bd8d2174df9dfaa'),
#  ObjectId('5b9aadb39bd8d2174df9dfab'),
#  ObjectId('5b9aadb39bd8d2174df9dfac'),
#  ObjectId('5b9aadb39bd8d2174df9dfad'),
#  ObjectId('5b9aadb39bd8d2174df9dfae'),
#  ObjectId('5b9aadb39bd8d2174df9dfaf'),
#  ObjectId('5b9aadb39bd8d2174df9dfb0'),
#  ObjectId('5b9aadb39bd8d2174df9dfb1'),
#  ObjectId('5b9aadb39bd8d2174df9dfb2'),
#  ObjectId('5b9aadb39bd8d2174df9dfb3'),
#  ObjectId('5b9aadb39bd8d2174df9dfb4'),
#  ObjectId('5b9aadb39bd8d2174df9dfb5'),
#  ObjectId('5b9aadb39bd8d2174df9dfb6'),
#  ObjectId('5b9aadb39bd8d2174df9dfb7'),
#  ObjectId('5b9aadb39bd8d2174df9dfb8'),
#  ObjectId('5b9aadb39bd8d2174df9dfb9'),
#  ObjectId('5b9aadb39bd8d2174df9dfba'),
#  ObjectId('5b9aadb39bd8d2174df9dfbb'),
#  ObjectId('5b9aadb39bd8d2174df9dfbc'),
#  ObjectId('5b9aadb39bd8d2174df9dfbd'),
#  ObjectId('5b9aadb39bd8d2174df9dfbe'),
#  ObjectId('5b9aadb39bd8d2174df9dfbf'),
#  ObjectId('5b9aadb39bd8d2174df9dfc0'),
#  ObjectId('5b9aadb39bd8d2174df9dfc1'),
#  ObjectId('5b9aadb39bd8d2174df9dfc2'),
#  ObjectId('5b9aadb39bd8d2174df9dfc3'),
#  ObjectId('5b9aadb39bd8d2174df9dfc4'),
#  ObjectId('5b9aadb39bd8d2174df9dfc5'),
#  ObjectId('5b9aadb39bd8d2174df9dfc6'),
#  ObjectId('5b9aadb39bd8d2174df9dfc7'),
#  ObjectId('5b9aadb39bd8d2174df9dfc8'),
#  ObjectId('5b9aadb39bd8d2174df9dfc9'),
#  ObjectId('5b9aadb39bd8d2174df9dfca'),
#  ObjectId('5b9aadb39bd8d2174df9dfcb'),
#  ObjectId('5b9aadb39bd8d2174df9dfcc'),
#  ObjectId('5b9aadb39bd8d2174df9dfcd'),
#  ...]
